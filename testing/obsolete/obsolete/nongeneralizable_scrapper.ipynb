# %%
#!pip install lxml

# %%
import json
from pprint import pprint
import os
from datetime import datetime
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from lxml import etree
# Constants
API_SOURCE = "mediastack"
current_date, time = str(datetime.today()).split(" ")
current_date

path = os.path.join("News storage", API_SOURCE, current_date)

file_name = current_date + "_" + API_SOURCE + "_" + "extracted_news.json"
file_path = os.path.join(path, file_name)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}

# %%
def extract_html(url, main_root, headers=HEADERS):

    # With headers
    response = requests.get(url, headers=headers)
    print("Response code:", response.status_code)  # HTTP status code

    parsed_hmtl = BeautifulSoup(response.content, "html.parser")

    return parsed_hmtl, response.status_code

# %% [markdown]
# ## Extracion of full article from given url

# %% [markdown]
# ### el mundo

# %%
url = "https://elmundo.com/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}

# %%
# With headers
response = requests.get(url, headers=headers)
print(response.status_code)  # HTTP status code

parsed_hmtl = BeautifulSoup(response.content, "html.parser")
# Out:
# 503

# %% [markdown]
# ### 20minutos

# %%
url = "https://www.20minutos.es/"
main_root = "https://www.20minutos.es/"

date = "20230524"
# With headers
response = requests.get(url, headers=headers)
print("Response code:", response.status_code)  # HTTP status code
parsed_hmtl = BeautifulSoup(response.content, "html.parser")

#sections = parsed_hmtl.find_all("li", {"itemprop":"name"})
#urls_sections = [x.find("a").attrs["href"] for x in sections]
#print(urls_sections)

a_tags = parsed_hmtl.find_all("a", href=re.compile("/[0-9]+/"))


valid_urls = []
for a in a_tags:
    try:
        href = a["href"]
        print(href)
        if not href.startswith(main_root):
            href = main_root + href
        valid_urls.append(href)
    except:
        continue
print(len(valid_urls))
# Out:
# Response code: 200
# https://www.20minutos.es/noticia/5138821/0/asi-gesto-apoyo-pp-psoe-collboni-alcalde-barcelona-colau-fuera/
# https://www.20minutos.es/deportes/noticia/5138820/0/libres-3-y-clasificacion-del-gran-premio-de-canada-de-formula-1-en-directo-ultima-hora-de-alonso-y-sainz/
# https://www.20minutos.es/noticia/5138393/0/directo-negociaciones-partidos-contra-reloj-ultimo-dia-constitucion-ayuntamientos-pactos/
# https://www.20minutos.es/noticia/5138817/0/jaume-collboni-elegido-nuevo-alcalde-de-barcelona-con-el-apoyo-de-bcomu-y-el-pp/
# https://www.20minutos.es/noticia/5138821/0/asi-gesto-apoyo-pp-psoe-collboni-alcalde-barcelona-colau-fuera/
# https://www.20minutos.es/noticia/5138821/0/asi-gesto-apoyo-pp-psoe-collboni-alcalde-barcelona-colau-fuera/
# https://www.20minutos.es/noticia/5138826/0/trias-enfado-alcaldia-barcelona-que-les-den/
# https://www.20minutos.es/noticia/5138826/0/trias-enfado-alcaldia-barcelona-que-les-den/
# https://www.20minutos.es/noticia/5138823/0/colau-collboni-alcaldia-barcelona/
# https://www.20minutos.es/noticia/5138823/0/colau-collboni-alcaldia-barcelona/
# https://www.20minutos.es/noticia/5138813/0/llega-un-descenso-de-las-temperaturas-zonas-que-notaran-mas-la-bajada-del-termometro/
# https://www.20minutos.es/noticia/5138770/0/podemos-asume-su-derrota-ante-diaz-y-el-veto-a-irene-montero-para-ganar-hay-que-saber-perder/
# https://www.20minutos.es/noticia/5138707/0/comprobar-bonoloto-resultados-de-hoy-viernes-16-de-junio-de-2023/
# https://www.20minutos.es/noticia/5138707/0/comprobar-bonoloto-resultados-de-hoy-viernes-16-de-junio-de-2023/
# https://www.20minutos.es/noticia/5138728/0/euromillones-nuevo-millonario-espana-bote-millones/
# https://www.20minutos.es/noticia/5138728/0/euromillones-nuevo-millonario-espana-bote-millones/
# https://www.20minutos.es/noticia/5137529/0/cotizar-para-jubilacion-sin-necesidad-de-trabajar-convenios/
# https://www.20minutos.es/noticia/5137529/0/cotizar-para-jubilacion-sin-necesidad-de-trabajar-convenios/
# 134

# %%
parsed_hmtl.find_all("ul", attrs={"class": "default-secciones-menu"})
# Out:
# []

# %% [markdown]
# ### larazon

# %%
url = "https://www.larazon.es"
main_root = "https://www.larazon.es"

date = "20230524"
# With headers
response = requests.get(url, headers=headers)
print("Response code:", response.status_code)  # HTTP status code
parsed_hmtl = BeautifulSoup(response.content, "html.parser")

sections = parsed_hmtl.find("ul", attrs={"class": "custom_carousel_container"})
urls_sections = [x.attrs["href"] for x in sections.find_all("a")]

a_tags = parsed_hmtl.find_all("a", href=re.compile(".html$"))

valid_news_urls = []
not_valid_news_urls = []
for a in a_tags:
    try:
        href = a["href"]
        if not href.startswith(main_root):
            continue
        valid_news_urls.append(href)
    except:
        not_valid_news_urls.append(href)
len(valid_news_urls), len(not_valid_news_urls),
# Out:
# Response code: 200
# (551, 0)

# %%
urls = pd.Series(valid_news_urls)
urls
# Out:
# 0      https://www.larazon.es/gente/famosos/gerard-pi...
# 1      https://www.larazon.es/cataluna/jaume-collboni...
# 2      https://www.larazon.es/deportes/formula-1/jarr...
# 3      https://www.larazon.es/espana/feijoo-tapona-bi...
# 4      https://www.larazon.es/gente/famosos/natalia-a...
#                              ...
# 546    https://www.larazon.es/gente/famosos/gran-amor...
# 547    https://www.larazon.es/andalucia/situacion-ace...
# 548    https://www.larazon.es/andalucia/situacion-ace...
# 549    https://www.larazon.es/television/juez-tain-te...
# 550    https://www.larazon.es/television/juez-tain-te...
# Length: 551, dtype: object

# %%
urls[urls.str.split("/").str.len() > 4].iloc[:5].values
# Out:
# array(['https://www.larazon.es/gente/famosos/gerard-pique-clara-chia-casan-asi-sera-anuncio-matrimonial_20230617648dbaaa44049c0001c830c2.html',
#        'https://www.larazon.es/cataluna/jaume-collboni-psc-nuevo-alcalde-barcelona-votos-gratis-colau_20230617648dd57de9f5530001bf5ac4.html',
#        'https://www.larazon.es/deportes/formula-1/jarro-agua-fria-fernando-alonso-que-saldra-segundo-canada-aun-estamos-ese-nivel_20230618648ea45144049c0001ca02f5.html',
#        'https://www.larazon.es/espana/feijoo-tapona-bildu-erc-recupera-pactos-estado_20230618648e4554e9f5530001c04da1.html',
#        'https://www.larazon.es/gente/famosos/natalia-almarcha-risto-mejide-responde-comunicado-publicista-merezco_20230616648c4a3ee9f5530001bacf83.html'],
#       dtype=object)

# %%
urls[urls.str.split("/").str.len() > 5].iloc[:5].values
# Out:
# array(['https://www.larazon.es/gente/famosos/gerard-pique-clara-chia-casan-asi-sera-anuncio-matrimonial_20230617648dbaaa44049c0001c830c2.html',
#        'https://www.larazon.es/deportes/formula-1/jarro-agua-fria-fernando-alonso-que-saldra-segundo-canada-aun-estamos-ese-nivel_20230618648ea45144049c0001ca02f5.html',
#        'https://www.larazon.es/gente/famosos/natalia-almarcha-risto-mejide-responde-comunicado-publicista-merezco_20230616648c4a3ee9f5530001bacf83.html',
#        'https://www.larazon.es/deportes/futbol/hay-fecha-juicio-dani-alves-que-pena-enfrenta_20230618648eb3b2e9f5530001c0f69d.html',
#        'https://www.larazon.es/gente/famosos/donaciones-deudas-ficticias-sociedades-cruzadas-tretas-barbara-rey-burlar-hacienda_20230617648cf2e6e9f5530001bcd912.html'],
#       dtype=object)

# %% [markdown]
# Analyze one element

# %%
for i, news_url in enumerate(valid_news_urls[1:]):
    resp_url_news = requests.get(news_url, 
                                 headers=headers)
    parsed_hmtl = BeautifulSoup(resp_url_news.content, "html.parser")
    etree.xmlfile
    # header, footer and content
    element_article_mains = parsed_hmtl.find_all("div", 
                                                 class_=re.compile(r'article-main')
                                                )[:-1]
    texts = {}
    
    for main in element_article_mains:
        article_key = " ".join(main.attrs["class"])
        print(main.attrs)
        texts[article_key] = main.get_text(separator="\n", strip=True)
    # tags
    element_tags = parsed_hmtl.find("ul", {"class": "article-tags-list"}).get_text(separator="\n").split("\n")
    break
# Out:
# {'class': ['article-main', 'margin-none']}
# {'class': ['article-main__footer']}
# {'class': ['article-main']}

# %%
def find_attr_title(tag):
    return tag.has_attr('class') and "title" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
def find_attr_desc(tag):
    return tag.has_attr('class') and "description" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
def find_attr_maintag(tag):
    return tag.has_attr('class') and "tag" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
def find_attr_author(tag):
    return tag.has_attr('class') and "author" in " ".join(tag.attrs["class"])
def find_attr_date(tag):
    return tag.has_attr('class') and "date" in " ".join(tag.attrs["class"])
def find_attr_content(tag):
    return tag.has_attr('class') and "content" in " ".join(tag.attrs["class"])

# %%
for element in element_article_mains:
    
    main_division = " ".join(elem_it.attrs["class"])
    print(main_division)
    print(30*"*")
    element_title = element.find(find_attr_title)
    if element_title and element_title.text and element_title.text.strip():
        title = element_title.text
        print("title:", title)
    
    element_desc = element.find(find_attr_desc)
    if element_desc and element_desc.text and element_desc.text.strip():
        desc = element_desc.text
        print("desc:", desc)
    
    element_maintag = element.find(find_attr_maintag)
    if element_maintag and element_maintag.text and element_maintag.text.strip():
        maintag = element_maintag.text
        print("maintag:", maintag)
    
    #element_author_dates = element.find(find_attr_author)
    #if element_author_dates and element_author_dates.text and element_author_dates.text.strip():
    #    author_dates = element_author_dates.text
    #    creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", author_dates)
    #    print("author and dates:", author_dates)
            
    element_dates = element.find(find_attr_date)
    if element_dates and element_dates.text and element_dates.text.strip():
        dates = element_dates.text
        creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", author_dates)
        print("date:", dates)
            
    element_content = element.find(find_attr_content)
    if element_content and element_content.text and elem.text.strip():
        content = element_content.text
        print("content:", content)
    print("......")
# Out:
# article-main
# ******************************
# title: El PP impide que el independentismo consiga Barcelona: Collboni (PSC), nuevo alcalde
# desc: La alianza frena el gobierno independentista de Xavier Trias y Ernest Maragall
# maintag: Vuelco
# ......
# article-main
# ******************************
# date: Barcelona Creada: 17.06.2023 17:47 Última actualización: 17.06.2023 20:25
# ......
# article-main
# ******************************
# content: Final de infarto el que se vivió ayer en Barcelona con una insólita e histórica maniobra para evitar que el independentismo gobernara la ciudad y retomara el relato del «procés» en esta nueva etapa política. El PSC de Jaume Collboni recupera la alcaldía de la capital catalana 12 años después con los votos del partido de Ada Colau y del PP. Unos apoyos para la investidura necesarios e indispensables para evitar un frente de Junts y ERC en la capital catalana y que llevan a los socialistas a lograr su botín más preciado. Eso sí, Collboni gobernará en minoría y tendrá que llegar a acuerdos a lo largo de la legislatura.En concreto, la candidatura socialista ha obtenido este 17-J 23 apoyos –los 10 del PSC, los 9 de los Comunes y los 4 del PP– por los 16 de Trias con Junts y ERC.La capital catalana era la joya de la Corona para el PSC y también para el PSOE, la plaza a conquistar para afrontar con mejores perspectivas la campaña de las elecciones generales del 23 de julio. Y los socialistas han logrado «in extremis» la vara de mando con Jaume Collboni y gracias a los votos de los Comunes –facción integrada dentro de Sumar, de Yolanda Díaz– y del PP, una decisión que se materializó ayer en el último minuto. La formación de Colau anunció además que no entrará en el gobierno del PSC y que pasan a «hacer oposición», uno de los grandes objetivos de los populares comandados por Daniel Sirera en la capital catalana. «Barcelona en Comú solo formará parte de un gobierno en la ciudad de Barcelona si puede sumar con las otras dos fuerzas progresistas –PSC y ERC– y desde la oposición hará todo lo necesario para conseguirlo», señala el texto difundido por los Comunes sobre un pacto con socialistas y republicanos imposible.De hecho, el PP de Daniel Sirera dio los últimos votos necesarios a Jaume Collboni (PSC) al lograr sus dos máximos objetivos: evitar que Junts –el partido de Carles Puigdemont y Xavier Trias– gobernase la ciudad y levantase aquí el frente común independentista que reclama Pere Aragonès tras la fuerte caída de ERC en las municipales; y conseguir que ni Ada Colau ni los Comunes estén en el equipo de gobierno municipal. Es decir, ha dado carpetazo a la gestión de la ya exalcaldesa de Barcelona y posibilitó la investidura del candidato del PSC para evitar otro órdago independentista.Según fuentes del PP, el coordinador general del PP, Elías Bendodo, se puso en contacto el jueves con el secretario de Organización del PSOE, Santos Cerdán para ofrecer los votos populares bajo una condición: que Ada Colau no entrara en el equipo de gobierno, como así ha terminado ocurriendo en Barcelona.«No ha sido fácil dar apoyo a Collboni, principal adversario en el Gobierno de España. Pero siempre he dicho que priorizaríamos los intereses en Barcelona por encima de los de mi partido», admitió ayer Sirera sobre la posibilidad de que Puigdemont desde Waterloo y ERC desde la Generalitat usaran el Ayuntamiento de la capital catalana para sus intereses.La magnitud del vuelco se evidenció con solo ver las caras y los gestos del independentismo. Trias negaba con la cabeza, mientras Ernest Maragall miraba serio a Oriol Junqueras en el Consistorio minutos antes de la investidura de Collboni. Y en el momento de los discursos, el posconvergente Xavier Trias cambió de tono e incluso llegó a perder los papeles. En concreto, acusó al resto de partidos de «hacer tonterías», enmarcando lo sucedido en una maniobra para frenar al independentismo y se fue con las siguientes palabras: «A mis 76 años, yo ya lo decía: Si no salgo alcalde, que les den a todos».También está por ver qué ocurre con Ernest Maragall y ERC tras la debacle del partido en las municipales del 28-M y ante el 23-J.
# ......

# %%
title
# Out:
# 'El PP impide que el independentismo consiga Barcelona: Collboni (PSC), nuevo alcalde'

# %%
desc
# Out:
# 'La alianza frena el gobierno independentista de Xavier Trias y Ernest Maragall'

# %%
maintag
# Out:
# 'Vuelco'

# %%
author_dates
# Out:
# 'Cristina RubioBarcelona Creada: 17.06.2023 17:47 Última actualización: 17.06.2023 20:25'

# %%
#re.findall(r"[0-9]+(?:.{1}[0-9]+){0,2}", author_dates)
creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", dates)
creation_date, creation_time, update_date, update_time
# Out:
# ('17.06.2023', '17:47', '17.06.2023', '20:25')

# %%
content
# Out:
# 'Final de infarto el que se vivió ayer en Barcelona con una insólita e histórica maniobra para evitar que el independentismo gobernara la ciudad y retomara el relato del «procés» en esta nueva etapa política. El PSC de Jaume Collboni recupera la alcaldía de la capital catalana 12 años después con los votos del partido de Ada Colau y del PP. Unos apoyos para la investidura necesarios e indispensables para evitar un frente de Junts y ERC en la capital catalana y que llevan a los socialistas a lograr su botín más preciado. Eso sí, Collboni gobernará en minoría y tendrá que llegar a acuerdos a lo largo de la legislatura.En concreto, la candidatura socialista ha obtenido este 17-J 23 apoyos –los 10 del PSC, los 9 de los Comunes y los 4 del PP– por los 16 de Trias con Junts y ERC.La capital catalana era la joya de la Corona para el PSC y también para el PSOE, la plaza a conquistar para afrontar con mejores perspectivas la campaña de las elecciones generales del 23 de julio. Y los socialistas han logrado «in extremis» la vara de mando con Jaume Collboni y gracias a los votos de los Comunes –facción integrada dentro de Sumar, de Yolanda Díaz– y del PP, una decisión que se materializó ayer en el último minuto. La formación de Colau anunció además que no entrará en el gobierno del PSC y que pasan a «hacer oposición», uno de los grandes objetivos de los populares comandados por Daniel Sirera en la capital catalana. «Barcelona en Comú solo formará parte de un gobierno en la ciudad de Barcelona si puede sumar con las otras dos fuerzas progresistas –PSC y ERC– y desde la oposición hará todo lo necesario para conseguirlo», señala el texto difundido por los Comunes sobre un pacto con socialistas y republicanos imposible.De hecho, el PP de Daniel Sirera dio los últimos votos necesarios a Jaume Collboni (PSC) al lograr sus dos máximos objetivos: evitar que Junts –el partido de Carles Puigdemont y Xavier Trias– gobernase la ciudad y levantase aquí el frente común independentista que reclama Pere Aragonès tras la fuerte caída de ERC en las municipales; y conseguir que ni Ada Colau ni los Comunes estén en el equipo de gobierno municipal. Es decir, ha dado carpetazo a la gestión de la ya exalcaldesa de Barcelona y posibilitó la investidura del candidato del PSC para evitar otro órdago independentista.Según fuentes del PP, el coordinador general del PP, Elías Bendodo, se puso en contacto el jueves con el secretario de Organización del PSOE, Santos Cerdán para ofrecer los votos populares bajo una condición: que Ada Colau no entrara en el equipo de gobierno, como así ha terminado ocurriendo en Barcelona.«No ha sido fácil dar apoyo a Collboni, principal adversario en el Gobierno de España. Pero siempre he dicho que priorizaríamos los intereses en Barcelona por encima de los de mi partido», admitió ayer Sirera sobre la posibilidad de que Puigdemont desde Waterloo y ERC desde la Generalitat usaran el Ayuntamiento de la capital catalana para sus intereses.La magnitud del vuelco se evidenció con solo ver las caras y los gestos del independentismo. Trias negaba con la cabeza, mientras Ernest Maragall miraba serio a Oriol Junqueras en el Consistorio minutos antes de la investidura de Collboni. Y en el momento de los discursos, el posconvergente Xavier Trias cambió de tono e incluso llegó a perder los papeles. En concreto, acusó al resto de partidos de «hacer tonterías», enmarcando lo sucedido en una maniobra para frenar al independentismo y se fue con las siguientes palabras: «A mis 76 años, yo ya lo decía: Si no salgo alcalde, que les den a todos».También está por ver qué ocurre con Ernest Maragall y ERC tras la debacle del partido en las municipales del 28-M y ante el 23-J.'

# %% [markdown]
# Final script

# %%
# For title
def find_attr_title(tag):
    return tag.has_attr('class') and "title" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
# For desc
def find_attr_desc(tag):
    return tag.has_attr('class') and "description" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
# For maintag
def find_attr_maintag(tag):
    return tag.has_attr('class') and "tag" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
# For author
def find_attr_author(tag):
    return tag.has_attr('class') and "author" in " ".join(tag.attrs["class"])
# For dates
def find_attr_date(tag):
    return tag.has_attr('class') and "date" in " ".join(tag.attrs["class"])
# For content
def find_attr_content(tag):
    return tag.has_attr('class') and "content" in " ".join(tag.attrs["class"])

def one_news_data_extractor(elements):
    for element in elements:
        element_title = element.find(find_attr_title)
        title = None
        desc = None
        maintag = None
        creation_date, creation_time, update_date, update_time = [None] * 4
        content = None
        if element_title and element_title.text and element_title.text.strip():
            title = element_title.text
            if not title:
                return None

        element_desc = element.find(find_attr_desc)
        if element_desc and element_desc.text and element_desc.text.strip():
            desc = element_desc.text
            if not desc:
                return None

        element_maintag = element.find(find_attr_maintag)
        if element_maintag and element_maintag.text and element_maintag.text.strip():
            maintag = element_maintag.text
            if not maintag:
                return None

        element_dates = element.find(find_attr_date)
        
        if element_dates and element_dates.text and element_dates.text.strip():
            dates = element_dates.text
            creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", author_dates)
            if not creation_date or not creation_time or not update_date or not update_time:
                return None
            
        element_content = element.find(find_attr_content)
        if element_content and element_content.text and elem.text.strip():
            content = element_content.text
            if not content:
                None
    return dict(zip(("title", "desc", "maintag", "creation_date", "creation_time", "update_date", "update_time", "content"), 
                    (title, desc, maintag, creation_date, creation_time, update_date, update_time, content)
                   ))
# For tags
def find_attr_tags(tag):
    return tag.has_attr('class') and "tags" in " ".join(tag.attrs["class"]) and "article" in " ".join(tag.attrs["class"])

# %% [markdown]
# //*[contains(@class, 'tags') and contains(@class, 'article')]

# %%
news_url
# Out:
# 'https://www.larazon.es/podcast/imagenes-mundo-17-junio-2023_20230617648d30e644049c0001c69adb.html'

# %%
len(valid_news_urls)
# Out:
# 551

# %%
news_media_data = {}
not_processed_urls = []
valid_news_urls = list(set(valid_news_urls))
for i, news_url in enumerate(valid_news_urls):
    news_url_id = news_url.replace(".html", "").split("_")[-1]
    resp_url_news = requests.get(news_url, 
                                 headers=headers)
    parsed_news_hmtl = BeautifulSoup(resp_url_news.content, "html.parser")
    # header, footer and content
    elements_article = parsed_news_hmtl.find_all("div", 
                                                 class_=re.compile(r'article-main')
                                                )[:-1]
    if not elements_article:
        not_processed_urls.append(news_url)
        continue
    one_news_data = one_news_data_extractor(elements_article)
    one_news_data["tags"] = parsed_news_hmtl.find(find_attr_tags).get_text(separator="\n").split("\n")
    news_media_data[news_url_id] = one_news_data

# %%
len(valid_news_urls), len(news_media_data)
# Out:
# (551, 170)

# %% [markdown]
# La vanguardia

# %%
def find_attr_article(tag):
    return tag.has_attr('class') and "article" in " ".join(tag.attrs["class"])

# %%
raw_url
# Out:
# 'https://www.emagister.com/topemagister/Marketing_Digital-opc42p101t2?lavanguardia=pf-16845-widget&utm_source=lavanguardia&utm_medium=cpl&utm_campaign=widget_3&utm_content=muex_cursos_marketing_digital'

# %%
re.search(r"/[0-9]{8}/[0-9]{1,}/", "https://www.lavanguardia.com/economia/20230620/9055689/protesta-h-m-paraliza-mayoria-tiendas-espana-amenaza-rebajas.htm")
# Out:
# <re.Match object; span=(37, 55), match='/20230620/9055689/'>

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}
url = "https://www.lavanguardia.com"
main_root = "https://www.lavanguardia.com"
date = current_date.replace("-", "")
# With headers
response = requests.get(url, headers=headers)
print("Response code:", response.status_code)  # HTTP status code

parsed_hmtl = BeautifulSoup(response.content, "html.parser")
articles = parsed_hmtl.find_all(find_attr_article)

raw_urls = [article.find("a").attrs["href"] for article in articles]
complete_urls = []
rejected_urls = []
for raw_url in raw_urls:
    if not re.search(r"/[0-9]{8}/[0-9]{1,}/", raw_url):
        rejected_urls.append(raw_url)
        continue
    if raw_url.startswith("/"):
        raw_url = main_root + raw_url
    elif main_root not in raw_url:
        rejected_urls.append(raw_url)
        continue
    complete_urls.append(raw_url)
complete_urls = list(set(complete_urls))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001FB7A5D4C40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='www.lavanguardia.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001FB7A5D4C40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8012\1319569464.py in <module>
#       6 date = current_date.replace("-", "")
#       7 # With headers
# ----> 8 response = requests.get(url, headers=headers)
#       9 print("Response code:", response.status_code)  # HTTP status code
#      10
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     563                 raise SSLError(e, request=request)
#     564
# --> 565             raise ConnectionError(e, request=request)
#     566
#     567         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.lavanguardia.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001FB7A5D4C40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
len(complete_urls), len(rejected_urls)
# Out:
# (97, 32)

# %%
complete_urls
# Out:
# ['https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html',
#  'https://www.lavanguardia.com/economia/20230620/9053107/principado-reivindica-motor-economico-pirineo-brl.html',
#  'https://www.lavanguardia.com/economia/20230620/9056150/hacienda-autoriza-contrato-1-700-millones-airbus-comprar-16-nuevos-aviones.html',
#  'https://www.lavanguardia.com/deportes/tenis/20230620/9055874/resumen-alcaraz-rinderknech-queen-s.html',
#  'https://www.lavanguardia.com/local/barcelona/20230620/9055265/incendio-montjuic-levanta-columna-humo-visible-puntos-barcelona.html',
#  'https://www.lavanguardia.com/cultura/20230620/9056237/orquestra-liceu-lleva-ravel-dvorak-playa-bogatell-barcelona.html',
#  'https://www.lavanguardia.com/deportes/fc-barcelona/20230620/9055674/asi-avanzan-obras-camp-nou-cesped-asientos-grada.html',
#  'https://www.lavanguardia.com/natural/20230620/9051995/capturan-aguas-taiwan-mayor-tiburon-duende-conocido-fecha.html',
#  'https://www.lavanguardia.com/economia/20230620/9054968/cambra-cifra-50-900-millones-inversion-corregir-deficit-infraestructuras-catalunya.html',
#  'https://www.lavanguardia.com/cultura/20230620/8906729/alberto-mayol-50-leyes-el-padrino-aprender-tan-poderoso-vito-corleone.html',
#  'https://www.lavanguardia.com/cultura/20230620/9054928/poema-virgilio-grabado-anfora-romana-aceite-hallada-cordoba-arqueologia.html',
#  'https://www.lavanguardia.com/economia/20230620/9055287/call-center-100-000-trabajadores-estres-temporalidad-baja.html',
#  'https://www.lavanguardia.com/politica/20230620/9054725/interior-grave-delito-odio-lona-vox-madrid-basura-lgtbi-trans-independentismo.html',
#  'https://www.lavanguardia.com/local/barcelona/20230620/9056110/barcelona-global-pide-collboni-ambicion-posicionar-ciudad-mundo.html',
#  'https://www.lavanguardia.com/internacional/20230620/9054041/rusia-lanza-ataque-nocturno-masivo-sobre-toda-ucrania.html',
#  'https://www.lavanguardia.com/cultura/20230620/9053139/rito-revive-ultimo-puente-sogas-inca-mundo-q-eswachaka-peru.html',
#  'https://www.lavanguardia.com/economia/20230620/9054526/goirigolzarri-defiende-remuneracion-depositos-sera-clientes-demanden.html',
#  'https://www.lavanguardia.com/natural/20230620/9050819/l-eixample-puertos-barcelona-tarragona-treinta-zonas-contaminadas.html',
#  'https://www.lavanguardia.com/ciencia/20230620/9055581/economista-jaume-ventura-virologa-julia-vergara-reciben-premi-nacional-recerca.html',
#  'https://www.lavanguardia.com/magazine/moda/20230620/9055470/flores-3d-sombreros-mas-espectaculares-ascot.html',
#  'https://www.lavanguardia.com/opinion/20230620/9053065/chuppitos-privilegios-nuevas-generaciones.html',
#  'https://www.lavanguardia.com/historiayvida/mas-historias/20230620/9055351/historia-titanic-contaron.html',
head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- Source Hints -->
# <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//rsc.lavanguardia.com" rel="dns-prefetch"/>
# <link href="//rsc.mundodeportivo.com" rel="dns-prefetch"/>
# <link href="//sdk.privacy-center.org" rel="preconnect"/>
# <link href="//sdk.privacy-center.org" rel="dns-prefetch"/>
# <link href="//https://www.googletagmanager.com" rel="preconnect"/>
# <link href="//https://www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//es-config.sensic.net" rel="preconnect"/>
# <link href="//es-config.sensic.net" rel="dns-prefetch"/>
# <link href="//c.amazon-adsystem.com" rel="preconnect"/>
# <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//static.lavanguardia.com" rel="dns-prefetch"/>
# <script>var gg = window.gg = window.gg || {};
# window.googletag = window.googletag || {}, window.googletag.cmd = window.googletag.cmd || [];
# window.enabledYtIma = true;</script>
# <script async="" fetchpriority="high" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <link as="script" fetchpriority="low" href="https://sdk.privacy-center.org/3da070b4-2745-4eb6-8fc9-1fabe5f634e6/loader.js?target=www.lavanguardia.com" rel="preload"/>
# <script defer="" fetchpriority="high" src="https://rsc.lavanguardia.com/js/godo-didomix-v1001002.js"></script>
# <script defer="" fetchpriority="high" src="https://rsc.lavanguardia.com/js/godo-adsx-n-v1001082.js"></script>
# <link as="script" fetchpriority="high" href="https://es-config.sensic.net/s2s-web.js" rel="preload"/>
# <link as="script" fetchpriority="high" href="https://www.googletagmanager.com/gtm.js?id=GTM-PHSTS65" rel="preload"/>
# <link as="script" fetchpriority="low" href="https://www.google-analytics.com/analytics.js" rel="preload"/>
# <link as="script" fetchpriority="low" href="https://c.amazon-adsystem.com/aax2/apstag.js" rel="preload"/>
# <link as="font" crossorigin="" fetchpriority="low" href="https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Bold.woff2" rel="preload">
# <link as="font" crossorigin="" fetchpriority="low" href="https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Black.woff2" rel="preload">
# <link as="font" crossorigin="" fetchpriority="low" href="https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Regular.woff2" rel="preload">
# <link as="font" crossorigin="" fetchpriority="low" href="https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Light.woff2" rel="preload">
# <link as="font" crossorigin="" fetchpriority="low" href="https://static.lavanguardia.com/css/fonts/iconsfont/iconsfont-v10.woff2" rel="preload">
# <!-- Generic Site Meta's -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="La Vanguardia S.A" name="organization"/>
# <meta content="La Vanguardia Ediciones" name="copyright"/>
# <meta content="none" name="msapplication-config"/>
# <link href="https://www.lavanguardia.com/feed/rss/home" rel="alternate" title="RSS Portada" type="application/rss+xml"/>
# <link href="https://www.lavanguardia.com/favicon.ico" rel="icon" type="image/ico"/>
# <link href="https://www.lavanguardia.com/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-57x57.png.pagespeed.ic.9hwv6AsziA.webp" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-60x60.png.pagespeed.ic.fNndtHVf-o.webp" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-72x72.png.pagespeed.ic.PhT15TS3QO.webp" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-72x72.png.pagespeed.ic.PhT15TS3QO.webp" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-76x76.png.pagespeed.ic.lJ4TuCKwry.webp" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-76x76.png.pagespeed.ic.lJ4TuCKwry.webp" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-114x114.png.pagespeed.ic.rJzhCz7koN.webp" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-114x114.png.pagespeed.ic.rJzhCz7koN.webp" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-120x120.png.pagespeed.ic.jHsnbSr-cd.webp" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-120x120.png.pagespeed.ic.jHsnbSr-cd.webp" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-144x144.png.pagespeed.ic.KZ2pd6L53p.webp" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-152x152.png.pagespeed.ic.EnL8xWSBPu.webp" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-152x152.png.pagespeed.ic.EnL8xWSBPu.webp" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://www.lavanguardia.com/xlv-apple-icon-180x180.png.pagespeed.ic.YwI-K2mNIG.webp" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.lavanguardia.com/xlv-android-icon-192x192.png.pagespeed.ic._ODxVr2OkP.webp" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://www.lavanguardia.com/xlv-favicon-32x32.png.pagespeed.ic.5937V8MMmI.webp" rel="apple-touch-icon" sizes="32x32"/>
# <link href="https://www.lavanguardia.com/xlv-favicon-96x96.png.pagespeed.ic.bi49KItJKY.webp" rel="apple-touch-icon" sizes="96x96"/>
# <link href="https://www.lavanguardia.com/xlv-favicon-16x16.png.pagespeed.ic.cJHTo1iqYV.webp" rel="apple-touch-icon" sizes="16x16"/>
# <!-- SEO metatags -->
# <title>Feijóo ofrece un cara a cara con Sánchez o Yolanda Díaz o con ambos</title>
# <meta content="Feijóo ofrece un cara a cara con Sánchez o Yolanda Díaz o con ambos" name="title"/>
# <meta content="Llegó el día. El PP ha esperado hasta hoy, cuando se publican las listas electorales, para responder a los imperativos del PSOE para negociar los debates electorales" name="description"/>
# <meta content="pp, contempla, cara, cara, sánchez, feijóo, debate, económico, nadie, calviño" name="Keywords"/>
# <meta content="pp, contempla, cara, cara, sánchez, feijóo, debate, económico, nadie, calviño" name="news_keywords"/>
# <meta content="index, follow" name="robots"/>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html" rel="canonical"/>
# <link href="https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.amp.html" rel="amphtml"/>
# <!-- CMS metatags -->
# <meta content="2023-06-20T13:17:32Z" property="cms_creationDate"/>
# <meta content="Mari Carmen Del Riego De Lucas" property="cms_creator"/>
# <meta content="Mari Carmen Del Riego De Lucas" property="firma"/>
# <meta content="" property="cms_source"/>
# <meta content="" property="cms_id"/>
# <meta content="" property="cms_iid"/>
# <meta content="Mari Carmen Del Riego De Lucas" property="first_historical_creator"/>
# <meta content="2023-06-20T13:16:07Z" property="article:modified_time"/>
# <meta content="2023-06-20T09:10:15Z" name="date"/>
# <meta content="2023-06-20T09:10:15Z" name="DC.date.issued"/>
# <meta content="Política" property="article:section"/>
# <!-- Twitter sharing metatags -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@lavanguardia" name="twitter:site"/>
# <meta content="Feijóo ofrece un cara a cara con Sánchez o Yolanda Díaz o con ambos" name="twitter:title"/>
# <meta content="https://www.lavanguardia.com/files/og_thumbnail/files/fp/uploads/2023/06/18/648e31f1ab506.r_d.605-345-0.jpeg" name="twitter:image"/>
# <meta content="Llegó el día. El PP ha esperado hasta hoy, cuando se publican las listas electorales, para responder a los imperativos del PSOE para negociar los debates electorales" name="twitter:description"/>
# <meta content="15748165" property="twitter:account_id"/>
# <!-- Facebook sharing metatags -->
# <meta content="https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html" data-page-subject="true" property="og:url"/>
# <meta content="Feijóo ofrece un cara a cara con Sánchez o Yolanda Díaz o con ambos" data-page-subject="true" property="og:title"/>
# <meta content="article" data-page-subject="true" property="og:type"/>
# <meta content="La Vanguardia" data-page-subject="true" property="og:site_name"/>
# <meta content="Llegó el día. El PP ha esperado hasta hoy, cuando se publican las listas electorales, para responder a los imperativos del PSOE para negociar los debates electorales" data-page-subject="true" property="og:description"/>
# <meta content="https://www.lavanguardia.com/files/og_thumbnail/files/fp/uploads/2023/06/18/648e31f1ab506.r_d.605-345-0.jpeg" data-page-subject="true" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="675" property="og:image:height"/>
# <meta content="2023-06-20T09:10:15Z" property="og:article:published_time"/>
# <meta content="308114232627941" property="fb:app_id"/>
# <meta content="156552584408339, 771277509704459, 958861534247204, 926823234046883, 212415508953697, 291917499474" property="fb:pages"/>
# <!--script type="didomi/javascript" data-vendor-raw="didomi:google" data-purposes="cookies" async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script-->
# <link as="image" href="/files/image_449_220/files/fp/uploads/2023/06/18/648e31f1ab506.r_d.605-345.jpeg" media="(max-width: 479px)" rel="preload"/>
# <link as="image" href="/files/image_607_298/files/fp/uploads/2023/06/18/648e31f1ab506.r_d.605-345.jpeg" media="(min-width: 479.1px) and (max-width: 637px)" rel="preload"/>
# <link as="image" href="/files/image_948_465/files/fp/uploads/2023/06/18/648e31f1ab506.r_d.605-345.jpeg" media="(min-width: 638px)" rel="preload"/>
# <meta content="false" property="article:opinion"/>
# <meta content="free" property="article:content_tier"/>
# <meta content="region:ESP" property="article:location"/>
# <meta content="Politics" property="article:tag"/>
# <!--article-critical-default-->
# <script>var ggIsApp=false</script>
# <style>
#                     @font-face{font-family:tiemposheadline-medium;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Medium.woff2?1684396345) format("woff2"),url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Medium.eot#iefix?1684396345) format("embedded-opentype");font-weight:400;font-style:normal;font-display:swap}@font-face{font-family:tiemposheadline-regular;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Regular.woff2?1684396345) format("woff2"),url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Regular.eot#iefix?1684396345) format("embedded-opentype");font-weight:400;font-style:normal;font-display:swap}@font-face{font-family:tiemposheadline-black;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Black.woff2?1684396345) format("woff2"),url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Black.eot#iefix?1684396345) format("embedded-opentype");font-weight:700;font-style:normal;font-display:swap}@font-face{font-family:tiempostext-regular;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposText-Regular.woff2?1684396345) format("woff2"),url(https://static.lavanguardia.com/css/fonts/v2/TiemposText-Regular.eot#iefix?1684396345) format("embedded-opentype");font-style:normal;font-display:swap}@font-face{font-family:TiemposHeadline;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Bold.woff2?1684396345) format("woff2");font-weight:900;font-style:normal;font-display:swap}@font-face{font-family:TiemposHeadline;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Medium.woff2?1684396345) format("woff2");font-weight:700;font-style:normal;font-display:swap}@font-face{font-family:TiemposHeadline;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Regular.woff2?1684396345) format("woff2");font-weight:400;font-style:normal;font-display:swap}@font-face{font-family:TiemposHeadline;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposHeadline-Light.woff2?1684396345) format("woff2");font-weight:100;font-style:normal;font-display:swap}@font-face{font-family:TiemposText;src:url(https://static.lavanguardia.com/css/fonts/v2/TiemposText-Regular.woff2?1684396345) format("woff2");font-weight:400;font-style:normal;font-display:swap}@font-face{font-family:roboto-bold;src:url(https://static.lavanguardia.com/css/fonts/roboto/Roboto-Bold.woff?1684396345) format("woff"),url(https://static.lavanguardia.com/css/fonts/roboto/Roboto-Bold.eot#iefix?1684396345) format("embedded-opentype");font-style:normal;font-display:swap}@font-face{font-family:iconsfont;src:url(https://static.lavanguardia.com/css/fonts/iconsfont/iconsfont-v10.woff2?1684396345) format("woff2"),url(https://static.lavanguardia.com/css/fonts/iconsfont/iconsfont-v10.woff?1684396345) format("woff"),url(https://static.lavanguardia.com/css/fonts/iconsfont/iconsfont-v10.ttf?1684396345) format("truetype"),url(https://static.lavanguardia.com/css/fonts/iconsfont/iconsfont-v10.eot?#iefix?1684396345) format("embedded-opentype"),url(https://static.lavanguardia.com/css/fonts/iconsfont/iconsfont-v10.svg#fontawesome?1684396345) format("svg");font-weight:400;font-style:normal}.fa,.fab,.fad,.fal,.far,.fas{font-family:iconsfont;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;speak:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;display:inline-block;text-rendering:auto}.fa-bars:before{content:"\61"}.fa-search:before{content:"\62"}.fa-bell:before{content:"\63"}.fa-user:before{content:"\64"}.fa-camera:before{content:"\65"}.fa-play:before{content:"\66"}.fa-expand:before{content:"\67"}.fa-arrow-circle-right:before{content:"\68"}.fa-times:before{content:"\69"}.fa-user-circle:before{content:"\6a"}.fa-envelope:before{content:"\74"}.fa-plus:before{content:"\75"}.fa-caret-down:before{content:"\70"}.fa-angle-left:before{content:"\6f"}.fa-angle-right:before{content:"\6e"}.fa-right-open-big:before{ ...
#                     @media only screen and (min-width:768px) and (min-width:768px){body.wallpaper-adv-active-sky1 header.header,body.wallpaper-adv-active-sky2 header.header,body.wallpaper-adv-active-wall header.header{background:#fff}.ads-wall-container{position:absolute;top:0;bottom:0;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column}.ads-wall-container-left{margin-left:0;text-align:right;right:calc(50% + 504px);width:auto}.ads-wall-container-right{right:0;margin-right:0;text-align:left;width:auto;left:calc(50% + 504px)}.ads-wall-push{-webkit-box-flex:1;-ms-flex-positive:1;flex-grow:1}.ads-wall-left,.ads-wall-right{position:-webkit-sticky;position:sticky;top:40px;overflow:hidden}.top-ad-sky-board-container{position:absolute;top:0;bottom:0;display:block;left:50%;width:98vw;right:auto;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%)}.top-ad-sky-board-container .content-html,.top-ad-sky-board-container .top-ad-module,.top-ad-sky-board-container>div{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;height:100%;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column}.top-ad-sky-board-container .content-html>span,.top-ad-sky-board-container .top-ad-module>span,.top-ad-sky-board-container>div>span{height:100%}.top-ad-sky-board-container .skyl-inpage-container,.top-ad-sky-board-container .skyr-inpage-container{height:100%;position:absolute}.top-ad-sky-board-container .skyl-inpage-container{left:0;text-align:right;right:calc(50% + 504px)}.top-ad-sky-board-container .skyl-inpage-container .ad-unit{text-align:right}.top-ad-sky-board-container .skyr-inpage-container{right:0;text-align:left;left:calc(50% + 504px);min-width:auto}.top-ad-sky-board-container .skyr-inpage-container .ad-unit{text-align:left}.top-ad-sky-board-container .ad-unit{line-height:0;display:block;padding:0;position:-webkit-sticky;position:sticky;top:45px;z-index:1;height:600px}.top-ad-sky-board-container .ad-unit ins{min-width:300px;position:absolute;left:0;right:0}.top-ad-sky-board-container .ad-unit.skyl-inpage,.top-ad-sky-board-container .ad-unit.skyr-inpage{overflow:hidden}.top-ad-sky-board-container .ad-unit.skyl-inpage ins{left:auto;width:100%}}@media only screen and (min-width:768px){.wallpaper-inverted-ad{display:none}.container{padding-left:21px;padding-right:21px;max-width:990px}.container.full{padding-left:5px;padding-right:5px}.row{margin-left:-12px;margin-right:-12px}.visible-xs{display:none}.visible-md{display:block}.module-box-ads span{padding-top:0;padding-left:0;padding-right:0}.wallpaper-adv-active .top-ad-board-container .top-ad-module .content-ad.visible-md{margin-bottom:0}.container-freehtml .board-module-ads.visible-xs.mega-container{margin-left:0;margin-right:0}.container-freehtml.freehtml-3cols .col-md-4{margin:0}.col,.col-1,.col-10,.col-11,.col-12,.col-2,.col-3,.col-4,.col-5,.col-6,.col-7,.col-8,.col-9,.col-auto,.col-md,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-auto{padding-left:12px;padding-right:12px}main#main-container{max-width:100%;background-color:transparent;width:auto}.super-header-full-container{display:flex;display:-webkit-box;display:-moz-box;display:-ms-flexbox;display:-webkit-flex;justify-content:space-between;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;padding:0}.supra-header-icons{display:flex;min-width:265px}.supra-header-icons span.logged-In-icon{font-size:18px;line-height:18px}.supra-header-icons span.fa-user{font-size:18px;line-height:18px}header.header{padding-bottom:25px}header.header .main-header>.container.full{padding-left:9px;padding-right:9px}header.header.header-home .main-header{height:76px}header.header.header-ho ...
#             </style>
# <link as="style" href="https://static.lavanguardia.com/css/article-deferred.css?1684396345" onload="this.onload=null;this.rel='stylesheet'" rel="preload">
# <link as="style" href="https://static.lavanguardia.com/css/article-deferred-responsive.css?1684396345" media="screen and (min-width: 768px)" onload="this.onload=null;this.rel='stylesheet'" rel="preload">
# <script type="text/javascript">
#     var cssFilesByTemplate = {"default":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""}],"static":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\"","mediaQuery":"screen and (min-width: 768px)"},{"href":"https:\/\/static.lavanguardia.com\/css\/global.css?1684396345"},{"href":"https:\/\/static.lavanguardia.com\/css\/global-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)"}],"brandslab":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""}],"video":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""}],"coverage":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""}],"sport":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""}],"notepad":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""}],"opinion":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/article-opinion.css?1684396345"},{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred-responsive.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\"","mediaQuery":"screen and (min-width: 768px)"},{"href":"https:\/\/static.lavanguardia.com\/css\/article-opinion-responsive.css?1684396345","mediaQuery":"screen and (min-width: 768px)"}],"gallery":[{"href":"https:\/\/static.lavanguardia.com\/css\/article-deferred.css?1684396345","rel":"preload","extra":"as=\"style\" onload=\"this.onload=null;this.rel='stylesheet'\""},{"href":"https:\/\/static.lavanguardia.com\/css\/gallery.css?1684396345 ...
# </script>
# <script async="" src="https://news.google.com/swg/js/v1/swg.js" subscriptions-control="manual"></script>
# <script async="" src="https://news.google.com/swg/js/v1/swg-gaa.js"></script>
# <script async="" defer="" src="https://accounts.google.com/gsi/client"></script>
# <script type="application/ld+json">{"@type":"NewsArticle","@context":"https:\/\/schema.org","headline":"Feij\u00f3o ofrece un cara a cara con S\u00e1nchez o Yolanda D\u00edaz o con ambos","alternativeHeadline":"Los populares tambi\u00e9n se abren a un debate a cuatro con presencia de Vox y Sumar","datePublished":"2023-06-20T11:10:15+0200","dateModified":"2023-06-20T15:16:07+0200","publisher":{"@type":"Organization","id":"#organization","name":"La Vanguardia","url":"https:\/\/www.lavanguardia.com","logo":{"@type":"ImageObject","@id":"#logoImage","url":"https:\/\/www.lavanguardia.com\/files\/logo_microformat\/bundles\/lavanguardiacms\/images\/logo-lv.png","height":60,"width":326},"sameAs":["https:\/\/www.facebook.com\/LaVanguardia","https:\/\/www.instagram.com\/lavanguardia","https:\/\/www.twitter.com\/lavanguardia"]},"description":"El PP ya ha dado su respuesta al PSOE sobre los debates electorales y lo ha hecho una vez cerrado el plazo para registrar las listas para las elecciones generales del 23 de julio mediante&nbsp; una carta enviada por del vicesecretario de acci\u00f3n institucional del PP, Esteban Gonz\u00e1lez Pons, al secretario de Organizaci\u00f3n del PSOE, Santos Cerd\u00e1n, para transmitirle que aceptan un solo cara a cara entre Alberto N\u00fa\u00f1ez Feij\u00f3o y el integrante de la coalici\u00f3n del Gobierno que determinen el PSOE y Sumar, entendiendo que estos ser\u00edan Pedro S\u00e1nchez o Yolanda D\u00edaz. Aunque el PP tambi\u00e9n abre la puerta a que sean ambos los que debatan con su l\u00edder.","keywords":"pp, contempla, cara, cara, s\u00e1nchez, feij\u00f3o, debate, econ\u00f3mico, nadie, calvi\u00f1o","articleSection":"Pol\u00edtica","articleBody":"El PP ya ha dado su respuesta al PSOE sobre los debates electorales y lo ha hecho una vez cerrado el plazo para registrar las listas para las elecciones generales del 23 de julio mediante&nbsp; una carta enviada por del vicesecretario de acci\u00f3n institucional del PP, Esteban Gonz\u00e1lez Pons, al secretario de Organizaci\u00f3n del PSOE, Santos Cerd\u00e1n, para transmitirle que aceptan un solo cara a cara entre Alberto N\u00fa\u00f1ez Feij\u00f3o y el integrante de la coalici\u00f3n del Gobierno que determinen el PSOE y Sumar, entendiendo que estos ser\u00edan Pedro S\u00e1nchez o Yolanda D\u00edaz. Aunque el PP tambi\u00e9n abre la puerta a que sean ambos los que debatan con su l\u00edder. En la misiva, los populares se\u00f1alan que acceden a celebrar el cara a cara propuesto por los socialistas \"tras la agobiada petici\u00f3n repetida por su presidente\" y precisa Gonz\u00e1lez Pons  que dado que el Gobierno es el primero de coalici\u00f3n en la historia y que su vicepresidenta segunda ha manifestado p\u00fablicamente su inter\u00e9s por participar en ese cara a cara, quedan a la espera de que las fuerzas que componen el Ejecutivo comuniquen qu\u00e9 persona designan para el debate. Entienden que la propuesta ser\u00eda Pedro S\u00e1nchez o Yolanda D\u00edaz, pero a\u00f1aden que \"para facilitar vuestra situaci\u00f3n interna en el seno del Gobierno\" aceptar\u00edan la posibilidad de que el debate fuera \"a tres\" con S\u00e1nchez y con D\u00edaz. La idea con la que el PP se aproxima a las negociaciones de los debates electorales no contempla, en ninguno de los casos, los seis cara a cara que el presidente del Gobierno ha ofrecido al PP, uno por semana desde hace ya dos semanas. Los populares plantean tambi\u00e9n un debate con los cuatro principales partidos de \u00e1mbito espa\u00f1ol (PSOE, PP, Vox y Sumar) y con aquellos que, de la mano Pedro S\u00e1nchez, se incorporaron a la \u201cgobernabilidad del Estado\u201d (ERC, PNV y Bildu). Fuentes del PSOE ya han se\u00f1alado que la carta recibida \"destila la misma falta de respeto y el mismo tono falt\u00f3n que impregna todas las declaraciones del PP\" y que no es el PP quien determina los debates sino los grupos de comunicaci\u00f3n convocantes (RTVE, A3MEDIA, MEDIASET y PRISA) que han  ...
# <script type="text/javascript">
#                 var jwplayer_playerId = "hTFJ4MdY";
# var jwplayer_playList = "RPOlwxJ4";
#
#                 var adsPositionsNo = 4;
#         var varPageCommentsEnabled = 1;
#                 var varPageScrollEnabled = 1;
#             </script>
# <script> var varPageScrollEnabled = 1;</script>
# <script type="script/gg">
#     window.enabledYtIma = true;
#
#     var ggUnitName = "\/55964524\/lv_w\/politica\/p";
#     if (ggPageData.unitName){
#         ggUnitName = ggPageData.unitName;
#     } else if (ggPageData.adUnit) {
#         ggUnitName = ggPageData.adUnit;
#     }
#
#     var adsCfg = {
#         "unitname": ggUnitName,
#         "keys":{
#             "cat":ggPageData.webType,
#             "id":ggPageData.contentId
#         },
#         "sequential":["roba","mega","triplepack-izq-","triplepack-cen-","triplepack-der-","mega_suscriptor"],
#         "sectionable":["cintillo","patrocinio"]
#     };
#     adsCfg.keys['environment'] = "pro-cms";
#     adsCfg.keys['trackingId'] = gg.util.getTrackingId();
#     adsCfg.keys['articleCount'] = "1";
#     adsCfg.keys['sc'] = '';
#
#     var gaId = gg.cookie.get("_ga");
#     if (typeof gaId !== "undefined") {
#         adsCfg.keys["gaId"] = gaId;
#     }
#
#
#     adsCfg.keys['userAgent'] = navigator.userAgent;
#     adsCfg.keys['pageKeys'] = ggPageData.pageKeys ? ggPageData.pageKeys : [];
#
#     var getFormattedSections = function(){
#         var sections = ggPageData.sections || '';
#         return sections.split('#').filter(x => x != "");
#     }
#     adsCfg.keys['sections'] = getFormattedSections();
#
#     if (typeof dataAdsTopics != 'undefined'){
#         adsCfg.keys['topics'] = dataAdsTopics;
#     } else {
#         adsCfg.keys['topics'] = [];
#
#     }
#
#     adsCfg.unitname.split('/')[3] == 'p' ? adsCfg.adUnitSection = 'homepage' : adsCfg.adUnitSection = adsCfg.unitname.split('/')[3];
#
#     adsCfg.aps = {
#         pubID: '3714',
#         isEnabled: false,
#         adServer: 'googletag'
#     }
#
#     adsCfg.googletagVendorId = 'google';
#     adsCfg.apstagVendorId = 'c:amazonads-9c5TNGaj';
#     adsCfg.isDfpConsentRequired = true;
#
#     adsCfg.prebid = {
#         timeout : 1200,
#         bidders: {"appnexus":{"md":{"mega1":"16324259","mega2":"16324260","mega3":"16324261","mega4":"16324262","mega5":"16324263","mega6":"16324264","roba1":"16324265","roba2":"16324266","roba3":"16324267","roba4":"16324269","roba5":"16324270","roba6":"16324271","roba7":"16324272","skyr-inpage":"16324273","skyl-inpage":"16324274","pre-roll":"18208776"},"xs":{"mega1":"16324579","mega2":"16324580","mega3":"16324581","mega4":"16324582","mega5":"16324583","mega6":"16324584","roba1":"16324585","roba2":"16324586","roba3":"16324587","roba4":"16324588","roba5":"16324589","roba6":"16324590","roba7":"16324591","pre-roll":"18208771"}},"criteo":{"networkId":"9832","publisherSubIdPrefix":"lavanguardia_web"},"smartadserver":{"siteId":"293335","pageId":"1078632","md":{"mega1":"77826","mega2":"77827","mega3":"77828","mega4":"77829","mega5":"77830","mega6":"77831","mega7":"77832","mega8":"77833","mega9":"77834","roba1":"77847","roba2":"77848","roba3":"77849","roba4":"77850","roba5":"77851","roba6":"77852","roba7":"77853","roba8":"77854","roba9":"77855","skyl-inpage":"78109","skyr-inpage":"78108"},"xs":{"mega1":"77837","mega2":"77838","mega3":"77839","mega4":"77840","mega5":"77841","mega6":"77842","mega7":"77843","mega8":"77844","mega9":"77845","roba1":"77847","roba2":"77848","roba3":"77849","roba4":"77850","roba5":"77851","roba6":"77852","roba7":"77853","roba8":"77854","roba9":"77855"}},"richaudience":{"md":{"mega1":{"0":"aNaXJdDvuL","1":"1gQhRt80hv"},"roba1":"1RTpvUFaDi","roba2":"2F1bMdvQu6","roba3":"7Y70bZitxT","roba4":"1r9klYTjZC","roba5":"0CsNLIjw2h","roba6":"0LnvaGbOZa","roba7":"0hJChb7mJK","skyl-inpage":"j4SK4Qf3mj","skyr-inpage":"RwysGvzhSL"},"sm":{"mega1":{"0":"ypBZN0Dlrk","1":"xSVHofTKhi"},"roba1":"AGtH0mSoEW","roba2":"1jEFqsZQ0S","roba3":"WYhNchHxsD","roba4":"mHnn7u2ksB","roba5":"1ph3qY3443","roba6":"2PIByXjhcR","roba7":"S1VdhdOBlT"},"xs":"sm"},"ias":{"pubId":"931352"}}
#     };
#
#     godo.ads.push(function(x) {
#         x.configure(null, adsCfg);
#     });
#
#     godo.ads.push(function(x) {
#     document.location.hostname.indexOf('admin.') !== 0 && x.init()
#     });
#
#     godo.ads.push(function(x) {
#         x.displayOnScroll({
#             threshold: 450,
#             delay:100,
#             selector: "[data-ad-lazy=true]"
#         });
#     });
#
#     godo.ads.push(function(x) {x.display("[data-ad-lazy=false]")});
#
# </script>
# <script>
#     var ggPageData = {"contentId":"article-9054163","webType":"story","authorName":"Carmen del Riego#","sections":"\/politica#","relatedNews":"1","inlineNews":"1","accessType":"abierto-libre","wordCounter":"484","facet":"web","topics":"","slug":"\/politica\/20230620\/9054163\/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html","pageKeys":"","unitName":"\/55964524\/lv_w\/politica\/n","path":"","userType":"anonimo","consents":"","userId":"","signwallDate":"","environment":"pro","title":"Feijóo ofrece un cara a cara con Sánchez o Yolanda Díaz o con ambos","description":"Los populares también se abren a un debate a cuatro con presencia de Vox y Sumar","paragraphCounter":"7","mainSection":"\/politica","authorCreator":"Mari Carmen Del Riego De Lucas","authorPublication":"Josep Maria Calvet Fransesch","authorModification":"Josep Maria Calvet Fransesch","firstHistoricalCreator":"Mari Carmen Del Riego De Lucas","publicationDate":"2023-06-20 11:10:15","forcedUpdateDate":"2023-06-20 15:17:32","creationDate":"2023-06-20 11:05:55","modificationDate":"2023-06-20 15:16:07","La Contra":"","url":"https:\/\/www.lavanguardia.com\/politica\/20230620\/9054163\/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html"};
#     var dataLayer = window.dataLayer = window.dataLayer || [];
# </script>
# <script type="script/gg">
#     if(gg.didomi){
#         window.didomiOnReady.push(function(){
#             if(gg.didomi.getPurposesStatus()){
#                 ggPageData.consents = gg.didomi.getPurposesStatus();
#                 dataLayer.push({consents: ggPageData.consents})
#             }
#         });
#     }
#     if (gg && gg.util) {
#         var userId = gg.cookie.get(gg.accounts.cookieName);
#         if( userId ){
#             ggPageData.userId = userId;
#             ggPageData.userType = gg.accounts.getUserType();
#         }
#
#         var signwallDate = gg.accounts.getUser().signwallDate;
#         if (signwallDate !== undefined && userId) {
#             signwallDate = new Date(signwallDate);
#             var date = signwallDate.getFullYear() + "-" + ('0' + (signwallDate.getMonth() + 1)).slice(-2) + "-" + ('0' + signwallDate.getDate()).slice(-2);
#             var time = ('0' + signwallDate.getHours()).slice(-2) + ":" + ('0' + signwallDate.getMinutes()).slice(-2) + ":" + ('0' + signwallDate.getSeconds()).slice(-2);
#             ggPageData.signwallDate = date + " " + time;
#         }
#     }
#     window.ggPageDataReady && window.ggPageDataReady(ggPageData);
# </script>
# <script type="text/javascript">
#     var ggCmd = ggCmd || [];
#     var ggGDPRCmd = ggGDPRCmd || [];
# </script>
# <script type="text/javascript">
#     var megaAdSticky = '0';
# </script>
# <script>
# //window.didomiBypass = true;
# window.__didomiVersion = 2;
#
# var ua = 'UA-999736-3'
#
# var initGtm = function() {
# 	(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-PHSTS65');
#
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', ua, 'auto');
# };
#
# window.__evContext = {
# 	platform: "",
# 	token: "",
# 	isApp: false,
# 	onAuth: null,
# 	onNoConsent: null,
# 	isInfiniteScroll: false,
# 	isInfiniteScrollHandlerRegistered: false,
# 	isParamsHandlerRegistered: false,
# 	triggerStop: false,
# 	onAuthTriggered: false,
# 	webtypesAllowed: [],
# 	exemptedSections: [],
# 	usertypeNotifierAllowed: [],
#     webtypesAllowedNotifier: [],
#     exemptedSectionsNotifier: [],
#     webtypesAllowedPaywall: [],
# 	articleContainer: null,
# 	isNativePurchaseEnabled: null,
# 	dab: {
# 		active: false,
# 		adServiceURL: "https://static.criteo.net/images/pixel.gif"
# 	},
# 	googleOneTap: {
# 		active: true,
# 		webtypesAllowed: []
# 	}
# };
#
# var triggerAuth = function(opts) {
# 	try {
# 		opts = opts || {};
# 		opts.webtypesAllowed = ["story-reportage", "story-video", "la-contra", "lacontra", "story", "opinion", "homepage", "section-page", "section-page-opinion", "topics"];
# 		opts.exemptedSections = ["television", "series", "cribeo", "participacion", "de-moda", "motor", "comer", "magazine","gente"];
# 		opts.webtypesAllowedPaywall = ["story-reportage", "story-video", "la-contra", "lacontra", "story", "opinion", "homepage","section-page","section-page-opinion", "topics"];
# 		opts.googleOneTap.webtypesAllowed = ["homepage"];
#
# 		var sections = gg.paywall.utils.getSections(ggPageData.sections);
# 		var category = gg.paywall.utils.getCategory(ggPageData.sections);
# 		var accessType = gg.paywall.utils.getAccessType(ggPageData.accessType);
# 		window.params = window["params"] || {};
#
# 		params["articleId"] = ggPageData.contentId;
# 		params["section"] = sections[0];
# 		params["category"] = category;
# 		params["webtype"] = ggPageData.webType;
# 		params["authors"] = gg.paywall.utils.removeHash(ggPageData.authorName);
# 		params["site"] = window.location.hostname;
# 		try {
# 			params["registered"] = gg.paywall.utils.getRegisteredValue(gg.accounts.getUser().registrationDate);
# 		} catch(e){}
#
# 		try {
# 			if (typeof adsCfg !== "undefined") {
# 				if (typeof adsCfg.keys['topics'] !== "undefined") {
# 					params["tags"] = Array.isArray(adsCfg.keys['topics']) ? adsCfg.keys['topics'].join(',') : adsCfg.keys['topics'];
# 				}
# 			}
# 		} catch(e) {console.log(e)}
#
# 		params["publicationDate"] = gg.paywall.utils.getDate(ggPageData.publicationDate);
# 		params["modificationDate"] = gg.paywall.utils.getDate(ggPageData.modificationDate);
# 		params["facet"]= ggPageData.facet;
# 		params["url1"]= sections[0];
# 		params["url2"]= category.split("/")[0];
# 		params["accessType"] = accessType;
# 		params["platform"] = opts.isApp ? (gg.accounts.getCustomUserAgent() || "").replace(/[^A-Za-z]/g, "") : ggPageData.facet;
# 		params["thirdPartySegment"] = (JSON.parse(ev.storage.load("local", "evolok:impulso:config")) || {}).thirdPartySegment || "";
#
# 		try {
# 			var externalParamsKey = "evolok:external:params";
# 			var externalParamsConfig = JSON.parse(gg.cookie.get(externalParamsKey) || null) || {};
# 			if (externalParamsConfig.data &&  typeof externalParamsConfig.data === 'object' && Object.keys(externalParamsConfig.data).length > 0)
# 				params = $.extend({}, params, externalParamsConfig.data);
# 		} catch(e) {}
#
# 		if (gg.accounts.didomiLogged() || (Didomi && Didomi.getUserConsentStatusForVendor('c:evolok-izKz7AYV'))) {
# 			if (!opts.isInfiniteScroll || !opts.onAuthTriggered || (opts.isApp && !gg.accounts.didomiLogged())) {
# 				if (opts.onAuth && typeof opts.onAuth === "function") {
# 					opts.onAuth(params, opts.token, opts.platform);
# 					opts.onAuthTriggered = true;
# 				}
# 			} else {
# 				gg.paywall.verifyAuthorization(params, opts.isApp);
# 			}
# 		} else {
# 			if (accessType === "yes" && (opts.onNoConsent && typeof opts.onNoConsent === "function")) {
# 				opts.onNoConsent(params, opts);
# 				return;
# 			}
# 			if (!opts.isApp && opts.dab && opts.dab.active) {
# 				gg.paywall.triggerDabDetection(params);
# 			}
# 		}
# 	} catch(e) {
# 		console.log(e);
# 	}
# };
#
# var registerParams = function() {
# 	if (__evContext.isParamsHandlerRegistered) {
# 		return;
# 	}
#
# 	window.didomiOnReady = window.didomiOnReady || [];
# 	window.didomiOnReady.push(function (Didomi) {
# 		try {
# 			__evContext.articleContainer = document.querySelectorAll("article.article-default")[0];
#
# 			if (window.ggReady || (document.readyState === 'complete')) {
# 				gg.didomi.onTCLoaded(function(){
#             		triggerAuth(__evContext);
#         		});
# 			} else {
# 				document.addEventListener('readystatechange', (e) => {
# 					if (document.readyState === 'complete') {
# 						gg.didomi.onTCLoaded(function(){
# 							triggerAuth(__evContext);
# 						});
# 					}
# 				});
# 			}
# 			__evContext.isParamsHandlerRegistered = true;
# 		} catch(e) {
# 			console.log(e);
# 		}
# 	});
# };
#
# var registerInfiniteScroll = function() {
# 	if (__evContext.isInfiniteScrollHandlerRegistered) {
# 		return;
# 	}
# 	document.addEventListener("infiniteScrollChangeUrl", function(event) {
# 		if (!__evContext.isInfiniteScroll) {
# 			__evContext.isInfiniteScroll = true;
# 		}
# 		__evContext.articleContainer = event.articleContainer;
# 		triggerAuth(__evContext);
# 	});
# 	__evContext.isInfiniteScrollHandlerRegistered = true;
# };
#
# if (ggPageData) {
# 	var dataLayer = window.dataLayer || [];
# 	dataLayer.push({
# 		environment: ggPageData.environment,
# 		contentId: ggPageData.contentId,
# 		webType: ggPageData.webType,
# 		slug: ggPageData.slug,
# 		facet: ggPageData.facet,
# 		accessType: ggPageData.accessType,
# 		authorName: ggPageData.authorName,
# 		firstHistoricalCreator: ggPageData.firstHistoricalCreator,
# 		sections: ggPageData.sections,
# 		topics: ggPageData.topics,
# 		wordCounter: ggPageData.wordCounter,
# 		inlineNews: ggPageData.inlineNews,
# 		relatedNews: ggPageData.relatedNews,
# 		creationDate: ggPageData.creationDate,
# 		forcedUpdateDate: ggPageData.forcedUpdateDate,
# 		modificationDate: ggPageData.modificationDate,
# 		publicationDate: ggPageData.publicationDate,
# 		signwallDate: ggPageData.signwallDate,
# 		path: ggPageData.path,
# 		unitName: ggPageData.unitName,
# 		pageKeys: ggPageData.pageKeys,
# 		trackingId: ggPageData.trackingId,
# 	});
#
# }
#
# if (typeof ggIsApp !== 'undefined' && ggIsApp) {
# 	var callbackPopulate = function(token, populateFromApp, isNativePurchaseEnabled) {
# 		try {
# 			__evContext.isApp = true;
# 			__evContext.token = token;
# 			__evContext.isNativePurchaseEnabled = isNativePurchaseEnabled;
# 			populateFromApp = JSON.parse(populateFromApp);
# 		} catch(e) {}
# 		if (dataLayer) {
# 			if (populateFromApp && typeof populateFromApp === "object") {
# 				dataLayer.push({
# 					osVersion: populateFromApp.osVersion,
# 					kuid: populateFromApp.kuid,
# 					dt_kuid: populateFromApp.dt_kuid,
# 					userId: populateFromApp.userId
# 				});
#
# 				window["mobileUserId"] = populateFromApp.userId
# 			}
#
# 			initGtm();
#
# 			__evContext.onAuth = function(params, token, platform) {
# 				gg.accounts.evAppInitV2(params, token, platform);
# 			}
# 			__evContext.onNoConsent = function(params, opts) {
# 				gg.accounts.evAppNotConsent(params, opts);
# 			}
#
# 			registerParams();
# 			if (__evContext.token) {
# 				registerInfiniteScroll();
# 			}
#
# 		}
# 	};
#
# 	var userAgent = navigator.userAgent;
# 	try {
# 		if (/android/i.test(userAgent)){
# 			__evContext.platform = "android";
# 			appCallback.sendMessage("POPULATE");
# 		} else if (/iPad|iPhone|iPod/i.test(userAgent)){
# 			__evContext.platform = "ios";
# 			window.webkit.messageHandlers.appCallback.postMessage("POPULATE");
# 		}
# 	} catch(e) {
# 		console.log("caught exception fwdToAppPopulate"+': ' + e);
# 	}
# } else {
# 	initGtm();
#
# 	__evContext.onAuth = function(params) {
# 		gg.accounts.evInit(params);
# 	}
# 	__evContext.onNoConsent = function() {
# 		gg.accounts.evNotConsent();
# 	}
#
# 	registerParams();
# 	registerInfiniteScroll();
#
# }
# </script>
# <script type="script/gg">
# 	var userInfo = {};
# 	var userId = gg.cookie.get(gg.accounts.cookieName);
# 	if (userId)
# 		userInfo.userId = userId;
# 	userInfo.userType = gg.accounts.getUserType();
# 	userInfo.userAge = (typeof gg.accounts.getUser().getAge === 'function') ? gg.accounts.getUser().getAge() : "";
# 	userInfo.monthsFromUserRegistration = gg.accounts.getUser().registrationDate ? gg.paywall.utils.getRegisteredValue(gg.accounts.getUser().registrationDate) : "";
# 	dataLayer.push(userInfo);
#
# </script>
# <script type="script/gg">
# 	gg.qualifio.sso();
# </script>
# <script defer="" src="https://static.lavanguardia.com/assets/global.abafa04246d86a350552.js" type="text/javascript"></script>
# <script>
#     const onGGLoad = () => {
#         document.querySelectorAll('script[type=\"script/gg\"]')
#             .forEach(scr => {
#                 try {
#                     eval.call(window, scr.textContent)
#                 } catch (e) {
#                     console.error('Error running gg script', e);
#                     console.log('gg script contents:', scr.textContent);
#                 }
#             });
#             window.ggReady = true;
#             document.dispatchEvent(new CustomEvent("ggReady", {}));
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         return onGGLoad();
#     });
# </script>
# <script defer="" fetchpriority="low" src="https://rsc.lavanguardia.com/js/godo-base1x-v1000960.js"></script>
# <script defer="" fetchpriority="low" src="https://rsc.lavanguardia.com/js/accounts-v1001085.js"></script>
# <script type="script/gg">
#             console.log('start');
#             gg.breakpoint.setBreakpoints({
#                 'xs': 0,
#                 'md': 768
#             }, true);
#             gg.util.disableImageLoading();
#         </script>
# <script>
#
#     var godo = {};
#     godo.ads = [];
# </script>
# <script type="script/gg">
#     Breakpoint.init([
#         { name: 'xs', maxWidth: 767 },
#         { name: 'md', maxWidth: Infinity }
#     ]);
# </script>
# <script>
#     /* conditions to allow PiP Youtube Mini player */
#     /*ytMiniDisplayConds = window.innerWidth >= 1880 && ggPageData.mainSection.includes('cribeo', 1) || ggPageData.mainSection.includes('television', 1);*/
#     ytMiniDisplayConds = false;
# </script>
# <script type="script/gg">
#     window.lv = window.lv || {};
#     window.lv.onWallpaperAdv = function (s) {
#         if(s.displayed) {
#     	    document.querySelector("body").classList.add("wallpaper-adv-active");
#         }
#     };
# </script>
# <style>
# .supra-header-icons .shi-alerts { display:none; }
# /*Tablet fixes*/
# .main-container{
#     position: relative;
# }
# @media (min-width: 768px) and (max-width: 1023px) and (orientation: portrait) {
#     html {
#         position: absolute;
#         height: 100%;
#         overflow: hidden;
#         width:100%;
#     }
#     body {
#         -webkit-transform: scale(0.75) translateX(50%);
#         -webkit-transform-origin: top right;
#         transform: scale(0.75) translateX(50%);
#         transform-origin: top right;
#         position: absolute;
#         right: 50%;
#         top: 0;
#         width: 1024px !important;
#         height: 133vh;
#         overflow-y: auto;
#         -webkit-overflow-scrolling: touch;
#     }
#     #didomi-host {
#         position: -webkit-sticky !important;
#         position: sticky !important;
#         top: 0 !important;
#         z-index: 99 !important;
#     }
#     #didomi-notice{
#         position: absolute !important;
#         width: 1024px;
#         bottom: initial !important;
#         top: calc(133vh - 219px);
#     }
# }
# @media (min-width: 768px) and (max-width: 1024px){
#     html, body { overflow-x: hidden }
# }
#
# /* #29414 */
# /*.super-header-full-container {
#     z-index: 1 !important;
# }*/
# </style>
# <style>
#     /*FIX back effect*/
# @media (max-width: 767px) {
# 	.xk.home .article-module1x1:not(.article-module1x1-double):not(.article-module-multimedia) .article-module .image-container picture img,
# 	.xk.home .article-module2x1 .article-module .image-container picture img,
# 	.xk.home .article-module2x2 .article-module .image-container picture img,
# 	.xk.home .article-module3x1 .article-module .image-container picture img,
# 	.xk.home .article-module3x2 .article-module .image-container picture img{
# 		position: absolute;
# 		top: 0;
# 	}
#
# 	.xk.home .article-module1x1:not(.article-module1x1-double):not(.article-module-multimedia) .article-module .image-container picture,
# 	.xk.home .article-module2x1.article-module2x1-vertical.article-module2x1-vertical-small .article-module .image-container picture,
# 	.xk.home .article-module2x2.article-module-video .article-module .image-container picture,
# 	.xk.home .article-module2x2.article-module-reportaje .article-module .image-container picture,
# 	.xk.home .article-module3x2.article-module3x2-cintell:not(.article-module3x2-cintell-visual) .article-module .image-container picture{
# 		position: relative;
# 		padding-top: 49.22%;
# 		overflow: hidden;
# 	}
#
# 	.xk.home .article-module1x1.article-module-visual.module-box .article-module .image-container picture,
# 	.xk.home .article-module2x1 .article-module .image-container picture,
# 	.xk.home .article-module2x2 .article-module .image-container picture,
# 	.xk.home .article-module3x1 .article-module .image-container picture,
# 	.xk.home .article-module3x2 .article-module .image-container picture{
# ...
# <a class="share-icon fab fa-twitter" data-gtm-social-provider="twitter" href="https://twitter.com/intent/tweet?text=Feij%C3%B3o%20ofrece%20un%20cara%20a%20cara%20con%20S%C3%A1nchez%20o%20Yolanda%20D%C3%ADaz%20o%20con%20ambos&amp;url=https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html" rel="nofollow" target="_blank"></a>
# <a class="share-icon share-icon-whatsapp fab fa-whatsapp" data-gtm-social-provider="whatsapp" data-imported="" href="whatsapp://send?text=Feij%C3%B3o%20ofrece%20un%20cara%20a%20cara%20con%20S%C3%A1nchez%20o%20Yolanda%20D%C3%ADaz%20o%20con%20ambos%20https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html?utm_term=botones_sociales&amp;utm_source=whatsapp&amp;utm_medium=social" rel="nofollow" target="_blank"></a>
# </div>
# <div class="social-right">
# <a class="share-icon fa fa-comment" rel="nofollow"><span></span></a>
# </div>
# </div>
# </div>
# <div class="article-modules">
# <p class="paragraph" data-gtm-element-container="modulo-texto-link">El PP ya ha dado su respuesta al PSOE sobre los debates electorales y lo ha hecho una vez cerrado el plazo para registrar las listas para las elecciones generales del 23 de julio mediante  una carta enviada por del vicesecretario de acción institucional del PP, Esteban González Pons, al secretario de Organización del PSOE, Santos Cerdán, para transmitirle que aceptan un solo cara a cara entre Alberto Núñez Feijóo y el integrante de la coalición del Gobierno que determinen el PSOE y Sumar, entendiendo que estos serían Pedro Sánchez o Yolanda Díaz. Aunque el PP también abre la puerta a que sean ambos los que debatan con su líder.</p>
# <span class="content-ad-module hidden-ad">
# <span class="content-ad visible-xs roba-container hidden-ad"><span class="ad-unit roba">
# <ins data-ad-device="xs" data-ad-keys="{}" data-ad-lazy="false" data-ad-sizes='["fluid",[336,280],[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-xs="" data-name="roba"></ins>
# </span></span><span class="content-ad visible-md irr-container hidden-ad"><span class="ad-unit irr">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="false" data-ad-type="irr"></ins>
# </span></span><span class="content-html"><span class="intext-md hidden-xs hidden-md"></span></span></span><p class="paragraph" data-gtm-element-container="modulo-texto-link">En la misiva, los populares señalan que acceden a celebrar el cara a cara propuesto por los socialistas "tras la agobiada petición repetida por su presidente" y precisa González Pons  que dado que el Gobierno es el primero de coalición en la historia y que su vicepresidenta segunda ha manifestado públicamente su interés por participar en ese cara a cara, quedan a la espera de que las fuerzas que componen el Ejecutivo comuniquen qué persona designan para el debate.</p>
# <p class="paragraph" data-gtm-element-container="modulo-texto-link">Entienden que la propuesta sería Pedro Sánchez o Yolanda Díaz, pero añaden que "para facilitar vuestra situación interna en el seno del Gobierno" aceptarían la posibilidad de que el debate fuera "a tres" con Sánchez y con Díaz.</p>
# <p class="paragraph" data-gtm-element-container="modulo-texto-link">La idea con la que el PP se aproxima a las negociaciones de los debates electorales no contempla, en ninguno de los casos, los <a href="https://www.lavanguardia.com/politica/20230606/9020940/sanchez-reta-feijoo-seis-cara-cara-televisivos-pp-descarta-envite.html">seis cara a cara que el presidente del Gobierno ha ofrecido al PP</a>, uno por semana desde hace ya dos semanas.</p>
# <p class="paragraph" data-gtm-element-container="modulo-texto-link">Los populares plantean también un debate con los cuatro principales partidos de ámbito español (PSOE, PP, Vox y Sumar) y con aquellos que, de la mano Pedro Sánchez, se incorporaron a la “gobernabilidad del Estado” (ERC, PNV y Bildu).</p>
# <span class="content-ad-module hidden-ad">
# <span class="content-ad visible-xs irr-container hidden-ad"><span class="ad-unit irr">
# <ins data-ad-device="xs" data-ad-keys="{}" data-ad-lazy="false" data-ad-type="irr"></ins>
# </span></span><span class="content-html"><span class="intext-xs hidden-xs hidden-md"></span></span></span><span class="content-subtitle">
# <h3 class="subtitle">El PSOE ve un tono faltón en la carta</h3></span><p class="paragraph" data-gtm-element-container="modulo-texto-link">Fuentes del PSOE ya han señalado que la carta recibida "destila la misma falta de respeto y el mismo tono faltón que impregna todas las declaraciones del PP" y que no es el PP quien determina los debates sino los grupos de comunicación convocantes (RTVE, A3MEDIA, MEDIASET y PRISA) que han solicitado debates cara a cara de Sánchez con Feijóo y debates a cuatro, con las 4 formaciones de ámbito nacional. El PSOE ha aceptado todos estos debates, recuerdan. Por ello, las fuentes socialistas que ven "afán por buscar pretextos y evitar debates a toda costa" emplazan al  PP a decidir qué debates acepta y cuáles rechaza para inmediatamente negociar con ellos las cuestiones técnicas.</p>
# <span class="content-subtitle">
# <h3 class="subtitle">Sumar prefiere un debate a tres</h3></span><p class="paragraph" data-gtm-element-container="modulo-texto-link">Por su parte, fuentes de Sumar señalan que la democracia "necesita campañas electorales con debates, ideas y propuestas" y apuntan que  un debate a tres "se parece más a la España de hoy" que un debate a dos. "Vamos a hacer los debates que hagan falta", explican las fuentes que apuestan por hacer "una campaña en positivo".</p>
# <span class="content-related content-border related-list" data-gtm-element-container="modulo-noticias-relacionadas">
# <span class="module-supra-title">
# <span>Lee también</span></span>
# <ul>
# <li>
# <a href="/politica/20230620/9054869/maria-guardiola-dejar-entrar-gobierno-niegan-violencia-machista.html">María Guardiola: "No puedo dejar entrar en el gobierno a los que niegan la violencia machista"</a>
# </li>
# <li>
# <a href="/politica/20230620/9054824/gobierno-carga-feijoo-hay-divorcios-duros-justifiquen-violencia-genero.html">El Gobierno carga contra Feijóo: “No hay divorcios duros que justifiquen la violencia de género”</a>
# </li>
# <li>
# <a href="/politica/20230620/9054725/interior-grave-delito-odio-lona-vox-madrid-basura-lgtbi-trans-independentismo.html">Interior tilda de "grave" la 'lona del odio' desplegada por Vox en el centro de Madrid</a>
# </li>
# <li>
# <a href="/politica/20230620/9054459/pp-rechaza-feijoo-justificara-violencia-machista-ataques-izquierda.html">El PP rechaza que Feijóo justificara la violencia machista tras los ataques de la izquierda</a>
# </li>
# <li>
# <a href="/politica/20230620/9054389/vox-logra-presidencia-parlament-balear-candidato-define-catolico-liberal.html">Vox logra la presidencia del Parlament balear con un candidato ultracatólico y negacionista</a>
# </li>
# </ul>
# </span><span class="content-ad-module hidden-ad">
# <span class="content-ad visible-xs roba-container hidden-ad"><span class="ad-unit roba">
# <ins data-ad-device="xs" data-ad-keys="{}" data-ad-lazy="false" data-ad-sizes='["fluid",[336,280],[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-xs="" data-name="roba"></ins>
# </span></span></span><span class="content-ad-module hidden-ad">
# <span class="content-ad visible-xs roba-container hidden-ad"><span class="ad-unit roba">
# <ins data-ad-device="xs" data-ad-keys="{}" data-ad-lazy="true" data-ad-sizes='["fluid",[336,280],[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-xs="" data-name="roba"></ins>
# </span></span></span>
# </div>
# <script>
#                             var dataAdsTopics = [];
#
#                             var dataTopics = [];
#                     </script>
# <div class="spotim-open">
#                             Mostrar comentarios
#                         </div>
# <aside class="board-article-outbrain" data-gtm-element-container="modulo-outbrain-paid"><div id="taboola-below-article-thumbnails"></div></aside>
# </div>
# <aside class="article-sidebar col-12 col-md-4">
# <div class="sidebar-dynamic"><div class="board-article-sidebar">
# <aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="false" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside><aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="false" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside><aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="true" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside><aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="true" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside><aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="true" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside><aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="true" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside><aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="true" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside><aside class="module-box-ads sticky-box">
# <aside class="ads-box">
# <aside class="visible-md roba-container"><span class="ad-unit roba">
# <ins data-ad-device="md" data-ad-keys="{}" data-ad-lazy="true" data-ad-sizes='["fluid",[300,250],[300,300],[300,600],[320,300]]' data-ad-type="roba" data-event-scroll-md="" data-name="roba"></ins>
# </span></aside></aside>
# </aside>
# </div></div></aside>
# </div>
# </div>
# <div class="spotim-info" hidden="">
# <div>{"allowComment":"allowed","articleId":"article-9054163","url":"https:\/\/admin.lavanguardia.com\/view\/politica\/20230620\/9054163\/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html","livefyre-url":"article-9054163"}</div>
# </div>
# <div class="comments-modal">
# <div class="comments-inner-modal">
# <div class="md-comments" id="spotim-comments"></div>
# <div data-post-id="article-9054163" data-post-url="https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html" data-spotim-module="conversation"></div>
# </div>
# </div>
# <div class="infinite-scroll-load-new" godo-keep-empty-div="1"></div>
# </article></div>
# <div class="container infinite-loading" id="infinite-loading">Cargando siguiente contenido...
#                 </div>
# <script>
#     dataLayer.push({'activarTaboolaPosition': true});
# </script>
# </main>
# <footer>
# <div class="container">
# <nav>
# <ol class="breadcrumb text-left" itemscope="itemscope" itemtype="https://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem">
# <a href="https://www.lavanguardia.com/politica" itemprop="item">
# <span itemprop="name">Política</span>
# </a>
# <meta content="1" itemprop="position"/>
# </li>
# </ol>
# </nav>
# </div>
# <div class="footer-logo-container container">
# <div class="logo" title="La Vanguardia - Últimas noticias, actualidad y última hora en Catalunya, España y el mundo">
# <a href="https://www.lavanguardia.com/" title="La Vanguardia">
# <span class="hidden-text">La Vanguardia</span>
# </a>
# </div>
# </div>
# <div class="footer-copyright container">
# <div class="footer-copyright-module">
# <p class="footer-copyright-text">© La Vanguardia Ediciones, SLU Todos los derechos reservados.</p>
# </div>
# </div>
# <div class="footer-menu container">
# <ul class="footer-main-menu" itemscope="navigation" itemtype="https://schema.org/SiteNavigationElement">
# <li itemprop="name">
# <a href="https://www.lavanguardia.com/quienes-somos" itemprop="url" title="Quiénes somos">Quiénes somos</a>
# </li>
# <li itemprop="name">
# <a href="https://www.lavanguardia.com/contacto" itemprop="url" title="Contacto">Contacto</a>
# </li>
# <li itemprop="name">
# <a href="https://www.lavanguardia.com/avisolegal" itemprop="url" title="Aviso legal">Aviso legal</a>
# </li>
# <li itemprop="name">
# <a href="https://www.lavanguardia.com/cookies_privacy_LV_popup.html" itemprop="url" title="Política de cookies">Política de cookies</a>
# </li>
# <li itemprop="name">
# <a href="https://www.lavanguardia.com/otras-webs" itemprop="url" title="Otras webs">Otras webs del sitio</a>
# </li>
# <li itemprop="name">
# <a href="https://www.lavanguardia.com/politica-privacidad" itemprop="url" title="Política de privacidad">Política de privacidad</a>
# </li>
# <li itemprop="name">
# <a href="javascript:Didomi.preferences.show()" itemprop="url" title="Área de privacidad">Área de privacidad</a>
# </li>
# <li itemprop="name">
# <a href="https://www.lavanguardia.com/sitemap-google-news.xml" itemprop="url">Sitemap</a>
# </li>
# </ul>
# </div>
# </footer>
# <script type="script/gg">
#     godo.ads.push(function(x) {x.display("[data-ad-lazy=false]")});
# </script><!--link href="https://rsc.lavanguardia.com/css/web/generable/screens-v1000506.css?v=1170f9e943e858a9a5f1b6107a7b5ee65207303e" rel="stylesheet" /-->
# <script type="script/gg">
#     window.ggIdentity = {};
#     window.ggIdentity.profile = gg.breakpoint.getCurrent() === "md" ? "https://www.lavanguardia.com/perfil" : "https://www.lavanguardia.com/perfil/menu";
#     var ggCmd = window.ggCmd;
#     ggCmd.push(function () {
#         gg.registry.register('accounts', 'gg.accounts.init', [], {priority: 10000});
#         gg.registry.register('lv-accounts', 'lv.accounts.init', [], {priority: 10000})
#         //gg.registry.register('lv-comments', 'lv.comments.init', [], {priority: 10000})
#         //gg.registry.register('lv-comments-counter', 'lv.commentscount.init', [], {priority: 10000})
#         gg.registry.init()
#     });
#     if (typeof ggIsApp !== 'undefined' && ggIsApp){
#         window.ggIdentity.profile += "?facet=app";
#     }
#     if (typeof gg.accounts.getUser().hasActiveSubscription === 'function' && gg.accounts.getUser().hasActiveSubscription()){
#         $(".btn-subscription").attr("data-subs-href", window.ggIdentity.profile);
#         $(".btn-subscription").html("ÁREA SUSCRIPTOR")
#     } else {
#         $(".btn-subscription").attr("data-subs-href", "https://www.lavanguardia.com/suscripciones/suscribete.html?lv_fuente=lavanguardia&lv_medio=boton-suscripcion&lv_camp=captacion&lv_contenido=header")
#         $(".btn-subscription").html("SUSCRÍBETE")
#     }
# </script>
# </body>
# </html>

# %%
import json

# %%
elem_script_application_json = parsed_news_hmtl.find("script", attrs={"type": re.compile("application")})
data_from_url_json = json.loads(elem_script_application_json.get_text())
data_from_url_json
# Out:
# {'@type': 'NewsArticle',
#  '@context': 'https://schema.org',
#  'headline': 'Feijóo ofrece un cara a cara con Sánchez o Yolanda Díaz o con ambos',
#  'alternativeHeadline': 'Los populares también se abren a un debate a cuatro con presencia de Vox y Sumar',
#  'datePublished': '2023-06-20T11:10:15+0200',
#  'dateModified': '2023-06-20T15:16:07+0200',
#  'publisher': {'@type': 'Organization',
#   'id': '#organization',
#   'name': 'La Vanguardia',
#   'url': 'https://www.lavanguardia.com',
#   'logo': {'@type': 'ImageObject',
#    '@id': '#logoImage',
#    'url': 'https://www.lavanguardia.com/files/logo_microformat/bundles/lavanguardiacms/images/logo-lv.png',
#    'height': 60,
#    'width': 326},
#   'sameAs': ['https://www.facebook.com/LaVanguardia',
#    'https://www.instagram.com/lavanguardia',
#    'https://www.twitter.com/lavanguardia']},
#  'description': 'El PP ya ha dado su respuesta al PSOE sobre los debates electorales y lo ha hecho una vez cerrado el plazo para registrar las listas para las elecciones generales del 23 de julio mediante&nbsp; una carta enviada por del vicesecretario de acción institucional del PP, Esteban González Pons, al secretario de Organización del PSOE, Santos Cerdán, para transmitirle que aceptan un solo cara a cara entre Alberto Núñez Feijóo y el integrante de la coalición del Gobierno que determinen el PSOE y Sumar, entendiendo que estos serían Pedro Sánchez o Yolanda Díaz. Aunque el PP también abre la puerta a que sean ambos los que debatan con su líder.',
#  'keywords': 'pp, contempla, cara, cara, sánchez, feijóo, debate, económico, nadie, calviño',
#  'articleSection': 'Política',
#  'articleBody': 'El PP ya ha dado su respuesta al PSOE sobre los debates electorales y lo ha hecho una vez cerrado el plazo para registrar las listas para las elecciones generales del 23 de julio mediante&nbsp; una carta enviada por del vicesecretario de acción institucional del PP, Esteban González Pons, al secretario de Organización del PSOE, Santos Cerdán, para transmitirle que aceptan un solo cara a cara entre Alberto Núñez Feijóo y el integrante de la coalición del Gobierno que determinen el PSOE y Sumar, entendiendo que estos serían Pedro Sánchez o Yolanda Díaz. Aunque el PP también abre la puerta a que sean ambos los que debatan con su líder. En la misiva, los populares señalan que acceden a celebrar el cara a cara propuesto por los socialistas "tras la agobiada petición repetida por su presidente" y precisa González Pons  que dado que el Gobierno es el primero de coalición en la historia y que su vicepresidenta segunda ha manifestado públicamente su interés por participar en ese cara a cara, quedan a la espera de que las fuerzas que componen el Ejecutivo comuniquen qué persona designan para el debate. Entienden que la propuesta sería Pedro Sánchez o Yolanda Díaz, pero añaden que "para facilitar vuestra situación interna en el seno del Gobierno" aceptarían la posibilidad de que el debate fuera "a tres" con Sánchez y con Díaz. La idea con la que el PP se aproxima a las negociaciones de los debates electorales no contempla, en ninguno de los casos, los seis cara a cara que el presidente del Gobierno ha ofrecido al PP, uno por semana desde hace ya dos semanas. Los populares plantean también un debate con los cuatro principales partidos de ámbito español (PSOE, PP, Vox y Sumar) y con aquellos que, de la mano Pedro Sánchez, se incorporaron a la “gobernabilidad del Estado” (ERC, PNV y Bildu). Fuentes del PSOE ya han señalado que la carta recibida "destila la misma falta de respeto y el mismo tono faltón que impregna todas las declaraciones del PP" y que no es el PP quien determina los debates sino los grupos de comunicación convocantes (RTVE, A3MEDIA, MEDIASET y PRISA) que han solicitado debates cara a cara de Sánchez con Feijóo y debates a cuatro, con las 4 formaciones de ámbito nacional. El PSOE ha aceptado todos estos debates, recuerdan. Por ello, las fuentes socialistas que ven "afán por buscar pretextos y evitar debates a toda costa" emplazan al  PP a decidir qué debates acepta y cuáles rechaza para inmediatamente negociar con ellos las cuestiones técnicas. Por su parte, fuentes de Sumar señalan que la democracia "necesita campañas electorales con debates, ideas y propuestas" y apuntan que  un debate a tres "se parece más a la España de hoy" que un debate a dos. "Vamos a hacer los debates que hagan falta", explican las fuentes que apuestan por hacer "una campaña en positivo".',
#  'mainEntityOfPage': {'@type': 'WebPage',
#   '@id': 'https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html'},
#  'author': [{'@type': 'Person', 'name': 'Carmen del Riego', 'id': '#author'}],
#  'image': [{'@type': 'ImageObject',
#    'url': 'https://www.lavanguardia.com/files/article_main_microformat/files/fp/uploads/2023/06/18/648e31f1ab506.r_d.605-345-0.jpeg',
#    'width': 1200,
#    'height': 675,
#    'id': '#openingImage'}],
#  'video': [],
#  'audio': [],
#  'isAccessibleForFree': True,
#  'isPartOf': {'@type': ['CreativeWork', 'Product'],
#   'name': 'La Vanguardia',
#  'https://www.emagister.com/topemagister/Marketing_Digital-opc42p101t2?lavanguardia=pf-16845-widget&utm_source=lavanguardia&utm_medium=cpl&utm_campaign=widget_3&utm_content=muex_cursos_marketing_digital']

# %%
# For title
def find_attr_title(tag):
    return tag.has_attr('class') and "title" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
# For desc
def find_attr_desc(tag):
    return tag.has_attr('class') and "description" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
# For maintag
def find_attr_maintag(tag):
    return tag.has_attr('class') and "tag" in " ".join(tag.attrs["class"]) and "main" in " ".join(tag.attrs["class"])
# For author
def find_attr_author(tag):
    return tag.has_attr('class') and "author" in " ".join(tag.attrs["class"])
# For dates
def find_attr_date(tag):
    return tag.has_attr('class') and "date" in " ".join(tag.attrs["class"])
# For content
def find_attr_content(tag):
    return tag.has_attr('class') and "content" in " ".join(tag.attrs["class"])

def one_news_data_extractor(elements):
    for element in elements:
        element_title = element.find(find_attr_title)
        title = None
        desc = None
        maintag = None
        creation_date, creation_time, update_date, update_time = [None] * 4
        content = None
        if element_title and element_title.text and element_title.text.strip():
            title = element_title.text
            if not title:
                return None

        element_desc = element.find(find_attr_desc)
        if element_desc and element_desc.text and element_desc.text.strip():
            desc = element_desc.text
            if not desc:
                return None

        element_maintag = element.find(find_attr_maintag)
        if element_maintag and element_maintag.text and element_maintag.text.strip():
            maintag = element_maintag.text
            if not maintag:
                return None

        element_dates = element.find(find_attr_date)
        
        if element_dates and element_dates.text and element_dates.text.strip():
            dates = element_dates.text
            creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", author_dates)
            if not creation_date or not creation_time or not update_date or not update_time:
                return None
            
        element_content = element.find(find_attr_content)
        if element_content and element_content.text and elem.text.strip():
            content = element_content.text
            if not content:
                None
    return dict(zip(("title", "desc", "maintag", "creation_date", "creation_time", "update_date", "update_time", "content"), 
                    (title, desc, maintag, creation_date, creation_time, update_date, update_time, content)
                   ))
# For tags
def find_attr_tags(tag):
    return tag.has_attr('class') and "tags" in " ".join(tag.attrs["class"]) and "article" in " ".join(tag.attrs["class"])

# %%
complete_urls[0]
# Out:
# 'https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html'

# %%
news_media_data = {}
not_processed_urls = []

for i, news_url in enumerate(complete_urls):
    #news_url_id = news_url.replace(".html", "").split("_")[-1]
    resp_url_news = requests.get(news_url, 
                                 headers=headers)
    parsed_news_hmtl = BeautifulSoup(resp_url_news.content, 
                                     "html.parser")
    # header, footer and content
    elements_article = parsed_news_hmtl.find_all("div", 
                                                 class_=re.compile(r'article-main')
                                                )[:-1]
    if not elements_article:
        not_processed_urls.append(news_url)
        continue
    one_news_data = one_news_data_extractor(elements_article)
    one_news_data["tags"] = parsed_news_hmtl.find(find_attr_tags).get_text(separator="\n").split("\n")
    news_media_data[news_url_id] = one_news_data

# %%
resp_url_news = requests.get(complete_urls[0], 
                             headers=headers)
parsed_news_hmtl = BeautifulSoup(resp_url_news.content, 
                                 "html.parser")

# %%
def find_attr_content(tag):
    return tag.name == "div" and tag.has_attr('class') and "article-modules" in " ".join(tag.attrs["class"]) and "modules" in " ".join(tag.attrs["class"])
def find_attr_meta(tag):
    return tag.name == "div" and tag.has_attr('class') and "article-info" in " ".join(tag.attrs["class"])

# %%
content = parsed_news_hmtl.find(find_attr_content)
meta = parsed_news_hmtl.find(find_attr_meta)
len(content), len(meta)
# Out:
# (23, 5)

# %%
content = " ".join([content.text for content in content.select("p")])
print(content)
# Out:
# El PP ya ha dado su respuesta al PSOE sobre los debates electorales y lo ha hecho una vez cerrado el plazo para registrar las listas para las elecciones generales del 23 de julio mediante  una carta enviada por del vicesecretario de acción institucional del PP, Esteban González Pons, al secretario de Organización del PSOE, Santos Cerdán, para transmitirle que aceptan un solo cara a cara entre Alberto Núñez Feijóo y el integrante de la coalición del Gobierno que determinen el PSOE y Sumar, entendiendo que estos serían Pedro Sánchez o Yolanda Díaz. Aunque el PP también abre la puerta a que sean ambos los que debatan con su líder. En la misiva, los populares señalan que acceden a celebrar el cara a cara propuesto por los socialistas "tras la agobiada petición repetida por su presidente" y precisa González Pons  que dado que el Gobierno es el primero de coalición en la historia y que su vicepresidenta segunda ha manifestado públicamente su interés por participar en ese cara a cara, quedan a la espera de que las fuerzas que componen el Ejecutivo comuniquen qué persona designan para el debate. Entienden que la propuesta sería Pedro Sánchez o Yolanda Díaz, pero añaden que "para facilitar vuestra situación interna en el seno del Gobierno" aceptarían la posibilidad de que el debate fuera "a tres" con Sánchez y con Díaz. La idea con la que el PP se aproxima a las negociaciones de los debates electorales no contempla, en ninguno de los casos, los seis cara a cara que el presidente del Gobierno ha ofrecido al PP, uno por semana desde hace ya dos semanas. Los populares plantean también un debate con los cuatro principales partidos de ámbito español (PSOE, PP, Vox y Sumar) y con aquellos que, de la mano Pedro Sánchez, se incorporaron a la “gobernabilidad del Estado” (ERC, PNV y Bildu). Fuentes del PSOE ya han señalado que la carta recibida "destila la misma falta de respeto y el mismo tono faltón que impregna todas las declaraciones del PP" y que no es el PP quien determina los debates sino los grupos de comunicación convocantes (RTVE, A3MEDIA, MEDIASET y PRISA) que han solicitado debates cara a cara de Sánchez con Feijóo y debates a cuatro, con las 4 formaciones de ámbito nacional. El PSOE ha aceptado todos estos debates, recuerdan. Por ello, las fuentes socialistas que ven "afán por buscar pretextos y evitar debates a toda costa" emplazan al  PP a decidir qué debates acepta y cuáles rechaza para inmediatamente negociar con ellos las cuestiones técnicas. Por su parte, fuentes de Sumar señalan que la democracia "necesita campañas electorales con debates, ideas y propuestas" y apuntan que  un debate a tres "se parece más a la España de hoy" que un debate a dos. "Vamos a hacer los debates que hagan falta", explican las fuentes que apuestan por hacer "una campaña en positivo".

# %%
" ".join([x.get_text().strip() for x in meta.select(".author-name")])
# Out:
# 'Carmen del Riego Madrid'

# %%
print(" ".join([x.get_text().strip() for x in meta.select(".date-time")]))
# Out:
# 20/06/2023 11:10
# Actualizado a  20/06/2023 15:16

# %%
author = " ".join([x.get_text().strip() for x in meta.select(".author-name")])
date_time = " ".join([x.get_text().strip() for x in meta.select(".date-time")])
print(meta)
# Out:
# <div class="article-info">
# <div class="author-date-content">
# <figure class="author-image" style="display: block;">
# <img alt="Feijóo ofrece un cara a cara con Sánchez o Yolanda Díaz o con ambos" class="lazy" data-src="/files/image_40_40/uploads/1970/01/01/5f9ad9d675386.jpeg" height="40" src="..." title="" width="40"/>
# </figure>
# <div class="author-date-time">
# <div class="author-name" data-gtm-element-container="author">
# <p><a href="/autores/maricarmen-delriego.html">Carmen del Riego</a></p>
# </div>
# <div class="author-name">
# <p>Madrid</p>
# </div>
# <div class="date-time">
# <time class="created" datetime="2023-06-20T11:10:15+02:00">20/06/2023 11:10</time>
# <time class="modified" datetime="2023-06-20T15:16:07+02:00">Actualizado a  20/06/2023 15:16</time>
# </div>
# </div>
# </div>
# <div class="social-buttons social-share" data-gtm-element="leaf-social-share-top">
# <div class="social-left">
# <a class="share-icon fab fa-facebook-f" data-gtm-social-provider="facebook" href="https://www.facebook.com/sharer/sharer.php?u=https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html" rel="nofollow" target="_blank"></a>
# <a class="share-icon fab fa-twitter" data-gtm-social-provider="twitter" href="https://twitter.com/intent/tweet?text=Feij%C3%B3o%20ofrece%20un%20cara%20a%20cara%20con%20S%C3%A1nchez%20o%20Yolanda%20D%C3%ADaz%20o%20con%20ambos&amp;url=https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html" rel="nofollow" target="_blank"></a>
# <a class="share-icon share-icon-whatsapp fab fa-whatsapp" data-gtm-social-provider="whatsapp" data-imported="" href="whatsapp://send?text=Feij%C3%B3o%20ofrece%20un%20cara%20a%20cara%20con%20S%C3%A1nchez%20o%20Yolanda%20D%C3%ADaz%20o%20con%20ambos%20https://www.lavanguardia.com/politica/20230620/9054163/pp-contempla-cara-cara-sanchez-feijoo-debate-economico-nadie-calvino.html?utm_term=botones_sociales&amp;utm_source=whatsapp&amp;utm_medium=social" rel="nofollow" target="_blank"></a>
# </div>
# <div class="social-right">
# <a class="share-icon fa fa-comment" rel="nofollow"><span></span></a>
# </div>
# </div>
# </div>

# %% [markdown]
# ## Okdiario

# %%
def find_attr_article(tag):
    return tag.name == "article"

# %%
def one_news_data_extractor(elements):
    for element in elements:
        element_title = element.find(find_attr_title)
        title = None
        desc = None
        maintag = None
        creation_date, creation_time, update_date, update_time = [None] * 4
        content = None
        if element_title and element_title.text and element_title.text.strip():
            title = element_title.text
            if not title:
                return None

        element_desc = element.find(find_attr_desc)
        if element_desc and element_desc.text and element_desc.text.strip():
            desc = element_desc.text
            if not desc:
                return None

        element_maintag = element.find(find_attr_maintag)
        if element_maintag and element_maintag.text and element_maintag.text.strip():
            maintag = element_maintag.text
            if not maintag:
                return None

        element_dates = element.find(find_attr_date)
        
        if element_dates and element_dates.text and element_dates.text.strip():
            dates = element_dates.text
            creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", author_dates)
            if not creation_date or not creation_time or not update_date or not update_time:
                return None
            
        element_content = element.find(find_attr_content)
        if element_content and element_content.text and elem.text.strip():
            content = element_content.text
            if not content:
                None
    return dict(zip(("title", "desc", "maintag", "creation_date", "creation_time", "update_date", "update_time", "content"), 
                    (title, desc, maintag, creation_date, creation_time, update_date, update_time, content)
                   ))

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}

url = "https://okdiario.com/"
main_root = "https://okdiario.com/"
date = current_date.replace("-", "")
# With headers
response = requests.get(url, headers=headers)
print("Response code:", response.status_code)  # HTTP status code

parsed_hmtl = BeautifulSoup(response.content, "html.parser")
articles = parsed_hmtl.find_all(find_attr_article)

raw_urls = [article.find("a").attrs["href"] for article in articles]
complete_urls = []
rejected_urls = []
for raw_url in raw_urls:
    if not re.search(r"-[0-9]+$", raw_url):
        rejected_urls.append(raw_url)
        continue
    if raw_url.startswith("/"):
        raw_url = main_root + raw_url
    elif main_root not in raw_url:
        rejected_urls.append(raw_url)
        continue
    complete_urls.append(raw_url)
complete_urls = list(set(complete_urls))
# Out:
# Response code: 200

# %%
len(complete_urls), len(rejected_urls)
# Out:
# (187, 0)

# %%
complete_urls
# Out:
# ['https://okdiario.com/lista/10-peliculas-terror-netflix-que-no-te-puedes-perder-4741644',
#  'https://okdiario.com/curiosidades/increible-historia-este-impresionante-valle-mas-bonito-del-mundo-solo-puede-acceder-unica-forma-11142802',
#  'https://okdiario.com/happyfm/hermanos-final-explicado-temporada-2-11131031',
#  'https://okdiario.com/bebes/como-prevenir-ahogamiento-ninos-agua-consejos-playa-piscina-11087381',
#  'https://okdiario.com/espana/feijoo-impulsara-nuevo-permiso-paternidad-4-meses-hasta-que-hijo-cumpla-8-anos-11150834',
#  'https://okdiario.com/tecnologia/peligroso-inquietante-modo-abuela-llega-chatgpt-no-deberias-utilizarlo-11150761',
#  'https://okdiario.com/happyfm/adele-confiesa-problema-salud-uso-continuado-esta-prenda-conciertos-11129856',
#  'https://okdiario.com/deportes/marc-marquez-no-correra-gran-premio-assen-lesion-11150383',
#  'https://okdiario.com/happyfm/rosalia-desnudo-que-querido-compartir-curiosa-reflexion-11130808',
#  'https://okdiario.com/deportes/ilia-topuria-gana-josh-emmett-entra-top-5-ufc-11149363',
#  'https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708',
#  'https://okdiario.com/madrid/buenisimas-noticias-esto-va-costar-abono-transporte-madrid-partir-ahora-11150368',
#  'https://okdiario.com/salud/dr-cidon-ayuno-no-sinonimo-hambre-o-inanicion-sino-forma-vida-salud-11142532',
#  'https://okdiario.com/coolthelifestyle/lifestyle/duenos-del-grand-tremezzo-abren-maravilloso-hotel-lago-di-como-527079',
#  'https://okdiario.com/deportes/consulta-calendario-completo-liga-2023-24-11136908',
#  'https://okdiario.com/mascotas/razones-que-perro-muerde-correa-6175394',
#  'https://okdiario.com/trailer/todo-lo-que-sabe-sobre-serie-harry-potter-hbo-11148072',
#  'https://okdiario.com/actualidad/operar-malformacion-del-pecho-hundido-ninos-tecnologia-3d-clave-elevar-calidad-vida-11092291',
#  'https://okdiario.com/elecciones/sorteo-mesa-electoral-cuando-como-saber-si-tocado-10888732',
#  'https://okdiario.com/sociedad/albert-rivera-habla-lo-que-esta-pasando-malu-creo-que-ya-esta-claro-11149464',
#  'https://okdiario.com/howto/como-cambiar-hotmail-outlook-3560723',
#  'https://okdiario.com/actualidad/retotech-proyecto-fundacion-endesa-que-despierta-vocaciones-stem-ninos-11099931',
#  'https://okdiario.com/okshopping/este-protector-solar-bella-aurora-factor-50-nutre-tu-piel-esta-rebajado-casi-30-11143194',
#  'https://okdiario.com/sociedad/peligro-espana-ciclones-tropicales-experto-que-alerta-posible-llegada-huracanes-11150639',
#  'https://okdiario.com/economia/seguridad-social-obligada-pagar-victima-violencia-genero-prestacion-familiares-11145146',
#  'https://okdiario.com/okclub/quitate-calor-del-verano-pack-6-botellas-pago-marinacea-verdejo-ser-socio-okclub-11142906',
#  'https://okdiario.com/look/estilo/5-vestidos-irresistibles-rebajas-zara-menos-20-euros-1757374',
#  'https://okdiario.com/curiosidades/quienes-eran-celtas-principales-caracteristicas-534391',
#  'https://okdiario.com/elecciones/cuando-avisan-si-tengo-que-estar-mesa-electoral-elecciones-generales-del-23j-11137306',
#  'https://okdiario.com/coolthelifestyle/lifestyle/ruta-del-gazpacho-autor-madrid-519998',
#  'https://okdiario.com/internacional/rusia-repara-danos-del-golpe-wagner-levanta-todas-restricciones-11150948',
#  'https://okdiario.com/okshopping/presume-estilo-comodidad-estas-zapatillas-nike-air-jordan-mitad-precio-11138672',
#  'https://okdiario.com/howto/como-configurar-botones-del-raton-windows-10-2278129',
#  'https://okdiario.com/happyfm/secretos-familia-avance-del-capitulo-hoy-ceylin-punto-mira-del-asesino-11136844',
#  'https://okdiario.com/howto/otros-usos-plancha-que-desconoces-11139471',
#  'https://okdiario.com/lista/10-mejores-libros-poemas-4614973',
#  'https://okdiario.com/historia/como-eran-tecnicas-secretas-ninjas-11121291',
#  'https://okdiario.com/lista/10-personajes-animacion-mas-famosos-historia-4502960',
#  'https://okdiario.com/economia/viajeros-iberia-seguimiento-maleta-verano-11144171',
#  'https://okdiario.com/elecciones/documentos-que-debes-presentar-tu-trabajo-si-te-tocado-ser-mesa-electoral-11142412',
#  'https://okdiario.com/trailer/comedia-del-momento-partirte-risa-esta-hbo-tiene-dos-temporadas-episodios-muy-cortos-11150371',
#  'https://okdiario.com/recetas/brochetas-salmon-melon-plancha-salsa-champan-11121489',
#  'https://okdiario.com/historia/cual-fue-origen-del-ciclismo-11121129',
#  'https://okdiario.com/educacion/como-escribe-raya-o-ralla-4262422',
#  'https://okdiario.com/trailer/psicosis-nacimiento-del-miedo-spoiler-11128272',
#  'https://okdiario.com/lista/10-libros-mas-vendidos-historia-4490634',
#  'https://okdiario.com/look/estilo/fichamos-10-bikinis-que-van-arrasar-rebajas-oysho-1757381',
#  'https://okdiario.com/mascotas/5-olores-que-mas-odian-perros-11150624',
#  'https://okdiario.com/espana/activistas-extrema-izquierda-manchan-pintura-lona-vox-11150907',
#  'https://okdiario.com/andalucia/juicio-mujer-pagar-1-000-sicario-que-asesine-marido-que-recibio-30-punaladas-11150603',
#  'https://okdiario.com/tecnologia/acabo-ponerle-funda-tu-movil-revolucion-llegado-tu-iphone-11142147',
#  'https://okdiario.com/sociedad/gran-cambio-exmujer-dabiz-munoz-historia-amor-fue-comienzo-todo-11147644',
#  'https://okdiario.com/motor/asi-ligier-myli-microcoche-electrico-que-puedes-conducir-sin-carnet-11124698',
#  'https://okdiario.com/sociedad/oportunidades-empleo-que-llegan-bus-hasta-puerta-casa-11007886',
#  'https://okdiario.com/mascotas/estas-son-enfermedades-piel-mas-frecuentes-gatos-6887625',
#  'https://okdiario.com/educacion/como-escribe-cayendo-o-callendo-4479983',
#  'https://okdiario.com/andalucia/montero-obvia-paliza-electoral-juanma-moreno-psoe-ere-ganaremos-andalucia-23j-11148894',
#  'https://okdiario.com/loteria/once-comprobar-resultado-hoy-24-junio-2023-11149381',
#  'https://okdiario.com/loteria/once-comprobar-resultado-hoy-23-junio-2023-11145584',
#  'https://okdiario.com/madrid/tirolina-piragua-sierra-guadarrama-comunidad-madrid-11105908',
#  'https://okdiario.com/loteria/bonoloto-comprobar-resultado-hoy-23-junio-2023-11145581',
#  'https://okdiario.com/tecnologia/llega-mayor-cambio-historia-whatsapp-podras-tener-dos-cuentas-mismo-movil-11126343',
#  'https://okdiario.com/actualidad/bonito-menu-pescado-chalana-marisqueria-11124941',
#  'https://okdiario.com/internacional/rusia-pacta-prigozhin-que-no-procesara-deja-que-vaya-bielorrusia-frenar-golpe-11149924',
#  'https://okdiario.com/economia/precio-luz-cae-este-domingo-12-costara-cero-euros-mwh-1500-1600-horas-11149292',
#  'https://okdiario.com/mascotas/caracteristicas-cuidados-del-perro-labrador-5454864',
#  'https://okdiario.com/baleares/cinco-detenidos-palma-agredir-hombre-reunirse-compraventa-solar-11150536',
#  'https://okdiario.com/loteria/primitiva-comprobar-resultado-hoy-24-junio-2023-11149389',
#  'https://okdiario.com/salud/hospital-juaneda-ciutadella-mejor-equipo-profesional-ultima-tecnologia-menorca-10862466',
#  'https://okdiario.com/trailer/obras-maestras-que-desapareceran-dentro-poco-del-catalogo-hbo-max-11122066',
#  'https://okdiario.com/sociedad/jamas-lo-hubieras-imaginado-multa-mas-absurda-que-te-pueden-poner-11150389',
#  'https://okdiario.com/educacion/universidades-privadas-acogen-35-estudiantes-extranjeros-que-estudian-espana-11140408',
#  'https://okdiario.com/espana/ferraz-preve-relevar-vara-si-hay-elecciones-que-no-lidere-rebelion-contra-sanchez-11142254',
#  'https://okdiario.com/curiosidades/impresionante-paraje-escondido-espana-aguas-turquesas-cascadas-11150443',
#  'https://okdiario.com/motor/museo-alfa-romeo-cita-imprescindible-amantes-historia-del-motor-11146059',
#  'https://okdiario.com/sociedad/secreto-hija-carlos-herrera-confiesa-verdad-sobre-apellido-11147762',
#  'https://okdiario.com/okgreen/verdaderos-datos-sobre-emisiones-co2-11060418',
#  'https://okdiario.com/baleares/joven-que-buscaba-robo-bolso-mujer-edad-avanzada-palma-aparece-muerto-11150428',
#  'https://okdiario.com/mascotas/este-animal-que-esta-practicamente-extinguido-segun-estudio-11148079',
#  'https://okdiario.com/diariomadridista/cantera/ya-viral-hijo-marcelo-imita-cristiano-graduacion-341807',
#  'https://okdiario.com/tecnologia/acabo-comprarte-otro-movil-ya-puedes-reparar-tus-moviles-ti-mismo-espana-11141918',
#  'https://okdiario.com/ok-vs-ko/ok-ko-del-domingo-25-junio-2023-11149848',
#  'https://okdiario.com/deportes/achraf-siguiente-deseo-guardiola-11149493',
#  'https://okdiario.com/economia/estas-son-ciudades-que-aspiran-formar-parte-del-parque-eolica-marina-repsol-espana-11144221',
#  'https://okdiario.com/deportes/sergio-ramos-apoyo-topuria-historica-victoria-ufc-11150043',
#  'https://okdiario.com/economia/airbus-supera-boeing-aviones-construidos-enero-mayo-244-aeronaves-creadas-11150636',
#  'https://okdiario.com/diariomadridista/cantera/hora-generacion-raul-341774',
#  'https://okdiario.com/trailer/drama-hbo-que-no-te-dejara-despegarte-pantalla-dura-casi-dos-horas-nos-encanta-11148517',
#  'https://okdiario.com/ciencia/ventajas-energia-geotermica-11120536',
#  'https://okdiario.com/deportes/superliga-unica-salida-frenar-arabia-saudi-11146316',
#  'https://okdiario.com/sociedad/llega-infierno-44o-aemet-lanza-comunicado-mas-aterrador-proximos-dias-11150568',
#  'https://okdiario.com/diariomadridista/cantera/encerrona-que-espera-castilla-nuevo-pepico-amat-elda-341682',
#  'https://okdiario.com/tecnologia/plan-amazon-disfrutar-verano-musical-0-11135708',
#  'https://okdiario.com/historia/origen-nba-como-comenzo-todo-11123158',
#  'https://okdiario.com/economia/hacienda-te-cuela-supermercados-nuevo-impuesto-tendras-que-pagar-mas-partir-ahora-11148751',
#  'https://okdiario.com/opinion/que-alguien-pare-guardiola-11150201',
#  'https://okdiario.com/opinion/alegato-antonio-banderas-11146413',
#  'https://okdiario.com/bebes/rebajas-zara-nino-verano-2018-2742564',
#  'https://okdiario.com/bebes/como-distraer-ninos-verano-consejos-practicos-11064117']

# %%
rejected_urls
# Out:
# []

# %%
def find_tag_article(tag):
    return tag.name == "article" and tag.has_attr('class') and "post-" in " ".join(tag.attrs["class"])
def find_attr_title(tag):
    return tag.has_attr('class') and "entry-title" in " ".join(tag.attrs["class"])
def find_attr_content(tag):
    return tag.has_attr('class') and "content" in " ".join(tag.attrs["class"])
def find_attr_author(tag):
    return tag.has_attr('class') and "autor" in " ".join(tag.attrs["class"])
def find_attr_topics(tag):
    return tag.has_attr('class') and "topics" in " ".join(tag.attrs["class"])

# %%
 parsed_news_hmtl
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708/amp" rel="amphtml"/>
# <title>El descomunal avance del Bernabéu en su tercera semana sin fútbol</title>
# <meta content="Estamos a punto de cumplir tres semanas sin fútbol en el Santiago Bernabéu desde que finalizase la temporada y las obras van a gran ritmo." name="description">
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
# <link href="https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" rel="canonical">
# <meta content="es_ES" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="El descomunal avance del Bernabéu en su tercera semana sin fútbol" property="og:title"/>
# <meta content="Estamos a punto de cumplir tres semanas sin fútbol en el Santiago Bernabéu desde que finalizase la temporada y las obras van a gran ritmo." property="og:description"/>
# <meta content="https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" property="og:url"/>
# <meta content="DiarioMadridista.com" property="og:site_name"/>
# <meta content="https://www.facebook.com/diariomadridista/" property="article:publisher"/>
# <meta content="2023-06-24T15:48:43+00:00" property="article:published_time"/>
# <meta content="https://okdiario.com/diariomadridista/img/2023/06/24/banon-video.jpg" property="og:image"/>
# <meta content="1800" property="og:image:width"/>
# <meta content="1013" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://okdiario.com/diariomadridista/img/2023/06/24/banon-video.jpg" name="twitter:image"/>
# <meta content="@dmadridistaok" name="twitter:creator"/>
# <meta content="@dmadridistaok" name="twitter:site"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <meta content="Estadio Santiago Bernabéu, Florentino Pérez, Real Madrid" name="news_keywords"/><link href="https://okdiario.com/diariomadridista/wp-includes/css/dist/block-library/style.min.css" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <meta content="548410225335752" property="fb:pages"><script type="application/ld+json">{"@context":"https://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708"},"headline":"El descomunal avance del Bernabéu en su tercera semana sin fútbol","image":{"@type":"ImageObject","url":"https://okdiario.com/diariomadridista/img/2023/06/24/banon.jpg","width":1800,"height":1013},"datePublished":"2023-06-24T17:48:43+02:00","publisher":{"@type":"Organization","name":"DiarioMadridista.com","logo":{"@type":"ImageObject","url":"https://okdiario.com/diariomadridista/web/themes/v10/css/_img/logo-dm-600x236.png","width":600,"height":236}},"author":{"@type":"Person","name":"Eduardo Bañón","url":"https://okdiario.com/diariomadridista/autor/eduardo-banon/"},"articleBody":"Estamos a punto de cumplir tres semanas sin fútbol en el Santiago Bernabéu desde que finalizase la temporada, y la verdad es que desde entonces el estadio está experimentando un sinfín de cambios. Las actuaciones son continuas tanto en los exteriores como en el interior de un Bernabéu que muestra un estado irreconocible.Por eso, un día más, nuestro experto en el seguimiento de las obras de remodelación del Santiago Bernabéu, Eduardo Bañón del canal de Youtube Fanáticos Real Madrid, nos cuenta de primera mano cuales han sido los grandes cambios que se han ido logrando en el coliseo blanco.En los exteriores del Santiago Bernabéu los trabajos se centran principalmente en el fondo Norte donde las nuevas puertas de acceso y evacuación se van extendiendo a lo largo de la fachada. En el fondo Sur comenzamos a ver los primeros trabajos relacionados con las nuevas puertas de manera tímida en el entorno del acceso a la tienda oficial del club. Estos no son, ni mucho menos, los únicos trabajos que se pueden ver en el estadio desde la calle.En el lateral de Castellana se apresuran para terminar de cubrir la viga museo (que abrirá sus puertas al público el 1 de julio según publica en su web el Real Madrid) y además se ha comenzado ya con la instalación de las lamas que cierran la parte baja de la piel envolvente en la zona de Paseo de la Castellana.Si accedemos al interior del estadio la obra nos deja con la boca abierta. Mires donde mires ves a cuadrillas de obreros trabajando a destajo. La mayor cantidad de trabajos está enfocada a la habilitación de las gradas de cara a la próxima temporada: reconstrucción de la grada del fondo Sur, el palco de honor, modificaciones en el primer anfiteatro, palcos VIP y la tribuna inferior del lateral Oeste están siendo objeto de manera simultánea de un sinfín de actividades para posibilitar la instalación de los nuevos asientos.Mientras tanto, en las alturas del estadio, se avanza a muy buen ritmo con la instalación de las lonas de la cubierta retráctil y las conexiones de las secciones de la estructura del videomarcador 360º en el fondo Norte. El Bernabéu ya toma velocidad de crucero de cara a su modificación más extrema de aquí a septiembre.","articleSection":{"@list":["Real Madrid"]},"dateModified":"2023-06-24T17:48:43+02:00","keywords":"Estadio Santiago Bernabéu, Florentino Pérez, Real Madrid","video":{"@context":"http://schema.org","@type":"VideoObject","name":"El descomunal avance del Bernabéu en su tercera semana sin fútbol","description":"Estamos a punto de cumplir tres semanas sin fútbol en el Santiago Bernabéu desde que finalizase la temporada y las obras van a gran ritmo.","thumbnailUrl":"https://okdiario.com/diariomadridista/img/2023/06/24/banon.jpg","uploadDate":"2023-06-24T17:48:43+02:00","embedUrl":"https://www.dailymotion.com/embed/video/x8m0ocq?syndication=273778","publisher":{"@type":"Organization","name":"DiarioMadridista.com","logo":{"@type":"ImageObject","url":"https://okdiario.com/diariomadridista/web/themes/v10/css/_img/logo-dm-600x236.png","width":600,"height":236}}},"description":"","alternati ...
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WQ3PQHT');
# </script>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="/diariomadridista/img/i/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/diariomadridista/img/i/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/diariomadridista/img/i/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/diariomadridista/img/i/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/diariomadridista/img/i/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/diariomadridista/img/i/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/diariomadridista/img/i/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/diariomadridista/img/i/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/diariomadridista/img/i/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/diariomadridista/img/i/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/diariomadridista/img/i/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/diariomadridista/img/i/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/diariomadridista/img/i/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/diariomadridista/img/i/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="Real Madrid" property="article:section"/>
# <script src="https://contributor.google.com/scripts/6baf8400b4b60141/loader.js"></script><script>(function(){'use strict';var f=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}},l=this,m=/^[\w+/_-]+[=]{0,2}$/,n=null,q=function(){},r=function(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";
#     if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==b&&"undefined"==typeof a.call)return"object";return b},t=Date.now||function(){return+new Date},u=function(a,b){function c(){}c.prototype=b.prototype;a.m=b.prototype;a.prototype=new c;a.prototype.constructor=a;a.j=function(a,c,g){for(var d=Array(arguments.length-2),e=2;e<arguments.length;e++)d[e-2]=arguments[e];return b.prototype[c].apply(a,
#     d)}};var v=function(a,b){Object.defineProperty(l,a,{configurable:!1,get:function(){return b},set:q})};var w=function(){return Math.floor(2147483648*Math.random()).toString(36)+Math.abs(Math.floor(2147483648*Math.random())^t()).toString(36)};var y=function(){this.a="";this.b=x},x={},z=function(a){var b=new y;b.a=a;return b};var A=function(a,b){a.src=b instanceof y&&b.constructor===y&&b.b===x?b.a:"type_error:TrustedResourceUrl";if(null===n)b:{b=l.document;if((b=b.querySelector&&b.querySelector("script[nonce]"))&&(b=b.nonce||b.getAttribute("nonce"))&&m.test(b)){n=b;break b}n=""}b=n;b&&a.setAttribute("nonce",b)};var B=function(a){this.a=a||l.document||document};B.prototype.appendChild=function(a,b){a.appendChild(b)};var C=function(a,b,c,d,e,g){try{var h=a.a,k=a.a.createElement("SCRIPT");k.async=!0;A(k,b);h.head.appendChild(k);k.addEventListener("load",function(){e();d&&h.head.removeChild(k)});k.addEventListener("error",function(){0<c?C(a,b,c-1,d,e,g):(d&&h.head.removeChild(k),g())})}catch(p){g()}};var D=l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"),E=l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="),aa=l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"),ba=function(a,b,c){this.b=a;this.f=new B(this.b);this.a=null;this.c=[];this.g=!1;this.i=b;this.h=c},H=function(a){if(a.b.body&&!a.g){var b=
#     function(){F(a);l.setTimeout(function(){return G(a,3)},50)};C(a.f,a.i,2,!0,function(){l[a.h]||b()},b);a.g=!0}},F=function(a){for(var b=I(1,5),c=0;c<b;c++){var d=J(a);a.b.body.appendChild(d);a.c.push(d)}b=J(a);b.style.bottom="0";b.style.left="0";b.style.position="fixed";b.style.width=I(100,110).toString()+"%";b.style.zIndex=I(2147483544,2147483644).toString();b.style["background-color"]=K(249,259,242,252,219,229);b.style["box-shadow"]="0 0 12px #888";b.style.color=K(0,10,0,10,0,10);b.style.display=
#     "flex";b.style["justify-content"]="center";b.style["font-family"]="Roboto, Arial";c=J(a);c.style.width=I(80,85).toString()+"%";c.style.maxWidth=I(750,775).toString()+"px";c.style.margin="24px";c.style.display="flex";c.style["align-items"]="flex-start";c.style["justify-content"]="center";d=a.f.a.createElement("IMG");d.className=w();d.src=D;d.style.height="24px";d.style.width="24px";d.style["padding-right"]="16px";var e=J(a),g=J(a);g.style["font-weight"]="bold";g.textContent=E;var h=J(a);h.textContent=
#     aa;L(a,e,g);L(a,e,h);L(a,c,d);L(a,c,e);L(a,b,c);a.a=b;a.b.body.appendChild(a.a);b=I(1,5);for(c=0;c<b;c++)d=J(a),a.b.body.appendChild(d),a.c.push(d)},L=function(a,b,c){for(var d=I(1,5),e=0;e<d;e++){var g=J(a);b.appendChild(g)}b.appendChild(c);c=I(1,5);for(d=0;d<c;d++)e=J(a),b.appendChild(e)},I=function(a,b){return Math.floor(a+Math.random()*(b-a))},K=function(a,b,c,d,e,g){return"rgb("+I(Math.max(a,0),Math.min(b,255)).toString()+","+I(Math.max(c,0),Math.min(d,255)).toString()+","+I(Math.max(e,0),Math.min(g,
#     255)).toString()+")"},J=function(a){a=a.f.a.createElement("DIV");a.className=w();return a},G=function(a,b){0>=b||null!=a.a&&0!=a.a.offsetHeight&&0!=a.a.offsetWidth||(ca(a),F(a),l.setTimeout(function(){return G(a,b-1)},50))},ca=function(a){var b=a.c;var c="undefined"!=typeof Symbol&&Symbol.iterator&&b[Symbol.iterator];b=c?c.call(b):{next:f(b)};for(c=b.next();!c.done;c=b.next())(c=c.value)&&c.parentNode&&c.parentNode.removeChild(c);a.c=[];(b=a.a)&&b.parentNode&&b.parentNode.removeChild(b);a.a=null};var M=function(a,b,c){a=l.btoa(a+b);v(a,c)},da=function(a,b,c){for(var d=[],e=2;e<arguments.length;++e)d[e-2]=arguments[e];e=l.btoa(a+b);e=l[e];if("function"==r(e))e.apply(null,d);else throw Error("API not exported.");};var fa=function(a,b,c,d,e){var g=ea(c),h=function(c){c.appendChild(g);l.setTimeout(function(){g?(0!==g.offsetHeight&&0!==g.offsetWidth?b():a(),g.parentNode&&g.parentNode.removeChild(g)):a()},d)},k=function(a){document.body?h(document.body):0<a?l.setTimeout(function(){k(a-1)},e):b()};k(3)},ea=function(a){var b=document.createElement("div");b.className=a;b.style.width="1px";b.style.height="1px";b.style.position="absolute";b.style.left="-10000px";b.style.top="-10000px";b.style.zIndex="-10000";return b};var N=null;var O=function(){},P="function"==typeof Uint8Array,Q=function(a,b){a.b=null;b||(b=[]);a.l=void 0;a.f=-1;a.a=b;a:{if(b=a.a.length){--b;var c=a.a[b];if(!(null===c||"object"!=typeof c||"array"==r(c)||P&&c instanceof Uint8Array)){a.g=b-a.f;a.c=c;break a}}a.g=Number.MAX_VALUE}a.i={}},R=[],S=function(a,b){if(b<a.g){b+=a.f;var c=a.a[b];return c===R?a.a[b]=[]:c}if(a.c)return c=a.c[b],c===R?a.c[b]=[]:c},U=function(a,b){var c=T;a.b||(a.b={});if(!a.b[b]){var d=S(a,b);d&&(a.b[b]=new c(d))}return a.b[b]};
#     O.prototype.h=P?function(){var a=Uint8Array.prototype.toJSON;Uint8Array.prototype.toJSON=function(){if(!N){N={};for(var a=0;65>a;a++)N[a]="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/=".charAt(a)}a=N;for(var c=[],d=0;d<this.length;d+=3){var e=this[d],g=d+1<this.length,h=g?this[d+1]:0,k=d+2<this.length,p=k?this[d+2]:0,ha=e>>2;e=(e&3)<<4|h>>4;h=(h&15)<<2|p>>6;p&=63;k||(p=64,g||(h=64));c.push(a[ha],a[e],a[h],a[p])}return c.join("")};try{return JSON.stringify(this.a&&this.a,V)}finally{Uint8Array.prototype.toJSON=
#     a}}:function(){return JSON.stringify(this.a&&this.a,V)};var V=function(a,b){return"number"!=typeof b||!isNaN(b)&&Infinity!==b&&-Infinity!==b?b:String(b)};O.prototype.toString=function(){return this.a.toString()};var T=function(a){Q(this,a)};u(T,O);var W=function(a){Q(this,a)};u(W,O);var ia=function(a,b){this.g=new B(a);var c=U(b,11);c=z(S(c,4)||"");this.b=new ba(a,c,S(b,10));this.a=b;this.f=S(this.a,1);this.c=!1},X=function(a,b,c,d){b=new T(b?JSON.parse(b):null);b=z(S(b,4)||"");C(a.g,b,3,!1,c,function(){fa(function(){H(a.b);d(!1)},function(){d(!0)},S(a.a,12),S(a.a,5),S(a.a,3))})},ja=function(a){a.c||(M(a.f,"internal_api_load_with_sb",function(b,c,d){X(a,b,c,d)}),M(a.f,"internal_api_sb",function(){H(a.b)}),a.c=!0)};var Y=function(a){this.h=l.document;this.a=new ia(this.h,a);this.f=S(a,1);this.g=U(a,2);this.c=!1;this.b=a};Y.prototype.start=function(){try{ka(),ja(this.a),l.googlefc=l.googlefc||{},"callbackQueue"in l.googlefc||(l.googlefc.callbackQueue=[]),la(this)}catch(a){H(this.a.b)}};
#     var ka=function(){var a=function(){if(!l.frames.googlefcPresent)if(document.body){var b=document.createElement("iframe");b.style.display="none";b.style.width="0px";b.style.height="0px";b.style.border="none";b.style.zIndex="-1000";b.style.left="-1000px";b.style.top="-1000px";b.name="googlefcPresent";document.body.appendChild(b)}else l.setTimeout(a,5)};a()},la=function(a){var b=t();X(a.a,a.g.h(),function(){var c=l.btoa(a.f+"cached_js");(c=l[c])?(c=l.atob(c),c=3E5>Math.abs(b-parseInt(c,10))):c=!1;c||
#     (da(a.f,"internal_api_sb"),Z(a,S(a.b,9)))},function(b){b?Z(a,S(a.b,7)):Z(a,S(a.b,8))})},Z=function(a,b){a.c||(a.c=!0,a=new l.XMLHttpRequest,a.open("GET",b,!0),a.send())};(function(a,b){l[a]=function(c){for(var d=[],e=0;e<arguments.length;++e)d[e-0]=arguments[e];l[a]=q;b.apply(null,d)}})("__475an521in8a__",function(a){"function"==typeof l.atob&&(a=l.atob(a),a=new W(a?JSON.parse(a):null),(new Y(a)).start())});}).call(this);
#     window.__475an521in8a__("...");</script>
# <script src="https://okdiario.com/diariomadridista/web/themes/v10/js/jquery-2.2.2.min.js?ver=2.2.2" type="text/javascript"></script>
# <link href="https://okdiario.com/feed" rel="alternate" title="Feed RSS de noticias nacionales e internacionales en OKDIARIO" type="application/rss+xml">
# <link href="https://okdiario.com/diariomadridista/web/themes/v10/css/okdiario-v1.css?v=1678272688" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.5.0/css/font-awesome.min.css" rel="stylesheet"/>
# <script type="text/javascript">
#     var gfkSettingsDg = {
#         "log": "none", //"none"
#         "production": true,
#         "c1": "okdiario.com",
#         "c2": "diariomadridista"
#     }
# </script>
# <script src="https://okdiario.com/diariomadridista/web/themes/v10/lib/cmp.js?v=1678272688" type="text/javascript"></script>
# <script src="https://okdiario.com/diariomadridista/web/themes/v10/lib/analytics-4.js?v=1678272688" type="text/javascript"></script>
# <!--[if lt IE 9]>
# <script type='text/javascript' src='https://okdiario.com/diariomadridista/web/themes/v10/js/html5.js?ver=3.7.3'></script>
# <![endif]-->
# <script type="text/javascript">
# window.didomiOnReady = window.didomiOnReady || [];
# window.didomiOnReady.push(function (Didomi) {
#  // Check user consent
#  var comScoreConsent = false;
#  var isComscoreConsentPresent = Didomi.getUserConsentStatusForVendor(77);
#
#  // Embed ComScore
#  window._comscore = window._comscore || [];
#
#   if(isComscoreConsentPresent === undefined){
#     window._comscore.push({ c1: "2", c2: "20643943"});
#     console.log("----comscore null----");
#   }else{
#    if (
#      !Didomi.isConsentRequired()
#      || isComscoreConsentPresent  === true
#    ) {
#      comScoreConsent = true;
#    }
#    console.log("----comscore true----");
#    window._comscore.push({ c1: "2", c2: "20643943",  cs_ucfr: comScoreConsent ? "1" : "0" });
#   }
#   console.log("----comscore end----");
#
#  (function() {
#    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/cs/20643943/beacon.js";
#    el.parentNode.insertBefore(s, el);
#  })();
# });
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=20643943&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-67280020-1"></script>
# <script data-vendor="c:googleanal-H6erbLW3" type="didomi/javascript">
#   console.log("----google analytics----");
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-67280020-1');
#   gtag('config', 'G-DQW6N10FYS');
#   gtag('config', 'AW-865277086');
#   gtag('event', 'conversion', {'send_to': 'AW-865277086/C087CJ3ClMMBEJ6pzJwD'});
# </script>
# <script type="text/javascript">
# function e(e){var t=!(arguments.length>1&&void 0!==arguments[1])||arguments[1],c=document.createElement("script");c.src=e,t?c.type="module":(c.async=!0,c.type="text/javascript",c.setAttribute("nomodule",""));var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(c,n)}function t(t,c,n){var a,o,r;null!==(a=t.marfeel)&&void 0!==a||(t.marfeel={}),null!==(o=(r=t.marfeel).cmd)&&void 0!==o||(r.cmd=[]),t.marfeel.config=n,t.marfeel.config.accountId=c;var i="https://sdk.mrf.io/statics";e("".concat(i,"/marfeel-sdk.js?id=").concat(c),!0),e("".concat(i,"/marfeel-sdk.es5.js?id=").concat(c),!1)}!function(e,c){var n=arguments.length>2&&void 0!==arguments[2]?arguments[2]:{};t(e,c,n)}(window,1993,{} /*config*/);
# </script>
# <script>
#             function detectDevice() {
#                 windowWidth = window.innerWidth;
#                 var device = 'desktop';
#
#                 if(windowWidth < 768){ //mobile
#                     device = 'mobile';
#                 }else if(windowWidth >= 768 && windowWidth <= 1024) {
#                     device = 'tablet';
#                 }
#                 return device;
#             }
#         </script><script async="async" data-vendor="didomi:google" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="didomi/javascript"></script>
# <script>
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#         </script>
# <script>
#             partnerCookie = (document.cookie.match(/^(?:.*;)?\s*f2da8790d54184f6c100d431d8e45430\s*=\s*([^;]+)(?:.*)?$/)||[,null])[1];
#             adsDisabled = (partnerCookie != null && partnerCookie === 'b326b5062b2f0e69046810717534cb09');
#         </script><script>
#                 if(!adsDisabled){
#                     if (detectDevice() == 'mobile') {
#                             googletag.cmd.push(function() {
#                                 googletag.defineSlot('/95562950/m.okdiario.com/articulo_top', ['fluid', [300, 100], [320, 50], [320, 100]], 'top1').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/m.okdiario.com/articulo_right1', [[250, 250], [300, 250], 'fluid', [300, 300], [300, 600], [336, 280]], 'right1').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/m.okdiario.com/articulo_right2', [[250, 250], [300, 250], 'fluid', [300, 300], [300, 600], [336, 280]], 'right2').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/m.okdiario.com/articulo_right3', [[250, 250], [300, 250], 'fluid', [300, 300], [300, 600], [336, 280]], 'right3').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/m.okdiario.com/articulo_sticky', [[300, 100], [320, 50], [320, 100]], 'articulo_sticky').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/m.okdiario.com/articulo_x01', 'x01').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/m.okdiario.com/articulo_intext1', 'intext1').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/m.okdiario.com/articulo_intext2', 'intext2').addService(googletag.pubads());
#                                 googletag.pubads().enableSingleRequest();
#                                 googletag.pubads().setTargeting('metatag', ['estadio-santiago-bernabeu', 'florentino-perez', 'real-madrid']).setTargeting('section', ['real-madrid']).setTargeting('subsection', ['real-madrid']);
#
#                                 googletag.enableServices();
#                             });
#                         }
#                         else if (detectDevice() == 'tablet') {
#                             googletag.cmd.push(function() {
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_top', [[728, 90]], 'top1').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_right1', [[250, 250], [300, 250], [300, 600], [300, 300], [160, 600]], 'right1').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_right2', [[250, 250], [300, 250], [300, 600], [300, 300], [160, 600]], 'right2').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_right3', [[250, 250], [300, 250], [300, 600], [300, 300], [160, 600]], 'right3').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_bottom', [[728, 90]], 'bottom').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/okdiario.com/articulo_x01', 'x01').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/okdiario.com/articulo_intext1', 'intext1').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/okdiario.com/articulo_intext2', 'intext2').addService(googletag.pubads());
#                                 googletag.pubads().enableSingleRequest();
#                                 googletag.pubads().setTargeting('metatag', ['estadio-santiago-bernabeu', 'florentino-perez', 'real-madrid']).setTargeting('section', ['real-madrid']).setTargeting('subsection', ['real-madrid']);
#                                 googletag.enableServices();
#                             });
#                         }
#                         else {
#                             googletag.cmd.push(function() {
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_top', [[980, 90], [728, 90], [980, 250], [970, 90], [970, 250], [990, 90], [990, 250]], 'top1').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_sky-derecha', [[160, 600], [120, 600], [120, 1000], [120, 800], [320, 1000], [450, 1000]], 'sky-derecha').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_sky-izquierda', [[160, 600], [120, 600], [120, 1000], [120, 800], [320, 1000], [450, 1000]], 'sky-izquierda').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_right1', [[250, 250], [300, 250], [300, 600], [300, 300], [160, 600]], 'right1').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_right2', [[250, 250], [300, 250], [300, 600], [300, 300], [160, 600]], 'right2').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_right3', [[250, 250], [300, 250], [300, 600], [300, 300], [160, 600]], 'right3').addService(googletag.pubads());
#                                 googletag.defineSlot('/95562950/okdiario.com/articulo_bottom', [[980, 90], [728, 90], [980, 250], [970, 90], [970, 250], [990, 90], [990, 250]], 'bottom').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/okdiario.com/articulo_x01', 'x01').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/okdiario.com/articulo_intext1', 'intext1').addService(googletag.pubads());
#                                 googletag.defineOutOfPageSlot('/95562950/okdiario.com/articulo_intext2', 'intext2').addService(googletag.pubads());
#                                 googletag.pubads().enableSingleRequest();
#                                 googletag.pubads().setTargeting('metatag', ['estadio-santiago-bernabeu', 'florentino-perez', 'real-madrid']).setTargeting('section', ['real-madrid']).setTargeting('subsection', ['real-madrid']);
#                                 googletag.enableServices();
#                             });
#                         }
#                     }
#                 </script>
# <script async="true" src="https://okdiario.idalgo-hosting.com/r/jil" type="text/javascript"></script>
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#    var OneSignal = window.OneSignal || [];
#    OneSignal.push(["init", {
#      appId: "da99b24a-9185-4cce-8b65-7f34a9ecdfc7",
#      autoRegister: true,
#      notifyButton: { enable: false },
#      welcomeNotification: { disable: true },
#      safari_web_id: "web.onesignal.auto.18f55e14-9585-4855-a0ee-ea6515e10e2",
#      promptOptions: {
#         /* actionMessage limited to 90 characters */
#         actionMessage: "¿Quieres que OKDIARIO te mantenga informado de las noticias más destacadas de cada día--?",
#         /* acceptButtonText limited to 15 characters */
#         acceptButtonText: "ACEPTAR",
#         /* cancelButtonText limited to 15 characters */
#         cancelButtonText: "NO, GRACIAS"
#       }
#    }]);
#  </script>
# <script>
#         if ('serviceWorker' in navigator) {
#             navigator.serviceWorker.register('/sw.js').then(function(reg){
#                     console.log("Service Worker Registered", reg);
#                 })
#                 .catch(function(err) {
#                     console.log("Service Worker Failed to Register", err);
#                 })
#         }
#     </script>
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '223156934992982');
#     fbq('track', 'PageView');
#     </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=223156934992982&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script src="https://widgets.besoccerapps.com/media/widgets/js/pym.min.js"></script>
# <script src="https://okdiario.com/diariomadridista/web/themes/v10/lib/indigitall.js?v=1678272688" type="text/javascript"></script>
# </link></meta></link></meta></meta></head>
# <body class="post-template-default single single-post postid-341708 single-format-standard real-madrid">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WQ3PQHT" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="all site" id="page">
# <div id="header">
# <script type="text/javascript">
#       if(screen.width > 767 || window.location.href.indexOf("fotos") > -1 || document.body.classList.contains('single') == false){
#           document.write("<aside class='mega'><div id='top1' style='margin: 0 auto; height: auto;'></div></aside>");
#           googletag.cmd.push(function() { googletag.display('top1'); });
#       }
#       </script>
# <header class="okdiario-cabecera" id="okdiario-cabecera">
# <div class="okdiario-cabecera-interior">
# <div class="okdiario-cabecera-superior">
# <div class="okdiario-cabecera-superior-interior">
# <div class="okdiario-cabecera-superior-izquierda">
# <div class="okdiario-cabecera-destacados">
# <span class="okdiario-destacados-title"><i class="fa fa-star"></i><span>Destacados:</span></span><div class="okdiario-destacados-container"><ul class="okdiario-destacados" id="okdiario-destacados"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-338711" id="menu-item-338711"><a href="https://okdiario.com/diariomadridista/real-madrid/real-madrid-esperara-mbappe-hasta-final-338600">Mbappé – Real Madrid</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-339348" id="menu-item-339348"><a href="https://okdiario.com/diariomadridista/real-madrid/imposible-encontrarla-camiseta-bellingham-agota-semana-341411">Camiseta Bellingham</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-339351" id="menu-item-339351"><a href="https://okdiario.com/diariomadridista/real-madrid/kroos-abre-puerta-seguir-real-madrid-mas-alla-2024-341436">Toni Kroos</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-341373" id="menu-item-341373"><a href="https://okdiario.com/diariomadridista/real-madrid/mijatovic-proxima-temporada-real-madrid-sera-transicion-341382">Mijatovic</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-339536" id="menu-item-339536"><a href="https://okdiario.com/diariomadridista/paparazzi/estrecha-relacion-que-une-mujer-joselu-carvajal-340662">Joselu – Carvajal</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-341093" id="menu-item-341093"><a href="https://okdiario.com/diariomadridista/real-madrid/oficial-ceballos-renueva-real-madrid-336176">Dani Ceballos</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-340479" id="menu-item-340479"><a href="https://okdiario.com/diariomadridista/real-madrid/bale-si-pierdes-madrid-te-crucifican-341301">Bale – Real Madrid</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-340487" id="menu-item-340487"><a href="https://okdiario.com/diariomadridista/cantera/viral-imagen-del-hijo-reyes-bufanda-del-madrid-graduacion-341523">Hijo José Antonio Reyes</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-340127" id="menu-item-340127"><a href="https://okdiario.com/diariomadridista/cantera/arribas-tiene-llave-del-ascenso-341240">Sergio Arribas</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-340490" id="menu-item-340490"><a href="https://okdiario.com/diariomadridista/real-madrid/espectacular-videomarcador-360o-del-bernabeu-ya-tiene-asiento-341189">Santiago Bernabéu</a></li>
# </ul></div><div class="okdiario-destacados-dropdown-top">
# <span class="okdiario-destacados-dropdown-top-title desktop"><a>Más <i></i></a></span>
# <span class="okdiario-destacados-dropdown-top-title mobile"><a><i></i></a></span><div class="okdiario-destacados-dropdown-container"><ul class="okdiario-destacados-dropdown empty"></ul></div>
# </div>
# </div>
# </div>
# <div class="okdiario-cabecera-superior-centro">
# <h2 class="okdiario-h2"></h2>
# </div>
# <div class="okdiario-cabecera-superior-derecha">
# <div class="okdiario-cabecera-fecha">
# <time>
# <span>25 Jun 2023</span>
# </time>
# </div>
# <div class="okdiario-cabecera-actualizacion">
# <time>
# <span><strong>Actualizado</strong></span>
# 13:18 <abbr title="Central European Time">CET</abbr>
# </time>
# </div>
# </div>
# </div>
# </div>
# <div class="okdiario-cabecera-inferior">
# <div class="okdiario-cabecera-inferior-interior">
# <nav class="navTop left">
# <ul>
# <li class="sections" id="sectionMenu">
# <div class="nav-icon">
# <a class="burger-box">
# <div class="burger"></div>
# </a>
# </div>
# <div class="menu-auxiliar">
# <div class="menu-menu-completo-container">
# <ul class="" id="menu-extra">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-extra
a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-extra-paparazzi">
# <a href="https://okdiario.com/diariomadridista/paparazzi/">Paparazzi</a>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-extra-okdiario">
# <a href="https://okdiario.com/">Okdiario</a>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-extra-look">
# <a href="https://okdiario.com/look/">Look</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="search">
# <a class="showSearchForm">
# <i class="icon-lupa"></i>
# </a>
# <div class="searchForm">
# <form action="/diariomadridista/buscador" class="search-form" method="get" role="search"> <label>
# <span class="searchIco"><i class="icon-lupa"></i></span>
# <input id="searchInput" name="q" placeholder="¿Qué noticia estás buscando?" type="text" value=""/>
# </label>
# <input class="hide" id="submitSearchForm" type="submit" value="Buscar"/>
# </form>
# </div>
# </li>
# </ul>
# </nav>
# <div class="okdiario categoria dm" id="okdiario">
# <div class="okdiario-logo"><a href="/diariomadridista/"> <span class="okdiario-logo-span" style="background:url('https://okdiario.com/diariomadridista//web/themes/v10/css/_img/logo-diario-madridista.svg') center no-repeat">DIARIO MADRIDISTA</span>
# </a>
# </div>
# </div>
# <div class="okdiario-seccion hidden-title" id="okdiario-seccion">
# <a class="okdiario-seccion-url" href="/diariomadridista/real-madrid/" title="Ir a Real Madrid"><h2 class="okdiario-seccion-title">Real Madrid</h2></a>
# </div> </div>
# </div>
# <div class="okdiario-cabecera-secciones" id="okdiario-cabecera-secciones">
# <div class="okdiario-secciones-menu">
# <div class="okdiario-secciones-menu-interior">
# <div class="okdiario-secciones-menu-navegacion">
# <ul class="okdiario-secciones-menu-navegacion-ul" style="color:white"><li class="nav-item-category ultimas-noticias"><a class="" href="https://okdiario.com/diariomadridista/ultimas-noticias/">Últimas noticias</a></li><li class="nav-item-category real-madrid"><a class="" href="https://okdiario.com/diariomadridista/real-madrid/">Real Madrid</a></li><li class="nav-item-category baloncesto"><a class="" href="https://okdiario.com/diariomadridista/baloncesto/">Baloncesto</a></li><li class="nav-item-category cantera"><a class="" href="https://okdiario.com/diariomadridista/cantera/">Cantera</a></li><li class="nav-item-category femenino"><a class="" href="https://okdiario.com/diariomadridista/femenino/">Femenino</a></li><li class="nav-item-category fichajes"><a class="" href="https://okdiario.com/diariomadridista/fichajes/">Fichajes</a></li><li class="nav-item-category paparazzi"><a class="" href="https://okdiario.com/diariomadridista/paparazzi/">Paparazzi</a></li></ul>
# <div class="okdiario-secciones-menu-navegacion-color-barr"></div>
# </div>
# </div>
# </div></div>
# </div>
# </header>
# </div>
# <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
# <script src="https://maps.googleapis.com/maps/api/js?libraries=places&amp;key=AIzaSyDCE6zkv9XziNKIrPrlSzi2TZZjuN0JB7o"></script>
# <div data-section="real-madrid" id="postContent">
# <aside class="sky-banners">
# <div class="sky-left">
# <div id="sky-izquierda">
# <script>
#                                         googletag.cmd.push(function() { googletag.display('sky-izquierda'); });
#                                     </script>
# </div>
# </div>
# <div class="sky-right">
# <div id="sky-derecha">
# <script>
# 									googletag.cmd.push(function() { googletag.display('sky-derecha'); });
# 								</script>
# </div>
# </div>
# </aside>
# ...
#             }
#             showDisqus();
#         }
#     }
#
# 	function showDisqus(){
# 		var disqus_shortname = 'diariomadridista'; //
#         var d = document, s = d.createElement('script');
#         s.src = 'https://' + disqus_shortname + '.disqus.com/embed.js';
#         s.setAttribute('data-timestamp', +new Date());
#         (d.head || d.body).appendChild(s);
# 	}
# </script>
# <div class="comments-area" id="comments">
# <div class="show-comments" onclick="showComments()">
# <span class="disqus-comment-count under-article-comments" data-disqus-url="https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" id="countDisqus"><span>Comentar</span></span>
# </div>
# <div class="disqusComments" id="commentsListDisqus">
# <div class="commentsPolitics" id="comentarios">
# <a href="https://okdiario.com/politica-comentarios" target="_blank">Consulta aquí la política de comentarios</a>
# </div>
# <div id="disqus_thread"></div>
# </div>
# </div>
# <div id="taboola-related-article-up"></div>
# <div id="taboola-related-article-down"></div>
# </section>
# <section class="aux-col">
# <aside class="ad-block">
# <div class="publicidad" id="adAfterP1">
# <div id="right1">
# <script>
# 								googletag.cmd.push(function() { googletag.display('right1'); });
# 							</script>
# </div>
# </div>
# </aside>
# <section class="widget" id="last-news">
# <h3 class="widget-title">Lo último en Real Madrid</h3>
# <ul>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/real-madrid/zidane-admiro-mucho-mbappe-341909" rel="bookmark" title="Zidane: «Admiro mucho a Mbappé»">
# <img alt="Zinedine Zidane" src="https://okdiario.com/diariomadridista/img/2022/06/10/zinedine-zidane-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/real-madrid/zidane-admiro-mucho-mbappe-341909" rel="bookmark" title="Zidane: «Admiro mucho a Mbappé»">Zidane: «Admiro mucho a Mbappé»</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/real-madrid/asi-fue-boda-jesus-vallejo-caso-pilar-pignoise-dio-concierto-341829" rel="bookmark" title="Así fue la boda de Jesús Vallejo: se casó en el Pilar y Pignoise dio un concierto">
# <img alt="vallejo" src="https://okdiario.com/diariomadridista/img/2023/06/24/vallejo-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/real-madrid/asi-fue-boda-jesus-vallejo-caso-pilar-pignoise-dio-concierto-341829" rel="bookmark" title="Así fue la boda de Jesús Vallejo: se casó en el Pilar y Pignoise dio un concierto">Así fue la boda de Jesús Vallejo: se casó en el Pilar y Pignoise dio un concierto</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" rel="bookmark" title="El descomunal avance del Bernabéu en su tercera semana sin fútbol">
# <img alt="bernabéu" src="https://okdiario.com/diariomadridista/img/2023/06/24/banon-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" rel="bookmark" title="El descomunal avance del Bernabéu en su tercera semana sin fútbol">El descomunal avance del Bernabéu en su tercera semana sin fútbol</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/real-madrid/show-vinicius-orlando-falla-ocasion-pone-firmar-autografos-341688" rel="bookmark" title="El ‘show’ de Vinicius en Orlando: falla una ocasión…¡y se pone a firmar autógrafos!">
# <img alt="El ‘show’ de Vinicius en Orlando: falla una ocasión…¡y se pone a firmar autógrafos!" src="https://okdiario.com/diariomadridista/img/2023/06/24/vini-15-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/real-madrid/show-vinicius-orlando-falla-ocasion-pone-firmar-autografos-341688" rel="bookmark" title="El ‘show’ de Vinicius en Orlando: falla una ocasión…¡y se pone a firmar autógrafos!">El ‘show’ de Vinicius en Orlando: falla una ocasión…¡y se pone a firmar autógrafos!</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/real-madrid/ceferin-tambien-juega-fichaje-mbappe-madrid-341445" rel="bookmark" title="Ceferin también juega en el fichaje de Mbappé por el Madrid">
# <img alt="Mbappé Ceferin Real Madrid" src="https://okdiario.com/diariomadridista/img/2023/06/23/ceferin-mbappe-interior-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/real-madrid/ceferin-tambien-juega-fichaje-mbappe-madrid-341445" rel="bookmark" title="Ceferin también juega en el fichaje de Mbappé por el Madrid">Ceferin también juega en el fichaje de Mbappé por el Madrid</a>
# </li>
# </ul>
# </section>
# <aside class="ad-block">
# <div class="publicidad" id="adAfterP2">
# <div id="right2">
# <script>
# 									googletag.cmd.push(function() { googletag.display('right2'); });
# 								</script>
# </div>
# </div>
# </aside>
# <section class="widget" id="last-news-all">
# <h3 class="widget-title">Últimas noticias</h3>
# <ul>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/real-madrid/zidane-admiro-mucho-mbappe-341909" rel="bookmark" title="Zidane: «Admiro mucho a Mbappé»">
# <img alt="Zinedine Zidane" src="https://okdiario.com/diariomadridista/img/2022/06/10/zinedine-zidane-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/real-madrid/zidane-admiro-mucho-mbappe-341909" rel="bookmark" title="Zidane: «Admiro mucho a Mbappé»">Zidane: «Admiro mucho a Mbappé»</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/cantera/asi-era-plantilla-del-real-madrid-castilla-ultimo-ascenso-segunda-donde-estan-ahora-341703" rel="bookmark" title="Así era la plantilla del Real Madrid Castilla en su último ascenso a Segunda: ¿dónde están ahora?">
# <img alt="casilla ascenso 2012" src="https://okdiario.com/diariomadridista/img/2023/06/24/castilla-ascenso-2012-1-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/cantera/asi-era-plantilla-del-real-madrid-castilla-ultimo-ascenso-segunda-donde-estan-ahora-341703" rel="bookmark" title="Así era la plantilla del Real Madrid Castilla en su último ascenso a Segunda: ¿dónde están ahora?">Así era la plantilla del Real Madrid Castilla en su último ascenso a Segunda: ¿dónde están ahora?</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/cantera/hora-generacion-raul-341774" rel="bookmark" title="La hora de la Generación Raúl">
# <img alt="La hora de la Generación Raúl" src="https://okdiario.com/diariomadridista/img/2023/06/24/la-hora-de-la-generacion-raul-interior-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/cantera/hora-generacion-raul-341774" rel="bookmark" title="La hora de la Generación Raúl">La hora de la Generación Raúl</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/cantera/eldense-real-madrid-castilla-segunda-espera-castilla-341763" rel="bookmark" title="Eldense – Real Madrid Castilla: Segunda espera al Castilla">
# <img alt="Eldense – Real Madrid Castilla: Segunda espera al Castilla" src="https://okdiario.com/diariomadridista/img/2023/06/24/previa-eldense-castilla-interior-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/cantera/eldense-real-madrid-castilla-segunda-espera-castilla-341763" rel="bookmark" title="Eldense – Real Madrid Castilla: Segunda espera al Castilla">Eldense – Real Madrid Castilla: Segunda espera al Castilla</a>
# </li>
# <li>
# <a class="rel-link" href="https://okdiario.com/diariomadridista/real-madrid/asi-fue-boda-jesus-vallejo-caso-pilar-pignoise-dio-concierto-341829" rel="bookmark" title="Así fue la boda de Jesús Vallejo: se casó en el Pilar y Pignoise dio un concierto">
# <img alt="vallejo" src="https://okdiario.com/diariomadridista/img/2023/06/24/vallejo-143x89.jpg"/>
# </a>
# <a href="https://okdiario.com/diariomadridista/real-madrid/asi-fue-boda-jesus-vallejo-caso-pilar-pignoise-dio-concierto-341829" rel="bookmark" title="Así fue la boda de Jesús Vallejo: se casó en el Pilar y Pignoise dio un concierto">Así fue la boda de Jesús Vallejo: se casó en el Pilar y Pignoise dio un concierto</a>
# </li>
# </ul>
# </section>
# <aside class="ad-block">
# <div class="publicidad" id="adAfterLastP">
# <div id="right3">
# <script>
# 										googletag.cmd.push(function() { googletag.display('right3'); });
# 									</script>
# </div>
# </div>
# </aside>
# </section>
# </article>
# <aside class="mega">
# <div id="bottom" style="margin: 0 auto;">
# <script>
# 						googletag.cmd.push(function() { googletag.display('bottom'); });
# 					</script>
# </div>
# </aside>
# </div>
# <aside class="outofpageHome">
# <div id="x01" style="margin: 0 auto;">
# <script>
# 					googletag.cmd.push(function() { googletag.display('x01'); });
# 				</script>
# </div>
# </aside>
# <footer id="footerPage">
# <div id="toTop">
# <div class="toTopContainer"><i class="fa fa-arrow-up"></i><span class="toTopText">Ir Arriba </span></div>
# </div>
# <ul>
# <li>DOS MIL PALABRAS S.L. 2023.</li>
# <li>Auditado por <i>ComScore</i></li>
# </ul>
# </footer>
# <div class="catfish-start" id="okd-catfish">
# <div class="catfish-space" id="container-catfish">
# <button id="catfish-btn"></button>
# </div>
# </div>
# <div id="native-addthis-fixed">
# <div class="native-share-buttons">
# <div class="addthis-item facebook">
# <a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fokdiario.com%2Fdiariomadridista%2Freal-madrid%2Fdescomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" target="_blank"></a>
# </div>
# <div class="addthis-item twitter">
# <a href="https://twitter.com/intent/tweet?text=El+descomunal+avance+del+Bernab%C3%A9u+en+su+tercera+semana+sin+f%C3%BAtbol%3A+https%3A%2F%2Fokdiario.com%2Fdiariomadridista%2Freal-madrid%2Fdescomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" target="_blank"></a>
# </div>
# <div class="addthis-item whatsapp">
# <a href="https://api.whatsapp.com/send?text=El+descomunal+avance+del+Bernab%C3%A9u+en+su+tercera+semana+sin+f%C3%BAtbol%3A+https%3A%2F%2Fokdiario.com%2Fdiariomadridista%2Freal-madrid%2Fdescomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" target="_blank"></a>
# </div>
# <div class="addthis-item telegram">
# <a href="https://telegram.me/share/url?url=https%3A%2F%2Fokdiario.com%2Fdiariomadridista%2Freal-madrid%2Fdescomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708" target="_blank"></a>
# </div>
# </div>
# </div>
# <script>
#     partnerCookie = (document.cookie.match(/^(?:.*;)?\s*f2da8790d54184f6c100d431d8e45430\s*=\s*([^;]+)(?:.*)?$/)||[,null])[1];
#     adsDisabled = (partnerCookie != null && partnerCookie === 'b326b5062b2f0e69046810717534cb09');
# </script>
# <script>
#         if(!adsDisabled) {
#             window._taboola = window._taboola || [];
#             !function (e, f, u, i) {
#                 if (!document.getElementById(i)) {
#                     e.async = 1;
#                     e.src = u;
#                     e.id = i;
#                     f.parentNode.insertBefore(e, f);
#                 }
#             }(document.createElement('script'), document.getElementsByTagName('script')[0], '//cdn.taboola.com/libtrc/okdiario/loader.js', 'tb_loader_script');
#             if (window.performance && typeof window.performance.mark == 'function') {
#                 window.performance.mark('tbl_ic');
#             }
#
#             (function () {
#                 chargeTaboola();
#             })();
#
#             function chargeTaboola() {
#                 if (typeof _taboola !== 'undefined') {
#                     _taboola.push({
#                         mode: 'thumbnails-a-new',
#                         container: 'taboola-related-article-up',
#                         placement: 'Below Article Thumbnails New',
#                         target_type: 'mix'
#                     });
#                     _taboola.push({
#                         mode: 'organic-thumbnails-a-new',
#                         container: 'taboola-related-article-down',
#                         placement: 'Organic Below Article Thumbnails New',
#                         target_type: 'mix'
#                     });
#                     _taboola.push({
#                         article: 'auto',
#                         url: window.location.href
#                     });
#                 }
#             }
#
#         }
# 	</script>
# <script src="https://okdiario.com/diariomadridista/web/themes/v10/lib/navigation.js?v=1669031752" type="text/javascript"></script>
# <script id="jquery-js" src="https://okdiario.com/diariomadridista/web/themes/v10/js/jquery.cookie.js" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://okdiario.com/diariomadridista/wp-includes/js/wp-embed.min.js" type="text/javascript"></script>
# <script async="" charset="utf-8" data-vendor="c:twitter" src="//platform.twitter.com/widgets.js"></script>
# <script type="text/javascript">
#     if(!adsDisabled) {
#         window._tfa = window._tfa || [];
#         window._tfa.push({notify: 'event', name: 'page_view'});
#         !function (t, f, a, x) {
#             if (!document.getElementById(x)) {
#                 t.async = 1;
#                 t.src = a;
#                 t.id = x;
#                 f.parentNode.insertBefore(t, f);
#             }
#         }(document.createElement('script'),
#             document.getElementsByTagName('script')[0],
#             '//cdn.taboola.com/libtrc/unip/1151813/tfa.js',
#             'tb_tfa_script');
#     }
# </script>
# <noscript>
# <img height="0" src="//trc.taboola.com/1151813/log/3/unip?en=page_view" style="display:none" width="0"/>
# </noscript>
# <script>
# 		$(document).ready(function() {
#         if ($('#right3').length){
#             sticky_banners("right3",2);
#         }else{
#             sticky_banners("right2",1);
#         }
#
# 		});
# 	</script>
# <script>
#     if ($('.arrow-left').length) {
#         $('.arrow-left').click(function () {
#             var index = $('.current').attr('data-index');
#
#             // 0 Por ser la primera diapositiva.
#             if (index > 0) {
#                 var siblings = $('.current').siblings();
#
#                 if ($(window).width() >= 1024) {
#                     $(siblings[parseInt(index) + 2]).removeClass('current right');
#                     $(siblings[parseInt(index) + 1]).addClass('right');
#                     $(siblings[index]).removeClass('left');
#                     $(siblings[parseInt(index) - 1]).addClass('current left');
#                 } else {
#                     $(siblings[parseInt(index) + 1]).removeClass('current right');
#                     $(siblings[index]).removeClass('left');
#                     $(siblings[index]).addClass('right');
#                     $(siblings[parseInt(index) - 1]).addClass('current left');
#                 }
#             }
#         });
#
#         var last = $('.current:last');
#         if ($(window).width() >= 1024) {
#             last.next().addClass('current right');
#             last.prev().addClass('left');
#         } else {
#             last.prev().addClass('left');
#             last.addClass('right');
#         }
#     }
#
#     if ($('.arrow-right').length) {
#         $('.arrow-right').click(function () {
#             var index = $('.current').attr('data-index');
#
#             // 19 por la ultima diapositiva (22) menos las 3 visibles.
#             if (index < 19) {
#
#                 var siblings = $('.current').siblings();
#
#                 if ($(window).width() >= 1024) {
#                     $(siblings[index]).removeClass('current left');
#                     $(siblings[parseInt(index) + 1]).addClass('left');
#                     $(siblings[parseInt(index) + 2]).removeClass('right');
#                     $(siblings[parseInt(index) + 3]).addClass('current right');
#                 } else {
#                     $(siblings[index]).removeClass('current left');
#                     $(siblings[parseInt(index) + 1]).removeClass('right');
#                     $(siblings[parseInt(index) + 1]).addClass('left');
#                     $(siblings[parseInt(index) + 2]).addClass('current right');
#                 }
#             }
#         });
#     }
# </script>
# <script type="text/javascript">
#   window._taboola = window._taboola || [];
#   _taboola.push({flush: true});
# </script>
# </div></body>
# </html>

# %%
news_url
# Out:
# 'https://okdiario.com/diariomadridista/real-madrid/descomunal-avance-del-bernabeu-tercera-semana-sin-futbol-341708'

# %%
news_media_data = {}
non_processed_urls = []

for i, news_url in enumerate(complete_urls):
    news_url_id = news_url.split("-")[-1]
    resp_url_news = requests.get(news_url, 
                                 headers=headers)
    parsed_news_hmtl = BeautifulSoup(resp_url_news.content, 
                                     "html.parser")
    article = parsed_news_hmtl.find(find_tag_article)
    # title, author, date, content
    try:
        title = article.find(find_attr_title).get_text()
    except:
        non_processed_urls.append((news_url, 
                                   "title error"))
        continue
    author_date = content_element.find(find_attr_author).get_text(separator="\n", 
                                                                  strip=True)
    content_element = article.find(find_attr_content)
    
    author_date_splits = author_date.split("\n")
    if len(author_date_splits) > 3:
        author = author_date[0]
        creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", author_date)
    else:
        author = author_date_splits[0]
        creation_date = re.findall(r"[0-9]+:[0-9]+", author_date)
        update_date = re.findall(r"[0-9]{1,2}.+20[0-9]{2}", author_date)
    
    content = content_element.find(find_attr_content).get_text()
    try:
        topics = content_element.find(find_attr_topics).get_text(separator="\n", 
                                                                 strip=True).split("\n")[1:]
    except:
        topics = []
    one_news_data = {"title": title, 
                     "creation_date": creation_date,
                     "creation_time": creation_time,
                     "update_date": update_date,
                     "update_time": update_time,
                     "content": content,
                     "topics": topics
                    }
    news_media_data[news_url_id] = one_news_data

# %%
len(news_media_data)
# Out:
# 184

# %%
news_media_data = {}
not_processed_urls = []

for i, news_url in enumerate(complete_urls):
    #news_url_id = news_url.replace(".html", "").split("_")[-1]
    resp_url_news = requests.get(news_url, 
                                 headers=headers)
    parsed_news_hmtl = BeautifulSoup(resp_url_news.content, 
                                     "html.parser")
    article = parsed_news_hmtl.find(find_attr_article)
    # title, author, date, content
    title = article.find(find_attr_title).get_text()
    author_date = content_element.find(find_attr_author).get_text(separator="\n", 
                                                                  strip=True)
    content_element = article.find(find_attr_content)
    
    if len(author_date) > 3:
        author = author_date[0]
        creation_date, creation_time, update_date, update_time = re.findall(r"[0-9]+.{1}[0-9]+(?:.{1}[0-9]+)?", author_date)
    else:
        author = author_date.split("\n")[0]
        creation_date = re.findall(r"[0-9]+:[0-9]+", author_date)
        update_date = re.findall(r"[0-9]{1,2}.+20[0-9]{2}", author_date)
    
    content = content_element.find(find_attr_content).get_text()
    topics = content_element.find(find_attr_topics).get_text(separator="\n", 
                                                             strip=True).split("\n")[1:]
    print(title)
    print(creation_date, creation_time, update_date, update_time)
    print(content)
    print(topics)
    break
# Out:
# 10 películas de terror en Netflix que no te puedes perder
# 29/12/2022 20:00 29/12/2022 21:54
#
# Netflix tiene las mejores películas de terror que no te puedes perder, disfrutarás del miedo en primera persona. Un genero que tiene sus seguidores y nos aportará esos instantes de emociones que estamos buscando. Puedes ver en Netflix series y películas de terror para disfrutar de este genero en estos días que tienes más tiempo libre. Con el mando tienes el control de todo un universo de emociones que podemos descubrir en estos días que corren. Toma nota de esta lista de las 10 películas de terror en Netflix que no te puedes perder esta temporada.Estas son algunas de las mejores películas de terror en Netflix
# «Sabrina»: esta película indonesia se centra en una niña que toca una lápiz para llamar a su difunta madre, y a partir de ese momento empiezan a suceder cosas muy extrañas. La muñeca Sabrina tiene mucho que ver.
# «La invitación»: película estadounidense en la que un hombre decide aceptar la invitación de su ex esposa para ir a una cena que está organizando. Esa noche se menciona un tema inquietante que dará lugar a muchas tensiones y reabrirá viejas heridas.
# «Habitación verde»: también estadounidense, muestra a una banda de rock que intenta escapar y sobrevivir tras presenciar un asesinato por parte de skinheads neonazis.
# «Tren a Busan»: entre las películas de terror en Netflix destaca especialmente ésta, en la que un virus zombi estalla en Corea del Sur y los pasajeros de un tren luchan por sobrevivir.
# «El sexto sentido»: todo un clásico dentro del género protagonizado por Bruce Willis y ese misterioso niño… no diremos más.
# «El conjuro»: dos investigadores paranormales quieren ayudar a una familia que está aterrorizada porque en su casa habita una presencia oscura.
# «Cargo»: película australiana que cuenta la historia de un padre que intenta proteger a su hija después de que una epidemia se haya extendido por todo el país.
# «Bird Box: A ciegas»: una presencia invisible lleva a gran parte de la sociedad al suicidio. 5 años después, una madre y sus dos hijos intentan llegar a un lugar seguro.
# «Apóstol»: un vagabundo quiere rescatar a su hermana, que está secuestrada, y se encuentra con un siniestro culto religioso que hay en una isla aislada. Todo sucede en el año 1905.
# «1922»: otra buena película de terror en Netflix, en este caso centrada en un agricultor que quiere asesinar a su mujer por dinero, e intenta convencer a su hijo adolescente para que le ayude.
#
#
# ['Cine', 'Netflix', 'Películas']

# %% [markdown]
# ## ABC

# %%
url = "https://abc.es/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}
main_root = "https://www.abc."
# With headers
response = requests.get(url, headers=headers)
print(response.status_code)  # HTTP status code

parsed_hmtl = BeautifulSoup(response.content, "html.parser")

a_tags = parsed_hmtl.find_all("a", href=re.compile("-[a-z]{1,2}.html$"))
valid_urls = []
not_valid_urls = []
for a in a_tags:
    try:
        href = a["href"]
        if main_root not in href:
            href = main_root + href
        valid_urls.append(href)
        print(href)
    except:
        continue
print(len(valid_urls))
# Out:
# 200
# https://www.abc.es/internacional/rusia-revivir-revolucion-1917-hijos-elites-escaquean-20230524143040-nt.html
# https://www.abc.es/espana/dinero-deberias-cobrar-mesa-electoral-elecciones-nuevo-20230524120833-nt.html
# https://www.abc.es/gente/central-park-altar-romantica-historia-amor-garbine-20230524172817-nt.html
# https://www.abc.es/play/television/noticias/mediaset-anuncia-baja-jorge-javier-vazquez-motivo-ausencia-presentador-20230523214959-nt.html
# https://www.abc.es/antropia/barcos-marroquies-pescan-forma-ilegal-aguas-espanolas-20230524002521-nt.html
# https://www.abc.es/tecnologia/informatica/soluciones/bill-gates-vaticina-inteligencia-artificial-arrasara-dos-20230523010902-nt.html
# https://www.abc.es/espana/elecciones-municipales-autonomicas-directo-entrevista-ayuso-encuestas-ultimas-noticias-20230522083951-di.html
# https://www.abc.es/economia/muface-protesta-ante-page-exclusion-mutualistas-rebaja-20230524134530-nt.html
# https://www.abc.es/play/television/noticias/ana-rosa-quintana-regresa-anuncio-sobre-cancer-20230524092128-nt.html
# https://www.abc.es/internacional/guerra-rusia-ucrania-directo-ultimas-noticias-sobre-conflicto-ataques-putin-20230524180714-di.html
# https://www.abc.es/recreo/mario-picazo-alerta-peligrosas-consecuencias-dana-espana-20230524212650-nt.html
# https://www.abc.es/economia/page-exige-miles-funcionarios-pasarse-sanidad-publica-20230524182510-nt.html
# https://www.abc.es/economia/banca-deniega-tres-hipotecas-rechazaron-profesion-pese-20230522171110-nt.html
# https://www.abc.es/espana/calendario-campana-elecciones-2023-empieza-dura-ilegal-mitin-20230524215631-nt.html
# https://www.abc.es/espana/castilla-leon/detenido-hombre-casado-hizo-pareja-conveniencia-anos-20230522125404-nt.html
# https://www.abc.es/espana/comunidad-valenciana/conductor-enfrenta-multa-millones-euros-transportar-cerdo-20230524095542-nt.html
# https://www.abc.es/gente/michu-habla-nunca-papel-jose-fernando-padre-20230524133515-nt.html
# https://www.abc.es/gente/exclusiva-imagenes-demuestra-alfred-maria-hervas-mantienen-20230524140355-nt.html
# https://www.abc.es/historia/era-gigantesca-red-prostibulos-publicos-levantaron-reyes-20230523130005-nt.html
