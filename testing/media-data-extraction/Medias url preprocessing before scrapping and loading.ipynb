# %%
import numpy as np
from scipy.spatial.distance import jaccard, cosine
from bs4 import BeautifulSoup
import re
import requests
import openai
import os
import json
from datetime import datetime
import pandas as pd
import tqdm
from matplotlib import pyplot as plt
import glob as glob

from nltk.corpus import wordnet as wn
from nltk import download
from nltk.metrics.distance import edit_distance
#download('wordnet')

# %%
def read_json_media_urls_file(file_path):
    with open(file_path, "r") as file:
        return json.load(file)
def read_plain_media_urls_file(file_path):
    with open(file_path, "r") as file:
        return file.readlines()

# %%
ranking_files = [(file, datetime.strptime(file.split("_")[-1].split(".")[0], "%d%m%Y") )for file in glob.glob("../data/SCImago*Spanish_*.xlsx")]
ranking_files_sort = sorted(ranking_files, 
                            key=lambda x: x[1]
                            )
most_recent_file = ranking_files_sort[-1][0]
ranking_files, ranking_files_sort, most_recent_file
# Out:
# ([('../data\\SCImago Media Ranking - Spain - Spanish_02092023.xlsx',
#    datetime.datetime(2023, 9, 2, 0, 0)),
#   ('../data\\SCImago Media Ranking - Spain - Spanish_20082023.xlsx',
#    datetime.datetime(2023, 8, 20, 0, 0))],
#  [('../data\\SCImago Media Ranking - Spain - Spanish_20082023.xlsx',
#    datetime.datetime(2023, 8, 20, 0, 0)),
#   ('../data\\SCImago Media Ranking - Spain - Spanish_02092023.xlsx',
#    datetime.datetime(2023, 9, 2, 0, 0))],
#  '../data\\SCImago Media Ranking - Spain - Spanish_02092023.xlsx')

# %%
rankings_file_path = os.path.join("..\data", most_recent_file)
media_ranks = pd.read_excel(rankings_file_path).sort_values("Global_rank")
media_ranks["Media"] = media_ranks["Media"].str.strip()
media_ranks["Domain"] = media_ranks["Domain"].str.strip()
media_ranks[["Media", "Domain"]].head(50).to_csv("../data/spain_media name_to_url.txt", 
                                        index=False, 
                                        header=False,
                                        sep=";")
media_ranks.head(15)
# Out:
#                          Media                       Domain Country  \
# 190                    El País                   elpais.com   Spain
# 189                        ABC                       abc.es   Spain
# 187              La Vanguardia             lavanguardia.com   Spain
# 188                 El Español                elespanol.com   Spain
# 186                   El Mundo                   elmundo.es   Spain
# 185  El Periódico de Catalunya              elperiodico.com   Spain
# 183                   La Razón                   larazon.es   Spain
# 184               Europa Press               europapress.es   Spain
# 182                 20 Minutos                 20minutos.es   Spain
# 181            El Confidencial           elconfidencial.com   Spain
# 180                elDiario.es                  eldiario.es   Spain
# 179             ABC de Sevilla               sevilla.abc.es   Spain
# 178          La Voz de Galicia            lavozdegalicia.es   Spain
# 177           Libertad Digital          libertaddigital.com   Spain
# 176             Crónica global  cronicaglobal.elespanol.com   Spain
#
#              Region          Language  Global_rank  Overall
# 190  Western Europe           Spanish            7    84.50
# 189  Western Europe           Spanish           28    78.25
# 187  Western Europe   Spanish/Catalan           43    76.75
# 188  Western Europe           Spanish           43    76.75
# 186  Western Europe           Spanish           60    74.75
# 185  Western Europe           Spanish           89    72.75
# 183  Western Europe           Spanish          115    71.25
# 184  Western Europe           Spanish          115    71.25
# 182  Western Europe           Spanish          124    70.75
# 181  Western Europe           Spanish          151    69.25
# 180  Western Europe           Spanish          151    69.25
# 179  Western Europe           Spanish          178    68.25
# 178  Western Europe  Spanish/Galician          211    67.50
# 177  Western Europe           Spanish          211    67.50
# 176  Western Europe           Spanish          253    66.25

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}
file_name = "spain_media name_to_url.txt"
file_path = os.path.join("..", "data", file_name)
if os.path.exists(file_path):
    print("Reading file of urls of regions...")
    name_to_media_urls = read_plain_media_urls_file(file_path)
    all_sections = []
skip_head = True
for media_line in name_to_media_urls:
    #if skip_head:
    #    skip_head = False
    #    continue
    _, media = media_line.split(";")
    media_url = "https://www." + media.strip()
    try:
        response = requests.get(media_url, 
                                headers=HEADERS, 
                                timeout=10)
    except requests.exceptions.Timeout:
        # Handle the timeout exception
        print("The request timed out.")
    except requests.exceptions.RequestException as e:
        # Handle other request exceptions
        print(f"An error occurred: {str(e)}")
        media_url = media_url.replace("www.", "")
        response = requests.get(media_url, 
                                headers=HEADERS, 
                                timeout=10) 

    parsed_hmtl = BeautifulSoup(response.content, 
                                "html.parser")
    try:
        links = [x.attrs.get("href", None) for x in parsed_hmtl.body.find_all("a")]
    except Exception as e:
        print(e)

    links_serie = pd.Series(links).dropna()
    nodes = links_serie.str.replace(media_url, "", regex=True)

    nodes_split = nodes.str.split("/")
    nodes_split_clean = nodes_split.apply(lambda x: [elem for elem in x if elem])

    nodes_split_clean_filter = nodes_split_clean.str.len().eq(1)

    valid_links = links_serie[nodes_split_clean_filter]
    #valid_links_complete = [media_url + x if not x.startswith(media_url) else x for x in valid_links]
    valid_links_complete = []
    with open("Skipped urls.txt", "w") as file_skipped:
        for link_node in valid_links:
            link = link_node
            link_lower = link.lower()
            # Drop if 'garbage' node
            if link == media_url \
                or len(link.replace("/", "")) == 1 \
                or "#" in link_lower \
                or ":" in link_lower \
                or "@" in link_lower \
                or "php" in link_lower \
                or "javascript" in link_lower \
                or "mailto" in link_lower \
                or "cookie" in link_lower \
                or "feed" in link_lower \
                or "contact" in link_lower \
                or ("aviso" in link_lower and "legal" in link_lower) \
                or "inici" in link_lower \
                or "session" in link_lower \
                or "sesion" in link_lower \
                or "ads" in link_lower \
                or "publicidad" in link_lower \
                or "privacidad" in link_lower \
                or "condiciones" in link_lower \
                or "tags" in link_lower \
                or "premium" in link_lower \
                or "archiv" in link_lower \
                or "sorteo" in link_lower \
                or "loter" in link_lower \
                or "newsletter" in link_lower \
                or "podcast" in link_lower \
                or "logout" in link_lower \
                or "login" in link_lower \
                or link.endswith(".html") \
                or "notifica" in link_lower \
                or "push" in link_lower \
                or "servicio" in link_lower \
                or "esquela" in link_lower \
                or "defunci" in link_lower \
                or "favorito" in link_lower \
                or "firma" in link_lower \
                or "suscri" in link_lower \
                or "subscrib" in link_lower \
                or "pasatiempo" in link_lower \
                or "compra" in link_lower \
                or "tienda" in link_lower \
                or "gráfico" in link_lower or "gráfico" in link_lower \
                or "humor" in link_lower \
                or "foto" in link_lower \
                or "opinion" in link_lower or "opinión" in link_lower \
                or "hemeroteca" in link_lower \
                or "video" in link_lower or "vídeo" in link_lower \
                or "play" in link_lower \
                or "patrocin" in link_lower \
                or "autor" in link_lower \
                or re.compile("\d{3,}").search(link):
                continue
            if not link.startswith(media_url):
                if not link.startswith("//www."):
                    link_parts = link.split("/")
                    link_parts = [x for x in link_parts if x]
                    if len(link_parts) == 1:
                        if link.startswith("/"):
                            link = media_url + link
                        else:
                            link = media_url + "/" + link
                    else:
                        continue
                else:
                    continue
            else:
                link_parts = link.split("/")
                link_parts = [x for x in link_parts if x][2:]
                if len(link_parts) > 1 or len(link_parts) == 0:
                    continue
                else:
                    continue
            if not link.endswith("/"):
                link += "/"
            valid_links_complete.append(link)
        print(f"Valid links of {media_url.strip()}:", len(valid_links))
        all_sections.extend(valid_links_complete)
    valid_links_complete_unique = list(set(all_sections))
# Out:
# Reading file of urls of regions...
# Valid links of https://www.elpais.com: 28
# Valid links of https://www.abc.es: 60
# Valid links of https://www.lavanguardia.com: 81
# Valid links of https://www.elespanol.com: 120
# Valid links of https://www.elmundo.es: 86
# Valid links of https://www.elperiodico.com: 18
# Valid links of https://www.larazon.es: 62
# Valid links of https://www.europapress.es: 107
# Valid links of https://www.20minutos.es: 48
# Valid links of https://www.elconfidencial.com: 30
# Valid links of https://www.eldiario.es: 121
# Valid links of https://www.sevilla.abc.es: 52
# Valid links of https://www.lavozdegalicia.es: 105
# Valid links of https://www.libertaddigital.com: 49
# An error occurred: HTTPSConnectionPool(host='www.cronicaglobal.elespanol.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001B46D6457C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Valid links of https://cronicaglobal.elespanol.com: 53
# Valid links of https://www.elcorreo.com: 93
# Valid links of https://www.diariosur.es: 119
# Valid links of https://www.diariodesevilla.es: 197
# Valid links of https://www.diariovasco.com: 110
# Valid links of https://www.huffingtonpost.es: 53
# Valid links of https://www.levante-emv.com: 301
# Valid links of https://www.lasprovincias.es: 100
# Valid links of https://www.laverdad.es: 88
# Valid links of https://www.heraldo.es: 24
# Valid links of https://www.farodevigo.es: 315
# Valid links of https://www.ideal.es: 86
# Valid links of https://www.epe.es: 8
# Valid links of https://www.publico.es: 49
# Valid links of https://www.diariodemallorca.es: 280
# Valid links of https://www.canarias7.es: 69
# Valid links of https://www.lainformacion.com: 33
# Valid links of https://www.okdiario.com: 0
# Valid links of https://www.periodistadigital.com: 322
# Valid links of https://www.deia.eus: 168
# Valid links of https://www.elcomercio.es: 110
# Valid links of https://www.hoy.es: 96
# Valid links of https://www.lne.es: 385
# Valid links of https://www.informacion.es: 342
# Valid links of https://www.eldiariomontanes.es: 77
# Valid links of https://www.diariodecadiz.es: 178
# Valid links of https://www.larioja.com: 76
# Valid links of https://www.republica.com: 30
# Valid links of https://www.noticiasdenavarra.com: 179
# Valid links of https://www.ultimahora.es: 104
# Valid links of https://www.elplural.com: 49
# Valid links of https://www.elcorreogallego.es: 260
# Valid links of https://www.elperiodicodearagon.com: 266
# Valid links of https://www.eldia.es: 347
# Valid links of https://www.diariocordoba.com: 290
# Valid links of https://www.elconfidencialdigital.com: 25

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}
file_name = "spain_media name_to_url.txt"
file_path = os.path.join("..", "data", file_name)
if os.path.exists(file_path):
    print("Reading file of urls of regions...")
    name_to_media_urls = read_plain_media_urls_file(file_path)
    all_sections = []
skip_head = True
for media_line in name_to_media_urls:
    #if skip_head:
    #    skip_head = False
    #    continue
    _, media = media_line.split(";")
    media = media.strip()
    media_url = "https://" + media
    try:
        response = requests.get(media_url, 
                                headers=HEADERS, 
                                timeout=6.0)
    except requests.exceptions.Timeout:
        # Handle the timeout exception
        print("The request timed out.")
        continue
    except requests.exceptions.RequestException as e:
        # Handle other request exceptions
        print(f"Retry request with 'https://www.' prefix")
        media_url = "https://www." + media
        response = requests.get(media_url, 
                                headers=HEADERS, 
                                timeout=6.0)
        print(f"ok ({response.status_code})")
        #continue
    domain = response.url.split("/")[2]
    domain_url = "/".join(response.url.split("/")[:3] + [""])
    parsed_hmtl = BeautifulSoup(response.content, 
                                "html.parser")
    try:
        links = [x.attrs.get("href", None) for x in parsed_hmtl.body.find_all("a")]
    except Exception as e:
        print(e)

    links_serie = pd.Series(links).dropna()
    nodes = links_serie.str.replace(media_url, "", regex=True)

    nodes_split = nodes.str.split("/")
    nodes_split_clean = nodes_split.apply(lambda x: [elem for elem in x if elem])

    nodes_split_clean_filter = nodes_split_clean.str.len().eq(1)

    valid_links = links_serie[nodes_split_clean_filter]
    #valid_links_complete = [media_url + x if not x.startswith(media_url) else x for x in valid_links]
    valid_links_complete = []
    with open("Skipped urls.txt", "w") as file_skipped:
        for link_node in valid_links:
            link = link_node
            link_lower = link.lower()
            if link.startswith("//www."):
                continue
            # Drop if 'garbage' nodes
            if link == media_url \
                or len(link.replace("/", "")) == 1 \
                or "#" in link_lower \
                or ":" in link_lower \
                or "@" in link_lower \
                or "php" in link_lower \
                or "javascript" in link_lower \
                or "mailto" in link_lower \
                or "cookie" in link_lower \
                or "feed" in link_lower \
                or "contact" in link_lower \
                or ("aviso" in link_lower and "legal" in link_lower) \
                or "inici" in link_lower \
                or "session" in link_lower \
                or "sesion" in link_lower \
                or "ads" in link_lower \
                or "publicidad" in link_lower \
                or "privacidad" in link_lower \
                or "condiciones" in link_lower \
                or "tags" in link_lower \
                or "premium" in link_lower \
                or "archiv" in link_lower \
                or "sorteo" in link_lower \
                or "loter" in link_lower \
                or "newsletter" in link_lower \
                or "podcast" in link_lower \
                or "logout" in link_lower \
                or "login" in link_lower \
                or link.endswith(".html") \
                or "notifica" in link_lower \
                or "push" in link_lower \
                or "servicio" in link_lower \
                or "esquela" in link_lower \
                or "defunci" in link_lower \
                or "favorito" in link_lower \
                or "firma" in link_lower \
                or "suscri" in link_lower \
                or "subscrib" in link_lower \
                or "pasatiempo" in link_lower \
                or "compra" in link_lower \
                or "tienda" in link_lower \
                or "gráfico" in link_lower or "gráfico" in link_lower \
                or "humor" in link_lower \
                or "foto" in link_lower \
                or "opinion" in link_lower or "opinión" in link_lower \
                or "hemeroteca" in link_lower \
                or "video" in link_lower or "vídeo" in link_lower \
                or "play" in link_lower \
                or "patrocin" in link_lower \
                or "autor" in link_lower \
                or re.compile("\d{3,}").search(link):
                continue
            if not link.startswith(domain):
                link_parts = link.split("/")
                nodes = [x for x in link_parts if x][:2]
                if len(nodes) < 1:
                    continue
                # Get only urls with one node
                elif len(nodes) == 1 and link.startswith("/"):
                    link = domain_url[:-1] + link
            if not link.endswith("/"):
                link += "/"
            valid_links_complete.append(link)
        print(f"Valid links of {media_url}, {domain}, {domain_url}:", len(valid_links))
        all_sections.extend(valid_links_complete)
    valid_links_complete_unique = list(set(all_sections))
# Out:
# Reading file of urls of regions...
# Valid links of https://elpais.com, elpais.com, https://elpais.com/: 84
# Valid links of https://abc.es, www.abc.es, https://www.abc.es/: 37
# Valid links of https://lavanguardia.com, www.lavanguardia.com, https://www.lavanguardia.com/: 12
# Valid links of https://elespanol.com, www.elespanol.com, https://www.elespanol.com/: 56
# Valid links of https://elmundo.es, www.elmundo.es, https://www.elmundo.es/: 7
# Valid links of https://elperiodico.com, www.elperiodico.com, https://www.elperiodico.com/: 15
# Retry request with 'https://www.' prefix
# ok (200)
# Valid links of https://www.larazon.es, www.larazon.es, https://www.larazon.es/: 62
# Valid links of https://europapress.es, www.europapress.es, https://www.europapress.es/: 50
# Valid links of https://20minutos.es, www.20minutos.es, https://www.20minutos.es/: 7
# Valid links of https://elconfidencial.com, www.elconfidencial.com, https://www.elconfidencial.com/: 10
# Valid links of https://eldiario.es, www.eldiario.es, https://www.eldiario.es/: 6
# Valid links of https://sevilla.abc.es, sevilla.abc.es, https://sevilla.abc.es/: 60
# Valid links of https://lavozdegalicia.es, lavozdegalicia.es, https://lavozdegalicia.es/: 81
# Valid links of https://libertaddigital.com, www.libertaddigital.com, https://www.libertaddigital.com/: 2
# Valid links of https://cronicaglobal.elespanol.com, cronicaglobal.elespanol.com, https://cronicaglobal.elespanol.com/: 53
# Valid links of https://elcorreo.com, www.elcorreo.com, https://www.elcorreo.com/: 19
# Valid links of https://diariosur.es, www.diariosur.es, https://www.diariosur.es/: 17
# Valid links of https://diariodesevilla.es, www.diariodesevilla.es, https://www.diariodesevilla.es/: 178
# Valid links of https://diariovasco.com, www.diariovasco.com, https://www.diariovasco.com/: 18
# Valid links of https://huffingtonpost.es, www.huffingtonpost.es, https://www.huffingtonpost.es/: 39
# Valid links of https://levante-emv.com, www.levante-emv.com, https://www.levante-emv.com/: 114
# Valid links of https://lasprovincias.es, www.lasprovincias.es, https://www.lasprovincias.es/: 16
# Valid links of https://laverdad.es, www.laverdad.es, https://www.laverdad.es/: 22
# Valid links of https://heraldo.es, www.heraldo.es, https://www.heraldo.es/: 2
# Valid links of https://farodevigo.es, www.farodevigo.es, https://www.farodevigo.es/: 116
# Valid links of https://ideal.es, www.ideal.es, https://www.ideal.es/: 21
# Valid links of https://epe.es, www.epe.es, https://www.epe.es/: 8
# Valid links of https://publico.es, www.publico.es, https://www.publico.es/: 11
# Valid links of https://diariodemallorca.es, www.diariodemallorca.es, https://www.diariodemallorca.es/: 146
# Valid links of https://canarias7.es, www.canarias7.es, https://www.canarias7.es/: 23
# Valid links of https://lainformacion.com, www.lainformacion.com, https://www.lainformacion.com/: 6
# Valid links of https://okdiario.com, okdiario.com, https://okdiario.com/: 80
# Valid links of https://periodistadigital.com, www.periodistadigital.com, https://www.periodistadigital.com/: 260
# Retry request with 'https://www.' prefix
# ok (200)
# Valid links of https://www.deia.eus, www.deia.eus, https://www.deia.eus/: 163
# Valid links of https://elcomercio.es, www.elcomercio.es, https://www.elcomercio.es/: 21
# Valid links of https://hoy.es, www.hoy.es, https://www.hoy.es/: 33
# Valid links of https://lne.es, www.lne.es, https://www.lne.es/: 179
# Valid links of https://informacion.es, www.informacion.es, https://www.informacion.es/: 147
# Valid links of https://eldiariomontanes.es, www.eldiariomontanes.es, https://www.eldiariomontanes.es/: 16
# Valid links of https://diariodecadiz.es, www.diariodecadiz.es, https://www.diariodecadiz.es/: 163
# Valid links of https://larioja.com, www.larioja.com, https://www.larioja.com/: 16
# Valid links of https://republica.com, www.republica.com, https://www.republica.com/: 0
# Retry request with 'https://www.' prefix
# ok (200)
# Valid links of https://www.noticiasdenavarra.com, www.noticiasdenavarra.com, https://www.noticiasdenavarra.com/: 178
# Valid links of https://ultimahora.es, www.ultimahora.es, https://www.ultimahora.es/: 74
# Valid links of https://elplural.com, www.elplural.com, https://www.elplural.com/: 32
# Retry request with 'https://www.' prefix
# ok (200)
# Valid links of https://www.elcorreogallego.es, www.elcorreogallego.es, https://www.elcorreogallego.es/: 259
# Valid links of https://elperiodicodearagon.com, www.elperiodicodearagon.com, https://www.elperiodicodearagon.com/: 137
# Valid links of https://eldia.es, www.eldia.es, https://www.eldia.es/: 181
# Valid links of https://diariocordoba.com, www.diariocordoba.com, https://www.diariocordoba.com/: 137
# Retry request with 'https://www.' prefix
# ok (200)
# Valid links of https://www.elconfidencialdigital.com, www.elconfidencialdigital.com, https://www.elconfidencialdigital.com/: 26

# %%
len(all_sections), len(valid_links_complete_unique)
# Out:
# (1977, 742)

# %% [markdown]
# #### Analysis of medias nodes

# %%
urls_serie = pd.Series(valid_links_complete_unique)
urls_serie.head()
# Out:
# 0           https://www.levante-emv.com/en-valencia/
# 1                         https://www.abc.es/espana/
# 2              https://www.levante-emv.com/comarcas/
# 3    https://www.diariodesevilla.es/ana_s-_ameneiro/
# 4                  https://www.hoy.es/internacional/
# dtype: object

# %%
urls_no_https = urls_serie.str.extract("[/]{2}(?P<url>.*)[/]")
urls_no_https
# Out:
#                                         url
# 0           www.levante-emv.com/en-valencia
# 1                         www.abc.es/espana
# 2              www.levante-emv.com/comarcas
# 3    www.diariodesevilla.es/ana_s-_ameneiro
# 4                  www.hoy.es/internacional
# ..                                      ...
# 737              www.diariodecadiz.es/mundo
# 738                      www.abc.es/familia
# 739                 lavozdegalicia.es/lemos
# 740               www.elespanol.com/ciencia
# 741              www.diariodecadiz.es/motor
#
# [742 rows x 1 columns]

# %%
media_count = urls_no_https.value_counts()
media_count
# Out:
# url
# cronicaglobal.elespanol.com/business     1
# www.elplural.com/autonomias              1
# www.elperiodicodearagon.com/salud        1
# www.elperiodicodearagon.com/sd-huesca    1
# www.elperiodicodearagon.com/sociedad     1
#                                         ..
# www.diariodemallorca.es/blogs            1
# www.diariodemallorca.es/cultura          1
# www.diariodemallorca.es/deportes         1
# www.diariodemallorca.es/economia         1
# www.publico.es/public                    1
# Name: count, Length: 741, dtype: int64

# %%
n_min_counts = 2
media_nodes = urls_serie.str.replace("/{0,2}$", "", 
                                     regex=True). \
                         str.extract(".*/{1}(.*)", 
                                     expand=False)
media_nodes_count = media_nodes.value_counts()
media_nodes_count_more_2 = media_nodes_count[media_nodes_count > n_min_counts]
#media_nodes_more_2_relfreq = (media_nodes_count_more_2 / media_nodes_count_more_2.sum())
#media_nodes_more_2_relfreq_smooth4 = media_nodes_more_2_relfreq.rolling(window=4, min_periods=1).mean()

common_sections = media_nodes_count_more_2.index.tolist()
filter_final_section_urls = urls_serie.apply(lambda url: any(section in url for section in common_sections))
final_section_urls = urls_serie[filter_final_section_urls].str.extract("(?P<section>https?://(?P<media>[^/]+/).*)")
#final_section_urls_concat = final_section_urls.section + ";" + final_section_urls.media
#final_section_urls_concat
final_section_urls
# Out:
#                                    section                  media
# 1               https://www.abc.es/espana/            www.abc.es/
# 2    https://www.levante-emv.com/comarcas/   www.levante-emv.com/
# 4        https://www.hoy.es/internacional/            www.hoy.es/
# 5        https://www.deia.eus/promociones/          www.deia.eus/
# 6              https://www.lne.es/sucesos/            www.lne.es/
# ..                                     ...                    ...
# 734         https://www.eldia.es/sociedad/          www.eldia.es/
# 737    https://www.diariodecadiz.es/mundo/  www.diariodecadiz.es/
# 739       https://lavozdegalicia.es/lemos/     lavozdegalicia.es/
# 740     https://www.elespanol.com/ciencia/     www.elespanol.com/
# 741    https://www.diariodecadiz.es/motor/  www.diariodecadiz.es/
#
# [376 rows x 2 columns]

# %%
files_section = glob.glob("../data/final_url_sections_v*.csv")
if len(files_section) > 0:
    version_n = max(int(x.split("_")[-1][1:-4]) for x in files_section) + 1
else:
    version_n = 0
final_section_urls.to_csv(f"../data/final_url_sections_v{version_n}.csv", 
                          index=False, 
                          header=True,
                          sep=";"
                         )
glob.glob("../data/final_url_sections_v*.csv")
# Out:
# ['../data\\final_url_sections_v3.csv',
#  '../data\\final_url_sections_v4.csv',
#  '../data\\final_url_sections_v5.csv',
#  '../data\\final_url_sections_v6.csv',
#  '../data\\final_url_sections_v7.csv']

# %%
temp = final_section_urls.loc[final_section_urls["section"].str.contains("https")]
subchunks = temp["section"] + ";" + temp["media"]
subchunks.tolist()
# Out:
# ['https://www.elplural.com/sociedad/;www.elplural.com/',
#  'https://www.noticiasdenavarra.com/vivir/;www.noticiasdenavarra.com/',
#  'https://www.diariodesevilla.es/tecnologia/;www.diariodesevilla.es/',
#  'https://www.canarias7.es/cultura/;www.canarias7.es/',
#  'https://www.lavozdegalicia.es/andarmiudino/;www.lavozdegalicia.es/',
#  'https://www.farodevigo.es/medio-ambiente/;www.farodevigo.es/',
#  'https://www.deia.eus/deportes/;www.deia.eus/',
#  'https://www.lavozdegalicia.es/amarina/;www.lavozdegalicia.es/',
#  'https://www.diariodesevilla.es/andalucia/;www.diariodesevilla.es/',
#  'https://www.diariodecadiz.es/opinion/;www.diariodecadiz.es/',
#  'https://www.eldia.es/violencia-de-genero/;www.eldia.es/',
#  'https://www.diariodesevilla.es/salud/;www.diariodesevilla.es/',
#  'https://www.lavozdegalicia.es/galicia-economica/;www.lavozdegalicia.es/',
#  'https://www.diariodesevilla.es/mundo/;www.diariodesevilla.es/',
#  'https://www.diariocordoba.com/agricultura-medio-ambiente/;www.diariocordoba.com/',
#  'https://www.elcorreogallego.es/vida-y-estilo/;www.elcorreogallego.es/',
#  'https://www.lne.es/sociedad/;www.lne.es/',
#  'https://www.diariodecadiz.es/espana/;www.diariodecadiz.es/',
#  'https://www.lavozdegalicia.es/arousa/;www.lavozdegalicia.es/',
#  'https://www.elperiodicodearagon.com/tendencias21/;www.elperiodicodearagon.com/',
#  'https://www.levante-emv.com/ocio/;www.levante-emv.com/',
#  'https://www.elcorreo.com/antropia/;www.elcorreo.com/',
#  'https://www.elperiodicodearagon.com/motogp/;www.elperiodicodearagon.com/',
#  'https://www.hoy.es/internacional/;www.hoy.es/',
#  'https://www.lavozdegalicia.es/mercados/;www.lavozdegalicia.es/',
#  'https://www.farodevigo.es/sociedad/;www.farodevigo.es/',
#  'https://www.lavozdegalicia.es/somosagro/;www.lavozdegalicia.es/',
#  'https://www.diariocordoba.com/cultura/;www.diariocordoba.com/',
#  'https://www.lne.es/lo-ultimo/;www.lne.es/',
#  'https://www.lavozdegalicia.es/alsol/;www.lavozdegalicia.es/',
#  'https://www.lasprovincias.es/antropia/;www.lasprovincias.es/',
#  'https://www.diariocordoba.com/medio-ambiente/;www.diariocordoba.com/',
#  'https://www.deia.eus/vivir/;www.deia.eus/',
#  'https://www.lavozdegalicia.es/localidades/;www.lavozdegalicia.es/',
#  'https://www.abc.es/economia/;www.abc.es/',
#  'https://www.diariodesevilla.es/gente/;www.diariodesevilla.es/',
#  'https://www.sevilla.abc.es/tecnologia/;www.sevilla.abc.es/',
#  'https://www.informacion.es/opinion/;www.informacion.es/',
#  'https://www.diariodecadiz.es/mundo/;www.diariodecadiz.es/',
#  'https://www.huffingtonpost.es/politica/;www.huffingtonpost.es/',
#  'https://www.abc.es/cultura/;www.abc.es/',
#  'https://www.elperiodicodearagon.com/opinion/;www.elperiodicodearagon.com/',
#  'https://www.informacion.es/nacional/;www.informacion.es/']

# %%
CURRENT_DATE, CURRENT_TIME = str(datetime.today()).split(" ")
CURRENT_DATE, CURRENT_TIME
# Out:
# ('2023-08-22', '20:42:25.856657')

# %%
CURRENT_TIME.split(" ")[-1].split(".")[0].replace(":", "-")
# Out:
# '20-42-25'

# %%
def test1():
    temp = final_section_urls.loc[final_section_urls["section"].str.contains("https")]
    return temp.loc[:, "media"] + ";" + temp.loc[:, "section"]
def test2():
    return  final_section_urls.loc[final_section_urls["section"].str.contains("https"), "section"] + ";" + final_section_urls.loc[final_section_urls["section"].str.contains("https"), "media"]

# %%
# %timeit test1()
# %timeit test2()
# Out:
# 556 µs ± 8.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 749 µs ± 6.83 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Word similarity analysis

# %%
words = media_nodes.tolist()

# %%
processed = []
scores = {}
for w1 in tqdm.tqdm(words):
    processed.append(w1)
    for w2 in words:
        if w2 not in processed:
            scores[(w1, w2)] = edit_distance(w1, w2)
sorted_scores = sorted(scores.items(), key=lambda k: (k[0][0], k[1]), reverse=False)
sorted_scores = dict(sorted_scores)
sorted_scores
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 722/722 [00:16<00:00, 44.00it/s]
# {('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'la-cronica-de-ribera-alta-del-ebro'): 80,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'la-cronica-del-campo-de-carinena'): 81,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'la-cronica-del-campo-de-belchite'): 83,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'la-cronica-del-campo-de-borja'): 85,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'la-cronica-de-ejea-y-sus-pueblos'): 85,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'la-cronica-de-valdejalon'): 85,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'agricultura-medio-ambiente'): 85,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'cronica-del-centro'): 85,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'mundial-baloncesto'): 85,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'cuadernos-del-sur'): 85,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'fiestas-del-pilar'): 86,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'sucesos-tribunales'): 86,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'farmacias-guardia'): 87,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'cordoba-ciudad'): 87,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'comunicacion'): 88,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'el-telescopio'): 88,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'area-blanquiverde'): 88,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'polideportivo'): 88,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'fuera-de-foco'): 89,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'lacantera'): 89,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'autonomias'): 90,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'elplural-tv'): 90,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'concellos'): 90,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'sd-huesca'): 90,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'baloncesto'): 90,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'tren-cultura'): 91,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'real-zaragoza'): 91,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'cai-zaragoza'): 91,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'balonmano'): 91,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'cordoba'): 92,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'leequid'): 93,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'oxigena2'): 93,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'esports'): 93,
#  ('Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río',
#   'zaragoza'): 94,
#  ('Más de Información', 'comunicacion'): 13,
#  ('Más de Información', 'polideportivo'): 13,
#  ('Más de Información', 'tour-francia'): 14,
#  ('Más de Información', 'autonomias'): 14,
#  ('Más de Información', 'osasuna'): 15,
#  ('Más de Información', 'on-in'): 15,
#  ('Más de Información', 'fuera-de-foco'): 15,
#  ('Más de Información', 'elplural-tv'): 15,
#  ('Más de Información', 'oxigena2'): 15,
#  ('Más de Información', 'el-telescopio'): 15,
#  ('Más de Información', 'esports'): 15,
#  ('Más de Información', 'real-zaragoza'): 15,
#  ('Más de Información', 'sd-huesca'): 15,
#  ('Más de Información', 'cordoba'): 15,
#  ('Más de Información', 'balonmano'): 15,
#  ('Más de Información', 'lacantera'): 15,
#  ('Más de Información', 'pamplona'): 16,
#  ('Más de Información', 'tren-cultura'): 16,
#  ('Más de Información', 'leequid'): 16,
#  ('Más de Información', 'concellos'): 16,
#  ('Más de Información', 'zaragoza'): 16,
#  ('Más de Información', 'cai-zaragoza'): 16,
#  ('Más de Información', 'cordoba-ciudad'): 16,
#  ('Más de Información', 'cuadernos-del-sur'): 16,
#  ('Más de Información', 'buzon-del-lector'): 17,
#  ('Más de Información', 'farmacias-guardia'): 17,
#  ('Más de Información', 'baloncesto'): 17,
#  ('Más de Información', 'sucesos-tribunales'): 17,
#  ('Más de Información', 'area-blanquiverde'): 17,
#  ('Más de Información', 'mundial-baloncesto'): 17,
#  ('Más de Información', 'fiestas-del-pilar'): 18,
#  ('Más de Información', 'cronica-del-centro'): 18,
#  ('Más de Información', 'la-cronica-de-valdejalon'): 21,
#  ('Más de Información', 'agricultura-medio-ambiente'): 22,
#  ('Más de Información', 'la-cronica-del-campo-de-borja'): 26,
#  ('Más de Información', 'la-cronica-del-campo-de-carinena'): 26,
#  ('Más de Información', 'la-cronica-del-campo-de-belchite'): 27,
#  ('Más de Información', 'la-cronica-de-ejea-y-sus-pueblos'): 30,
#  ('Más de Información', 'la-cronica-de-ribera-alta-del-ebro'): 30,
#  ('Más de Información',
#   'Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río'): 85,
#  ('abceduca', 'faroeduca'): 3,
#  ('abceduca', 'coruna'): 5,
#  ('abceduca', 'arousa'): 5,
#  ('abceduca', 'almeria'): 5,
#  ('abceduca', 'amarina'): 6,
#  ('abceduca', 'deza'): 6,
#  ('abceduca', 'cdlugo'): 6,
#  ('abceduca', 'vida'): 6,
#  ('abceduca', 'bizkaia'): 6,
#  ('abceduca', 'alava'): 6,
#  ('abceduca', 'comics'): 6,
#  ('abceduca', 'ribera'): 6,
#  ('abceduca', 'mallorca'): 6,
#  ('abceduca', 'athletic'): 6,
#  ('abceduca', 'caceres'): 6,
#  ('abceduca', 'merida'): 6,
#  ('abceduca', 'oviedo'): 6,
#  ('abceduca', 'cuencas'): 6,
#  ('abceduca', 'cadiz'): 6,
#  ('abceduca', 'sierra'): 6,
#  ('abceduca', 'janda'): 6,
#  ('abceduca', 'cadizcf'): 6,
#  ('abceduca', 'elda'): 6,
#  ('abceduca', 'alcoy'): 6,
#  ('abceduca', 'elche-cf'): 6,
#  ('abceduca', 'osasuna'): 6,
#  ('abceduca', 'leequid'): 6,
#  ('abceduca', 'cordoba'): 6,
#  ('abceduca', 'alsol'): 7,
#  ('abceduca', 'barbanza'): 7,
#  ('abceduca', 'ferrol'): 7,
#  ('abceduca', 'lemos'): 7,
#  ('abceduca', 'lugo'): 7,
#  ('abceduca', 'ourense'): 7,
#  ('abceduca', 'tiempo'): 7,
#  ('abceduca', 'minegocio'): 7,
#  ('abceduca', 'mercados'): 7,
#  ('abceduca', 'fugas'): 7,
#  ('abceduca', 'yes'): 7,
#  ('abceduca', 'culemania'): 7,
#  ('abceduca', 'aljarafe'): 7,
#  ('abceduca', 'consumo'): 7,
#  ('abceduca', 'mascotas'): 7,
#  ('abceduca', 'formula1'): 7,
#  ('abceduca', 'ocio'): 7,
#  ('abceduca', 'cine'): 7,
#  ('abceduca', 'lopd'): 7,
#  ('abceduca', 'quienes'): 7,
#  ('abceduca', 'life'): 7,
#  ('abceduca', 'planeta'): 7,
#  ('abceduca', 'costera'): 7,
#  ('abceduca', 'marina'): 7,
#  ('abceduca', 'comarcas'): 7,
#  ('abceduca', 'horta'): 7,
#  ('abceduca', 'morvedre'): 7,
#  ('abceduca', 'realmurcia'): 7,
#  ('abceduca', 'granada'): 7,
#  ('abceduca', 'jaen'): 7,
#  ('abceduca', 'public'): 7,
#  ('abceduca', 'blogs'): 7,
#  ('abceduca', 'fnd'): 7,
#  ('abceduca', 'palma'): 7,
#  ('abceduca', 'bilbao'): 7,
#  ('abceduca', 'forum'): 7,
#  ('abceduca', 'culturas'): 7,
#  ('abceduca', 'badajoz'): 7,
#  ('abceduca', 'plasencia'): 7,
#  ('abceduca', 'ensalsa'): 7,
#  ('abceduca', 'agro'): 7,
#  ('abceduca', 'oriente'): 7,
#  ('abceduca', 'aviles'): 7,
#  ('abceduca', 'siero'): 7,
#  ('abceduca', 'llanera'): 7,
#  ('abceduca', 'occidente'): 7,
#  ('abceduca', 'verano'): 7,
#  ('abceduca', 'chiclana'): 7,
#  ('abceduca', 'bocabierta'): 7,
#  ('abceduca', 'elche'): 7,
#  ('abceduca', 'benidorm'): 7,
#  ('abceduca', 'alacanti'): 7,
#  ('abceduca', 'pamplona'): 7,
#  ('abceduca', 'concellos'): 7,
#  ('abceduca', 'zaragoza'): 7,
#  ('abceduca', 'sd-huesca'): 7,
#  ('abceduca', 'lacantera'): 7,
#  ('abceduca', 'gurme'): 8,
#  ('abceduca', 'somosmar'): 8,
#  ('abceduca', 'carballo'): 8,
#  ('abceduca', 'pontevedra'): 8,
#  ('abceduca', 'santiago'): 8,
#  ('abceduca', 'vigo'): 8,
#  ('abceduca', 'graficos'): 8,
#  ('abceduca', 'gradario'): 8,
#  ('abceduca', 'business'): 8,
#  ('abceduca', 'creacion'): 8,
#  ('abceduca', 'elrocio'): 8,
#  ('abceduca', 'agr_andalucia'): 8,
#  ('abceduca', 'wappissima'): 8,
#  ('abceduca', 'realbetis'): 8,
#  ('abceduca', 'delibros'): 8,
#  ('abceduca', 'mapademusicas'): 8,
#  ('abceduca', 'toros'): 8,
#  ('abceduca', 'vital'): 8,
#  ('abceduca', 'paz_madrid'): 8,
#  ('abceduca', 'm-_h'): 8,
#  ('abceduca', 'pantallas'): 8,
#  ('abceduca', 'virales'): 8,
#  ('abceduca', 'global'): 8,
#  ('abceduca', 'safor'): 8,
#  ('abceduca', 'levante-ud'): 8,
#  ('abceduca', 'motogp'): 8,
#  ('abceduca', 'comunitat'): 8,
#  ('abceduca', 'humor'): 8,
#  ('abceduca', 'mapaweb'): 8,
#  ('abceduca', 'buzzeando'): 8,
#  ('abceduca', 'vivir'): 8,
#  ('abceduca', 'actualidad'): 8,
#  ('abceduca', 'tendencias'): 8,
#  ('abceduca', 'gijon'): 8,
#  ('abceduca', 'sporting'): 8,
#  ('abceduca', 'concursos'): 8,
#  ('abceduca', 'elbalcon'): 8,
#  ('abceduca', 'elpuerto'): 8,
#  ('abceduca', 'rss.html'): 8,
#  ('abceduca', 'hercules-cf'): 8,
#  ('abceduca', 'hogueras'): 8,
#  ('abceduca', 'vega-baja'): 8,
#  ('abceduca', 'on-in'): 8,
#  ('abceduca', 'autonomias'): 8,
#  ('abceduca', 'oxigena2'): 8,
#  ('abceduca', 'esports'): 8,
#  ('abceduca', 'baloncesto'): 8,
#  ('abceduca', 'balonmano'): 8,
#  ('abceduca', 'localidades'): 9,
#  ('abceduca', 'somosagro'): 9,
#  ('abceduca', 'obituarios'): 9,
#  ('abceduca', 'oparacing'): 9,
#  ('abceduca', 'forzabreo'): 9,
#  ('abceduca', 'doshermanas'): 9,
#  ('abceduca', 'entrevistas'): 9,
#  ('abceduca', 'sevillafc'): 9,
#  ('abceduca', 'television'): 9,
#  ('abceduca', 'registrate'): 9,
#  ('abceduca', 'lo-ultimo'): 9,
#  ('abceduca', 'en-valencia'): 9,
#  ('abceduca', 'fccartagena'): 9,
#  ('abceduca', 'butlletins'): 9,
#  ('abceduca', 'gran-vigo'): 9,
#  ('abceduca', 'o-morrazo'): 9,
#  ('abceduca', 'part-forana'): 9,
#  ('abceduca', 'especiales'): 9,
#  ('abceduca', 'descobreix'): 9,
#  ('abceduca', 'asturianos'): 9,
#  ('abceduca', 'sanfernando'): 9,
#  ('abceduca', 'tren-cultura'): 9,
#  ('abceduca', 'andarmiudino'): 10,
#  ('abceduca', 'reto-digital'): 10,
#  ('abceduca', 'pensamiento'): 10,
#  ('abceduca', 'en-voz-baja'): 10,
#  ('abceduca', 'letraglobal'): 10,
#  ('abceduca', 'ultima-hora'): 10,
#  ('abceduca', 'semana_santa'): 10,
#  ('abceduca', 'luis_lastra'): 10,
#  ('abceduca', 'marc_gabernet'): 10,
#  ('abceduca', 'carlos_colon'): 10,
#  ('abceduca', 'carmen_camacho'): 10,
#  ('abceduca', 'tendencias21'): 10,
#  ('abceduca', 'promociones'): 10,
#  ('abceduca', 'rcd-mallorca'): 10,
#  ('abceduca', 'localizacion'): 10,
#  ('abceduca', 'distribucion'): 10,
#  ('abceduca', 'villaviciosa'): 10,
#  ('abceduca', 'real-oviedo'): 10,
#  ('abceduca', 'con-la-venia'): 10,
#  ('abceduca', 'puerto-real'): 10,
#  ('abceduca', 'tamara_garcia'): 10,
#  ('abceduca', 'tour-francia'): 10,
#  ('abceduca', 'comunicacion'): 10,
#  ('abceduca', 'fuera-de-foco'): 10,
#  ('abceduca', 'elplural-tv'): 10,
#  ('abceduca', 'cai-zaragoza'): 10,
#  ('abceduca', 'torremarathon'): 11,
#  ('abceduca', 'galicia-innova'): 11,
#  ('abceduca', 'rastrodelafama'): 11,
#  ('abceduca', 'motociclismo'): 11,
#  ('abceduca', 'artes_plasticas'): 11,
#  ('abceduca', 'vida-y-estilo'): 11,
#  ('abceduca', 'carlos-alcaraz'): 11,
#  ('abceduca', 'celta-de-vigo'): 11,
#  ('abceduca', 'gente-estilo'): 11,
#  ('abceduca', 'prov-badajoz'): 11,
#  ('abceduca', 'prov-caceres'): 11,
#  ('abceduca', 'asturias-rural'): 11,
#  ('abceduca', 'vivir_en_cadiz'): 11,
#  ('abceduca', 'baix-vinalopo'): 11,
#  ('abceduca', 'el-telescopio'): 11,
#  ('abceduca', 'real-zaragoza'): 11,
#  ('abceduca', 'cordoba-ciudad'): 11,
#  ('abceduca', 'galicia-economica'): 12,
#  ('abceduca', 'futbolgallego'): 12,
#  ('abceduca', 'motor-gallego'): 12,
#  ('abceduca', 'cronica-directo'): 12,
#  ('abceduca', 'vivirensevilla'): 12,
#  ('abceduca', 'feria_de_abril'): 12,
#  ('abceduca', 'medio-ambiente'): 12,
#  ('abceduca', 'festivaldecine'): 12,
#  ('abceduca', 'gastronomia-c7'): 12,
#  ('abceduca', 'tv-espectaculos'): 12,
#  ('abceduca', 'polideportivo'): 12,
#  ('abceduca', 'primeras-planas'): 13,
#  ('abceduca', 'alcala_de_guadaira'): 13,
#  ('abceduca', 'empresas-al-dia'): 13,
#  ('abceduca', 'susana_c-_gomez'): 13,
#  ('abceduca', 'centenario-celta'): 13,
#  ('abceduca', 'portadas-del-dia'): 13,
#  ('abceduca', 'costa-noroeste'): 13,
#  ('abceduca', 'julio_gonzalez'): 13,
#  ('abceduca', 'teresa_almendros'): 13,
#  ('abceduca', 'farmacias-guardia'): 13,
#  ('abceduca', 'juzgado_de_guardia'): 14,
#  ('abceduca', 'galerias_graficas'): 14,
#  ('abceduca', 'buzon-del-lector'): 14,
#  ('abceduca', 'fiestas-del-pilar'): 14,
#  ('abceduca', 'sucesos-tribunales'): 14,
#  ('abceduca', 'area-blanquiverde'): 14,
#  ('abceduca', 'alfinaldelapalmera'): 15,
#  ('abceduca', 'orgullodenervion'): 15,
#  ('abceduca', 'diario_del_carnaval'): 15,
#  ('abceduca', 'j-m-_sanchez_reyes'): 15,
#  ('abceduca', 'francisco_zambrano'): 15,
#  ('abceduca', 'violencia-machista'): 15,
#  ('abceduca', 'cronica-del-centro'): 15,
#  ('abceduca', 'mundial-baloncesto'): 15,
#  ('abceduca', 'cuadernos-del-sur'): 15,
#  ('abceduca', 'historias-visuales'): 16,
#  ('abceduca', 'jose_miguel_carrasco'): 16,
#  ('abceduca', 'finanzas-personales'): 16,
#  ('abceduca', 'Más de Información'): 16,
#  ('abceduca', 'juan_antonio_solis'): 17,
#  ('abceduca', 'redaccion_grupo_joly'): 17,
#  ('abceduca', 'jose_ignacio_rufino'): 17,
#  ('abceduca', 'ignacio_f-_garmendia'): 17,
#  ('abceduca', 'fernando_perez_avila'): 17,
#  ('abceduca', 'violencia-de-genero'): 17,
#  ('abceduca', 'cristobal_perdigones'): 17,
#  ('abceduca', 'la-cronica-de-alacanti'): 17,
#  ('abceduca', 'guia_de_concesionarios'): 18,
#  ('abceduca', 'deza-tabeiros-montes'): 18,
#  ('abceduca', 'trabajos-de-impresion'): 18,
#  ('abceduca', 'arturo_rivera_barrera'): 18,
#  ('abceduca', 'resultados_deportivos'): 19,
#  ('abceduca', 'suplementotecnologico'): 19,
#  ('abceduca', 'enrique-garcia-maiquez'): 19,
#  ('abceduca', 'la-cronica-de-valdejalon'): 19,
#  ('abceduca', 'con_cuchillo_y_tenedor'): 20,
#  ('abceduca', 'noticias-provincia-cadiz'): 20,
#  ('abceduca', 'julia_alarcon_villanueva'): 20,
#  ('abceduca', 'promociones-faro-de-vigo'): 21,
#  ('abceduca', 'agricultura-medio-ambiente'): 21,
#  ('abceduca', 'la-cronica-barrios-alicante'): 23,
#  ('abceduca', 'clubpd.periodistadigital.com'): 24,
#  ('abceduca', 'rutas-senderismo-por-asturias'): 24,
#  ('abceduca', 'la-cronica-del-campo-de-borja'): 24,
#  ('abceduca', 'la-cronica-del-campo-de-carinena'): 26,
#  ('abceduca', 'la-cronica-del-campo-de-belchite'): 27,
#  ('abceduca', 'la-cronica-de-ejea-y-sus-pueblos'): 28,
#  ('abceduca', 'la-cronica-de-ribera-alta-del-ebro'): 30,
#  ('abceduca',
#   'Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río'): 92,
#  ('actualidad', 'culturas'): 7,
#  ('actualidad', 'merida'): 7,
#  ('actualidad', 'ensalsa'): 7,
#  ('actualidad', 'cuencas'): 7,
#  ('actualidad', 'asturianos'): 7,
#  ('actualidad', 'cadiz'): 7,
#  ('actualidad', 'chiclana'): 7,
#  ('actualidad', 'janda'): 7,
#  ('actualidad', 'cadizcf'): 7,
#  ('actualidad', 'elda'): 7,
#  ('actualidad', 'autonomias'): 7,
#  ('actualidad', 'caceres'): 8,
#  ('actualidad', 'aviles'): 8,
#  ('actualidad', 'llanera'): 8,
#  ('actualidad', 'elbalcon'): 8,
#  ('actualidad', 'alcoy'): 8,
#  ('actualidad', 'hogueras'): 8,
#  ('actualidad', 'alacanti'): 8,
#  ('actualidad', 'osasuna'): 8,
#  ('actualidad', 'pamplona'): 8,
#  ('actualidad', 'leequid'): 8,
#  ('actualidad', 'zaragoza'): 8,
#  ('actualidad', 'cordoba'): 8,
#  ('actualidad', 'lacantera'): 8,
#  ('actualidad', 'tendencias'): 9,
#  ('actualidad', 'forum'): 9,
#  ('actualidad', 'badajoz'): 9,
#  ('actualidad', 'plasencia'): 9,
#  ('actualidad', 'agro'): 9,
#  ('actualidad', 'gijon'): 9,
#  ('actualidad', 'oviedo'): 9,
#  ('actualidad', 'siero'): 9,
#  ('actualidad', 'sporting'): 9,
#  ('actualidad', 'occidente'): 9,
#  ('actualidad', 'verano'): 9,
#  ('actualidad', 'concursos'): 9,
#  ('actualidad', 'asturias-rural'): 9,
#  ('actualidad', 'elpuerto'): 9,
#  ('actualidad', 'sierra'): 9,
#  ('actualidad', 'bocabierta'): 9,
#  ('actualidad', 'elche'): 9,
#  ('actualidad', 'benidorm'): 9,
#  ('actualidad', 'vega-baja'): 9,
#  ('actualidad', 'on-in'): 9,
#  ('actualidad', 'elplural-tv'): 9,
#  ('actualidad', 'oxigena2'): 9,
#  ('actualidad', 'concellos'): 9,
#  ('actualidad', 'sd-huesca'): 9,
#  ('actualidad', 'cordoba-ciudad'): 9,
#  ('actualidad', 'balonmano'): 9,
#  ('actualidad', 'descobreix'): 10,
#  ('actualidad', 'prov-badajoz'): 10,
#  ('actualidad', 'oriente'): 10,
#  ('actualidad', 'villaviciosa'): 10,
#  ('actualidad', 'real-oviedo'): 10,
#  ('actualidad', 'sanfernando'): 10,
#  ('actualidad', 'puerto-real'): 10,
#  ('actualidad', 'rss.html'): 10,
#  ('actualidad', 'elche-cf'): 10,
#  ('actualidad', 'hercules-cf'): 10,
#  ('actualidad', 'comunicacion'): 10,
#  ('actualidad', 'esports'): 10,
#  ('actualidad', 'cai-zaragoza'): 10,
#  ('actualidad', 'baloncesto'): 10,
#  ('actualidad', 'distribucion'): 11,
#  ('actualidad', 'prov-caceres'): 11,
#  ('actualidad', 'con-la-venia'): 11,
#  ('actualidad', 'tamara_garcia'): 11,
#  ('actualidad', 'baix-vinalopo'): 11,
#  ('actualidad', 'tour-francia'): 11,
#  ('actualidad', 'tren-cultura'): 11,
#  ('actualidad', 'real-zaragoza'): 11,
#  ('actualidad', 'portadas-del-dia'): 12,
#  ('actualidad', 'vivir_en_cadiz'): 12,
#  ('actualidad', 'fuera-de-foco'): 12,
#  ('actualidad', 'el-telescopio'): 12,
#  ('actualidad', 'tv-espectaculos'): 13,
#  ('actualidad', 'costa-noroeste'): 13,
#  ('actualidad', 'julio_gonzalez'): 13,
#  ('actualidad', 'teresa_almendros'): 13,
#  ('actualidad', 'farmacias-guardia'): 13,
#  ('actualidad', 'fiestas-del-pilar'): 13,
#  ('actualidad', 'area-blanquiverde'): 13,
#  ('actualidad', 'polideportivo'): 13,
#  ('actualidad', 'francisco_zambrano'): 14,
#  ('actualidad', 'violencia-machista'): 15,
#  ('actualidad', 'buzon-del-lector'): 15,
#  ('actualidad', 'sucesos-tribunales'): 15,
#  ('actualidad', 'mundial-baloncesto'): 15,
#  ('actualidad', 'cuadernos-del-sur'): 15,
#  ('actualidad', 'diario_del_carnaval'): 16,
#  ('actualidad', 'cristobal_perdigones'): 16,
#  ('actualidad', 'j-m-_sanchez_reyes'): 16,
#  ('actualidad', 'arturo_rivera_barrera'): 16,
#  ('actualidad', 'cronica-del-centro'): 16,
#  ('actualidad', 'finanzas-personales'): 17,
#  ('actualidad', 'la-cronica-de-alacanti'): 17,
#  ('actualidad', 'Más de Información'): 17,
#  ('actualidad', 'trabajos-de-impresion'): 19,
#  ('actualidad', 'noticias-provincia-cadiz'): 19,
#  ('actualidad', 'la-cronica-de-valdejalon'): 19,
#  ('actualidad', 'agricultura-medio-ambiente'): 19,
#  ('actualidad', 'julia_alarcon_villanueva'): 20,
#  ('actualidad', 'la-cronica-barrios-alicante'): 21,
#  ('actualidad', 'la-cronica-del-campo-de-borja'): 23,
#  ('actualidad', 'rutas-senderismo-por-asturias'): 26,
#  ('actualidad', 'la-cronica-del-campo-de-belchite'): 26,
#  ('actualidad', 'la-cronica-del-campo-de-carinena'): 26,
#  ('actualidad', 'la-cronica-de-ejea-y-sus-pueblos'): 28,
#  ('actualidad', 'la-cronica-de-ribera-alta-del-ebro'): 28,
#  ('actualidad',
#   'Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río'): 89,
#  ('agr_andalucia', 'granada'): 7,
#  ('agr_andalucia', 'realmurcia'): 8,
#  ('agr_andalucia', 'faroeduca'): 8,
#  ('agr_andalucia', 'tamara_garcia'): 8,
#  ('agr_andalucia', 'pantallas'): 9,
#  ('agr_andalucia', 'en-valencia'): 9,
#  ('agr_andalucia', 'gran-vigo'): 9,
#  ('agr_andalucia', 'tendencias'): 9,
#  ('agr_andalucia', 'plasencia'): 9,
#  ('agr_andalucia', 'ensalsa'): 9,
#  ('agr_andalucia', 'janda'): 9,
#  ('agr_andalucia', 'alacanti'): 9,
#  ('agr_andalucia', 'tour-francia'): 9,
#  ('agr_andalucia', 'realbetis'): 10,
#  ('agr_andalucia', 'mapademusicas'): 10,
#  ('agr_andalucia', 'carmen_camacho'): 10,
#  ('agr_andalucia', 'paz_madrid'): 10,
#  ('agr_andalucia', 'virales'): 10,
#  ('agr_andalucia', 'global'): 10,
#  ('agr_andalucia', 'planeta'): 10,
#  ('agr_andalucia', 'marina'): 10,
#  ('agr_andalucia', 'levante-ud'): 10,
#  ('agr_andalucia', 'fccartagena'): 10,
#  ('agr_andalucia', 'carlos-alcaraz'): 10,
#  ('agr_andalucia', 'almeria'): 10,
#  ('agr_andalucia', 'palma'): 10,
#  ('agr_andalucia', 'rcd-mallorca'): 10,
#  ('agr_andalucia', 'mallorca'): 10,
#  ('agr_andalucia', 'athletic'): 10,
#  ('agr_andalucia', 'actualidad'): 10,
#  ('agr_andalucia', 'badajoz'): 10,
#  ('agr_andalucia', 'merida'): 10,
#  ('agr_andalucia', 'agro'): 10,
#  ('agr_andalucia', 'llanera'): 10,
#  ('agr_andalucia', 'verano'): 10,
#  ('agr_andalucia', 'portadas-del-dia'): 10,
#  ('agr_andalucia', 'cadiz'): 10,
#  ('agr_andalucia', 'elbalcon'): 10,
#  ('agr_andalucia', 'cadizcf'): 10,
#  ('agr_andalucia', 'alcoy'): 10,
#  ('agr_andalucia', 'vega-baja'): 10,
#  ('agr_andalucia', 'osasuna'): 10,
#  ('agr_andalucia', 'pamplona'): 10,
#  ('agr_andalucia', 'autonomias'): 10,
#  ('agr_andalucia', 'tren-cultura'): 10,
#  ('agr_andalucia', 'zaragoza'): 10,
#  ('agr_andalucia', 'cai-zaragoza'): 10,
#  ('agr_andalucia', 'cordoba'): 10,
#  ('agr_andalucia', 'lacantera'): 10,
#  ('agr_andalucia', 'wappissima'): 11,
#  ('agr_andalucia', 'sevillafc'): 11,
#  ('agr_andalucia', 'formula1'): 11,
#  ('agr_andalucia', 'ocio'): 11,
#  ('agr_andalucia', 'artes_plasticas'): 11,
#  ('agr_andalucia', 'vital'): 11,
#  ('agr_andalucia', 'festivaldecine'): 11,
#  ('agr_andalucia', 'luis_lastra'): 11,
#  ('agr_andalucia', 'ribera'): 11,
#  ('agr_andalucia', 'comarcas'): 11,
#  ('agr_andalucia', 'horta'): 11,
#  ('agr_andalucia', 'morvedre'): 11,
#  ('agr_andalucia', 'tendencias21'): 11,
#  ('agr_andalucia', 'celta-de-vigo'): 11,
#  ('agr_andalucia', 'public'): 11,
#  ('agr_andalucia', 'mapaweb'): 11,
#  ('agr_andalucia', 'fnd'): 11,
#  ('agr_andalucia', 'part-forana'): 11,
#  ('agr_andalucia', 'buzzeando'): 11,
#  ('agr_andalucia', 'especiales'): 11,
#  ('agr_andalucia', 'localizacion'): 11,
#  ('agr_andalucia', 'distribucion'): 11,
#  ('agr_andalucia', 'forum'): 11,
#  ('agr_andalucia', 'prov-badajoz'): 11,
#  ('agr_andalucia', 'prov-caceres'): 11,
#  ('agr_andalucia', 'oriente'): 11,
#  ('agr_andalucia', 'gijon'): 11,
#  ('agr_andalucia', 'aviles'): 11,
#  ('agr_andalucia', 'cuencas'): 11,
#  ('agr_andalucia', 'villaviciosa'): 11,
#  ('agr_andalucia', 'real-oviedo'): 11,
#  ('agr_andalucia', 'asturianos'): 11,
#  ('agr_andalucia', 'asturias-rural'): 11,
#  ('agr_andalucia', 'con-la-venia'): 11,
#  ('agr_andalucia', 'vivir_en_cadiz'): 11,
#  ('agr_andalucia', 'sanfernando'): 11,
#  ('agr_andalucia', 'chiclana'): 11,
#  ('agr_andalucia', 'bocabierta'): 11,
#  ('agr_andalucia', 'baix-vinalopo'): 11,
#  ('agr_andalucia', 'elche'): 11,
#  ('agr_andalucia', 'elda'): 11,
#  ('agr_andalucia', 'hercules-cf'): 11,
#  ('agr_andalucia', 'on-in'): 11,
#  ('agr_andalucia', 'comunicacion'): 11,
#  ('agr_andalucia', 'fuera-de-foco'): 11,
#  ('agr_andalucia', 'elplural-tv'): 11,
#  ('agr_andalucia', 'leequid'): 11,
#  ('agr_andalucia', 'oxigena2'): 11,
#  ('agr_andalucia', 'concellos'): 11,
#  ('agr_andalucia', 'farmacias-guardia'): 11,
#  ('agr_andalucia', 'real-zaragoza'): 11,
#  ('agr_andalucia', 'sd-huesca'): 11,
#  ('agr_andalucia', 'cordoba-ciudad'): 11,
#  ('agr_andalucia', 'balonmano'): 11,
#  ('agr_andalucia', 'mascotas'): 12,
#  ('agr_andalucia', 'motociclismo'): 12,
#  ('agr_andalucia', 'cine'): 12,
#  ('agr_andalucia', 'delibros'): 12,
#  ('agr_andalucia', 'comics'): 12,
#  ('agr_andalucia', 'toros'): 12,
#  ('agr_andalucia', 'galerias_graficas'): 12,
#  ('agr_andalucia', 'marc_gabernet'): 12,
#  ('agr_andalucia', 'carlos_colon'): 12,
#  ('agr_andalucia', 'm-_h'): 12,
#  ('agr_andalucia', 'registrate'): 12,
#  ('agr_andalucia', 'lopd'): 12,
#  ('agr_andalucia', 'quienes'): 12,
#  ('agr_andalucia', 'life'): 12,
#  ('agr_andalucia', 'lo-ultimo'): 12,
#  ('agr_andalucia', 'safor'): 12,
#  ('agr_andalucia', 'costera'): 12,
#  ('agr_andalucia', 'vida-y-estilo'): 12,
#  ('agr_andalucia', 'comunitat'): 12,
#  ('agr_andalucia', 'butlletins'): 12,
#  ('agr_andalucia', 'o-morrazo'): 12,
#  ('agr_andalucia', 'humor'): 12,
#  ('agr_andalucia', 'promociones'): 12,
#  ('agr_andalucia', 'jaen'): 12,
#  ('agr_andalucia', 'blogs'): 12,
#  ('agr_andalucia', 'vivir'): 12,
#  ('agr_andalucia', 'gastronomia-c7'): 12,
#  ('agr_andalucia', 'gente-estilo'): 12,
#  ('agr_andalucia', 'bilbao'): 12,
#  ('agr_andalucia', 'descobreix'): 12,
#  ('agr_andalucia', 'culturas'): 12,
#  ('agr_andalucia', 'caceres'): 12,
#  ('agr_andalucia', 'oviedo'): 12,
#  ('agr_andalucia', 'sporting'): 12,
#  ('agr_andalucia', 'occidente'): 12,
#  ('agr_andalucia', 'concursos'): 12,
#  ('agr_andalucia', 'puerto-real'): 12,
#  ('agr_andalucia', 'sierra'): 12,
#  ('agr_andalucia', 'costa-noroeste'): 12,
#  ('agr_andalucia', 'julio_gonzalez'): 12,
#  ('agr_andalucia', 'rss.html'): 12,
#  ('agr_andalucia', 'benidorm'): 12,
#  ('agr_andalucia', 'elche-cf'): 12,
#  ('agr_andalucia', 'hogueras'): 12,
#  ('agr_andalucia', 'el-telescopio'): 12,
#  ('agr_andalucia', 'fiestas-del-pilar'): 12,
#  ('agr_andalucia', 'baloncesto'): 12,
#  ('agr_andalucia', 'television'): 13,
#  ('agr_andalucia', 'motogp'): 13,
#  ('agr_andalucia', 'centenario-celta'): 13,
#  ('agr_andalucia', 'siero'): 13,
#  ('agr_andalucia', 'tv-espectaculos'): 13,
#  ('agr_andalucia', 'elpuerto'): 13,
#  ('agr_andalucia', 'teresa_almendros'): 13,
#  ('agr_andalucia', 'violencia-machista'): 13,
#  ('agr_andalucia', 'buzon-del-lector'): 13,
#  ('agr_andalucia', 'esports'): 13,
#  ('agr_andalucia', 'area-blanquiverde'): 13,
#  ('agr_andalucia', 'polideportivo'): 13,
#  ('agr_andalucia', 'cuadernos-del-sur'): 13,
#  ('agr_andalucia', 'medio-ambiente'): 14,
#  ('agr_andalucia', 'juan_antonio_solis'): 14,
#  ('agr_andalucia', 'susana_c-_gomez'): 14,
#  ('agr_andalucia', 'fernando_perez_avila'): 14,
#  ('agr_andalucia', 'diario_del_carnaval'): 14,
#  ('agr_andalucia', 'cronica-del-centro'): 14,
#  ('agr_andalucia', 'mundial-baloncesto'): 14,
#  ('agr_andalucia', 'jose_ignacio_rufino'): 15,
#  ('agr_andalucia', 'ignacio_f-_garmendia'): 15,
#  ('agr_andalucia', 'j-m-_sanchez_reyes'): 15,
#  ('agr_andalucia', 'arturo_rivera_barrera'): 15,
#  ('agr_andalucia', 'la-cronica-de-alacanti'): 15,
#  ('agr_andalucia', 'Más de Información'): 15,
#  ('agr_andalucia', 'jose_miguel_carrasco'): 16,
#  ('agr_andalucia', 'francisco_zambrano'): 16,
#  ('agr_andalucia', 'finanzas-personales'): 16,
#  ('agr_andalucia', 'redaccion_grupo_joly'): 17,
#  ('agr_andalucia', 'guia_de_concesionarios'): 17,
#  ('agr_andalucia', 'violencia-de-genero'): 17,
#  ('agr_andalucia', 'cristobal_perdigones'): 17,
#  ('agr_andalucia', 'la-cronica-de-valdejalon'): 17,
#  ('agr_andalucia', 'sucesos-tribunales'): 17,
#  ('agr_andalucia', 'resultados_deportivos'): 18,
#  ('agr_andalucia', 'suplementotecnologico'): 18,
#  ('agr_andalucia', 'enrique-garcia-maiquez'): 18,
#  ('agr_andalucia', 'trabajos-de-impresion'): 18,
#  ('agr_andalucia', 'julia_alarcon_villanueva'): 18,
#  ('agr_andalucia', 'deza-tabeiros-montes'): 19,
#  ('agr_andalucia', 'noticias-provincia-cadiz'): 19,
#  ('agr_andalucia', 'con_cuchillo_y_tenedor'): 20,
#  ('agr_andalucia', 'agricultura-medio-ambiente'): 20,
#  ('agr_andalucia', 'promociones-faro-de-vigo'): 21,
#  ('agr_andalucia', 'la-cronica-barrios-alicante'): 21,
#  ('agr_andalucia', 'rutas-senderismo-por-asturias'): 22,
#  ('agr_andalucia', 'la-cronica-del-campo-de-borja'): 22,
#  ('agr_andalucia', 'clubpd.periodistadigital.com'): 23,
#  ('agr_andalucia', 'la-cronica-del-campo-de-carinena'): 24,
#  ('agr_andalucia', 'la-cronica-del-campo-de-belchite'): 25,
#  ('agr_andalucia', 'la-cronica-de-ejea-y-sus-pueblos'): 26,
#  ('agr_andalucia', 'la-cronica-de-ribera-alta-del-ebro'): 28,
#  ('agr_andalucia',
#   'Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río'): 89,
#  ('agricultura-medio-ambiente', 'cronica-del-centro'): 19,
#  ('agricultura-medio-ambiente', 'mundial-baloncesto'): 21,
#  ('agricultura-medio-ambiente', 'cuadernos-del-sur'): 21,
#  ('agricultura-medio-ambiente', 'polideportivo'): 22,
#  ('agricultura-medio-ambiente', 'balonmano'): 22,
#  ('agricultura-medio-ambiente', 'lacantera'): 22,
#  ('agro', 'siero'): 3,
#  ('agro', 'alcoy'): 3,
#  ('agro', 'gijon'): 4,
#  ('agro', 'verano'): 4,
#  ('agro', 'cadiz'): 4,
#  ('agro', 'janda'): 4,
#  ('agro', 'elda'): 4,
#  ('agro', 'oviedo'): 5,
#  ('agro', 'aviles'): 5,
#  ('agro', 'llanera'): 5,
#  ('agro', 'sierra'): 5,
#  ('agro', 'elche'): 5,
#  ('agro', 'on-in'): 5,
#  ('agro', 'cordoba'): 5,
#  ('agro', 'elbalcon'): 6,
#  ('agro', 'elpuerto'): 6,
#  ('agro', 'cadizcf'): 6,
#  ('agro', 'hogueras'): 6,
#  ('agro', 'osasuna'): 6,
#  ('agro', 'pamplona'): 6,
#  ('agro', 'esports'): 6,
#  ('agro', 'zaragoza'): 6,
#  ('agro', 'oriente'): 7,
#  ('agro', 'cuencas'): 7,
#  ('agro', 'sporting'): 7,
#  ('agro', 'concursos'): 7,
#  ('agro', 'asturianos'): 7,
#  ('agro', 'benidorm'): 7,
#  ('agro', 'alacanti'): 7,
#  ('agro', 'leequid'): 7,
#  ('agro', 'oxigena2'): 7,
#  ('agro', 'balonmano'): 7,
#  ('agro', 'lacantera'): 7,
#  ('agro', 'sanfernando'): 8,
#  ('agro', 'chiclana'): 8,
#  ('agro', 'bocabierta'): 8,
#  ('agro', 'rss.html'): 8,
#  ('agro', 'elche-cf'): 8,
#  ('agro', 'vega-baja'): 8,
#  ('agro', 'autonomias'): 8,
#  ('agro', 'concellos'): 8,
#  ('agro', 'baloncesto'): 8,
#  ('agro', 'real-oviedo'): 9,
#  ('agro', 'occidente'): 9,
#  ('agro', 'puerto-real'): 9,
#  ('agro', 'sd-huesca'): 9,
#  ('agro', 'cai-zaragoza'): 9,
#  ('agro', 'villaviciosa'): 10,
#  ('agro', 'tamara_garcia'): 10,
#  ('agro', 'hercules-cf'): 10,
#  ('agro', 'comunicacion'): 10,
#  ('agro', 'elplural-tv'): 10,
#  ('agro', 'real-zaragoza'): 10,
#  ('agro', 'con-la-venia'): 11,
#  ('agro', 'costa-noroeste'): 11,
#  ('agro', 'baix-vinalopo'): 11,
#  ('agro', 'tour-francia'): 11,
#  ('agro', 'fuera-de-foco'): 11,
#  ('agro', 'tren-cultura'): 11,
#  ('agro', 'polideportivo'): 11,
#  ('agro', 'asturias-rural'): 12,
#  ('agro', 'el-telescopio'): 12,
#  ('agro', 'cordoba-ciudad'): 12,
#  ('agro', 'tv-espectaculos'): 13,
#  ('agro', 'vivir_en_cadiz'): 13,
#  ('agro', 'julio_gonzalez'): 13,
#  ('agro', 'teresa_almendros'): 13,
#  ('agro', 'farmacias-guardia'): 14,
#  ('agro', 'cuadernos-del-sur'): 14,
#  ('agro', 'portadas-del-dia'): 15,
#  ('agro', 'francisco_zambrano'): 15,
#  ('agro', 'buzon-del-lector'): 15,
#  ('agro', 'area-blanquiverde'): 15,
#  ('agro', 'cronica-del-centro'): 15,
#  ('agro', 'j-m-_sanchez_reyes'): 16,
#  ('agro', 'finanzas-personales'): 16,
#  ('agro', 'fiestas-del-pilar'): 16,
#  ('agro', 'mundial-baloncesto'): 16,
#  ('agro', 'diario_del_carnaval'): 17,
#  ('agro', 'cristobal_perdigones'): 17,
#  ('agro', 'violencia-machista'): 17,
#  ('agro', 'Más de Información'): 17,
#  ('agro', 'sucesos-tribunales'): 17,
#  ('agro', 'arturo_rivera_barrera'): 18,
#  ('agro', 'la-cronica-de-alacanti'): 19,
#  ('agro', 'noticias-provincia-cadiz'): 21,
#  ('agro', 'julia_alarcon_villanueva'): 21,
#  ('agro', 'la-cronica-de-valdejalon'): 21,
#  ('agro', 'agricultura-medio-ambiente'): 22,
#  ('agro', 'la-cronica-barrios-alicante'): 24,
#  ('agro', 'la-cronica-del-campo-de-borja'): 26,
#  ('agro', 'la-cronica-del-campo-de-belchite'): 29,
#  ('agro', 'la-cronica-del-campo-de-carinena'): 29,
#  ('agro', 'la-cronica-de-ejea-y-sus-pueblos'): 29,
#  ('agro', 'la-cronica-de-ribera-alta-del-ebro'): 31,
#  ('agro',
#   'Denuncian que Ayuso y Almeida han falsificado documentos en las obras de la estación de Madrid Río'): 95,
#  ('agronoma', 'arousa'): 4,
#  ('agronoma', 'granada'): 4,
#  ('agronoma', 'agro'): 4,
#  ('agronoma', 'autonomias'): 4,
#  ('agronoma', 'coruna'): 5,
#  ('agronoma', 'amarina'): 5,
#  ('agronoma', 'marina'): 5,
#  ('agronoma', 'verano'): 5,
#  ('agronoma', 'zaragoza'): 5,
#  ('agronoma', 'cordoba'): 5,
#  ('agronoma', 'abceduca'): 6,
#  ('agronoma', 'gurme'): 6,
#  ('agronoma', 'somosmar'): 6,
#  ('agronoma', 'alsol'): 6,
#  ('agronoma', 'barbanza'): 6,
#  ('agronoma', 'ferrol'): 6,
#  ('agronoma', 'ourense'): 6,
#  ('agronoma', 'alava'): 6,
#  ('agronoma', 'elrocio'): 6,
#  ('agronoma', 'consumo'): 6,
#  ('agronoma', 'toros'): 6,
#  ('agronoma', 'global'): 6,
#  ('agronoma', 'planeta'): 6,
#  ('agronoma', 'ribera'): 6,
#  ('agronoma', 'horta'): 6,
#  ('agronoma', 'motogp'): 6,
#  ('agronoma', 'faroeduca'): 6,
#  ('agronoma', 'almeria'): 6,
#  ('agronoma', 'palma'): 6,
#  ('agronoma', 'mallorca'): 6,
#  ('agronoma', 'forum'): 6,
#  ('agronoma', 'merida'): 6,
#  ('agronoma', 'gijon'): 6,
#  ('agronoma', 'llanera'): 6,
#  ('agronoma', 'janda'): 6,
#  ('agronoma', 'alcoy'): 6,
#  ('agronoma', 'pamplona'): 6,
#  ('agronoma', 'on-in'): 6,
#  ('agronoma', 'balonmano'): 6,
#  ('agronoma', 'carballo'): 7,
#  ('agronoma', 'deza'): 7,
#  ('agronoma', 'lemos'): 7,
#  ('agronoma', 'lugo'): 7,
#  ('agronoma', 'vigo'): 7,
#  ('agronoma', 'graficos'): 7,
#  ('agronoma', 'tiempo'): 7,
#  ('agronoma', 'gradario'): 7,
#  ('agronoma', 'cdlugo'): 7,
#  ('agronoma', 'mercados'): 7,
#  ('agronoma', 'business'): 7,
#  ('agronoma', 'vida'): 7,
#  ('agronoma', 'bizkaia'): 7,
#  ('agronoma', 'aljarafe'): 7,
#  ('agronoma', 'wappissima'): 7,
#  ('agronoma', 'mascotas'): 7,
#  ('agronoma', 'formula1'): 7,
#  ('agronoma', 'ocio'): 7,
#  ('agronoma', 'cine'): 7,
#  ('agronoma', 'comics'): 7,
#  ('agronoma', 'lopd'): 7,
#  ('agronoma', 'quienes'): 7,
#  ('agronoma', 'virales'): 7,
#  ('agronoma', 'safor'): 7,
#  ('agronoma', 'costera'): 7,
#  ('agronoma', 'morvedre'): 7,
#  ('agronoma', 'comunitat'): 7,
#  ('agronoma', 'gran-vigo'): 7,
#  ('agronoma', 'humor'): 7,
#  ('agronoma', 'jaen'): 7,
#  ('agronoma', 'blogs'): 7,
#  ('agronoma', 'fnd'): 7,
#  ('agronoma', 'gastronomia-c7'): 7,
#  ('agronoma', 'athletic'): 7,
#  ('agronoma', 'bilbao'): 7,
#  ('agronoma', 'badajoz'): 7,
#  ('agronoma', 'plasencia'): 7,
#  ('agronoma', 'ensalsa'): 7,
#  ('agronoma', 'oriente'): 7,
#  ('agronoma', 'oviedo'): 7,
#  ('agronoma', 'aviles'): 7,
#  ('agronoma', 'siero'): 7,
#  ('agronoma', 'cuencas'): 7,
#  ('agronoma', 'asturianos'): 7,
#  ('agronoma', 'chiclana'): 7,
#  ('agronoma', 'sierra'): 7,
#  ('agronoma', 'rss.html'): 7,
#  ('agronoma', 'benidorm'): 7,
#  ('agronoma', 'elda'): 7,
#  ('agronoma', 'alacanti'): 7,
#  ('agronoma', 'vega-baja'): 7,
#  ('agronoma', 'osasuna'): 7,
#  ('agronoma', 'esports'): 7,
#  ('agronoma', 'lacantera'): 7,
#  ('agronoma', 'somosagro'): 8,
#  ('agronoma', 'santiago'): 8,
#  ('agronoma', 'oparacing'): 8,
#  ('agronoma', 'forzabreo'): 8,
#  ('agronoma', 'minegocio'): 8,
#  ('agronoma', 'fugas'): 8,
#  ('agronoma', 'yes'): 8,
#  ('agronoma', 'creacion'): 8,
#  ('agronoma', 'culemania'): 8,
#  ('agronoma', 'letraglobal'): 8,
#  ('agronoma', 'agr_andalucia'): 8,
#  ('agronoma', 'delibros'): 8,
#  ('agronoma', 'vital'): 8,
#  ('agronoma', 'm-_h'): 8,
#  ('agronoma', 'pantallas'): 8,
#  ('agronoma', 'life'): 8,
#  ('agronoma', 'lo-ultimo'): 8,
#  ('agronoma', 'comarcas'): 8,
#  ('agronoma', 'realmurcia'): 8,
#  ('agronoma', 'o-morrazo'): 8,
#  ('agronoma', 'public'): 8,
#  ('agronoma', 'mapaweb'): 8,
#  ('agronoma', 'part-forana'): 8,
#  ('agronoma', 'vivir'): 8,
#  ('agronoma', 'actualidad'): 8,
#  ('agronoma', 'tendencias'): 8,
#  ('agronoma', 'culturas'): 8,
#  ('agronoma', 'caceres'): 8,
#  ('agronoma', 'sporting'): 8,
#  ('agronoma', 'cadiz'): 8,
#  ('agronoma', 'elbalcon'): 8,
#  ('agronoma', 'elpuerto'): 8,
#  ('agronoma', 'puerto-real'): 8,
#  ('agronoma', 'cadizcf'): 8,
#  ('agronoma', 'elche'): 8,
#  ('agronoma', 'elche-cf'): 8,
#  ('agronoma', 'hogueras'): 8,
#  ('agronoma', 'leequid'): 8,
#  ('agronoma', 'oxigena2'): 8,
#  ('agronoma', 'sd-huesca'): 8,
#  ('agronoma', 'cai-zaragoza'): 8,
#  ('agronoma', 'baloncesto'): 8,
#  ('agronoma', 'pontevedra'): 9,
#  ('agronoma', 'en-voz-baja'): 9,
#  ('agronoma', 'ultima-hora'): 9,
#  ('agronoma', 'rastrodelafama'): 9,
#  ('agronoma', 'doshermanas'): 9,
#  ('agronoma', 'entrevistas'): 9,
#  ('agronoma', 'sevillafc'): 9,
#  ('agronoma', 'realbetis'): 9,
#  ('agronoma', 'carlos_colon'): 9,
#  ('agronoma', 'paz_madrid'): 9,
#  ('agronoma', 'registrate'): 9,
#  ('agronoma', 'en-valencia'): 9,
#  ('agronoma', 'levante-ud'): 9,
#  ('agronoma', 'fccartagena'): 9,
#  ('agronoma', 'promociones'): 9,
#  ('agronoma', 'buzzeando'): 9,
#  ('agronoma', 'descobreix'): 9,
#  ('agronoma', 'villaviciosa'): 9,
#  ('agronoma', 'real-oviedo'): 9,
#  ('agronoma', 'occidente'): 9,
#  ('agronoma', 'concursos'): 9,
#  ('agronoma', 'sanfernando'): 9,
#  ('agronoma', 'bocabierta'): 9,
#  ('agronoma', 'tour-francia'): 9,
#  ('agronoma', 'concellos'): 9,
#  ('agronoma', 'real-zaragoza'): 9,
#  ('agronoma', 'localidades'): 10,
#  ('agronoma', 'obituarios'): 10,
#  ('agronoma', 'andarmiudino'): 10,
#  ('agronoma', 'reto-digital'): 10,
#  ('agronoma', 'galicia-innova'): 10,
#  ('agronoma', 'pensamiento'): 10,
#  ('agronoma', 'semana_santa'): 10,
#  ('agronoma', 'motociclismo'): 10,
#  ('agronoma', 'television'): 10,
#  ('agronoma', 'luis_lastra'): 10,
#  ('agronoma', 'carmen_camacho'): 10,
#  ('agronoma', 'tendencias21'): 10,
#  ('agronoma', 'butlletins'): 10,
#  ('agronoma', 'rcd-mallorca'): 10,
#  ('agronoma', 'especiales'): 10,
#  ('agronoma', 'prov-badajoz'): 10,
#  ('agronoma', 'prov-caceres'): 10,
#  ('agronoma', 'con-la-venia'): 10,
#  ('agronoma', 'tamara_garcia'): 10,
#  ('agronoma', 'baix-vinalopo'): 10,
#  ('agronoma', 'hercules-cf'): 10,
#  ('agronoma', 'comunicacion'): 10,
#  ('agronoma', 'elplural-tv'): 10,
#  ('agronoma', 'tren-cultura'): 10,
#  ('agronoma', 'galicia-economica'): 11,
#  ('agronoma', 'torremarathon'): 11,
#  ('agronoma', 'motor-gallego'): 11,
#  ('agronoma', 'vivirensevilla'): 11,
#  ('agronoma', 'mapademusicas'): 11,
#  ('agronoma', 'marc_gabernet'): 11,
#  ('agronoma', 'carlos-alcaraz'): 11,
#  ('agronoma', 'localizacion'): 11,
#  ('agronoma', 'distribucion'): 11,
#  ('agronoma', 'asturias-rural'): 11,
#  ('agronoma', 'vivir_en_cadiz'): 11,
#  ('agronoma', 'costa-noroeste'): 11,
#  ('agronoma', 'julio_gonzalez'): 11,
#  ('agronoma', 'fuera-de-foco'): 11,
#  ('agronoma', 'cordoba-ciudad'): 11,
#  ('agronoma', 'futbolgallego'): 12,
#  ('agronoma', 'cronica-directo'): 12,
#  ('agronoma', 'feria_de_abril'): 12,
#  ('agronoma', 'medio-ambiente'): 12,
#  ('agronoma', 'susana_c-_gomez'): 12,
#  ('agronoma', 'vida-y-estilo'): 12,
#  ('agronoma', 'celta-de-vigo'): 12,
#  ('agronoma', 'gente-estilo'): 12,
#  ('agronoma', 'el-telescopio'): 12,
#  ('agronoma', 'polideportivo'): 12,
#  ('agronoma', 'orgullodenervion'): 13,
#  ('agronoma', 'primeras-planas'): 13,
#  ('agronoma', 'empresas-al-dia'): 13,
#  ('agronoma', 'artes_plasticas'): 13,
#  ('agronoma', 'galerias_graficas'): 13,
#  ('agronoma', 'festivaldecine'): 13,
#  ('agronoma', 'centenario-celta'): 13,
#  ('agronoma', 'alfinaldelapalmera'): 14,
#  ('agronoma', 'juan_antonio_solis'): 14,
#  ('agronoma', 'tv-espectaculos'): 14,
#  ('agronoma', 'portadas-del-dia'): 14,
#  ('agronoma', 'francisco_zambrano'): 14,
#  ('agronoma', 'teresa_almendros'): 14,
#  ('agronoma', 'Más de Información'): 14,
#  ('agronoma', 'buzon-del-lector'): 14,
#  ('agronoma', 'farmacias-guardia'): 14,
#  ('agronoma', 'cuadernos-del-sur'): 14,
#  ('agronoma', 'juzgado_de_guardia'): 15,
#  ('agronoma', 'alcala_de_guadaira'): 15,
#  ('agronoma', 'redaccion_grupo_joly'): 15,
#  ('agronoma', 'ignacio_f-_garmendia'): 15,
#  ('agronoma', 'diario_del_carnaval'): 15,
#  ('agronoma', 'finanzas-personales'): 15,
#  ('agronoma', 'violencia-machista'): 15,
#  ('agronoma', 'fiestas-del-pilar'): 15,
#  ('agronoma', 'area-blanquiverde'): 15,
#  ('agronoma', 'cronica-del-centro'): 15,
#  ('agronoma', 'mundial-baloncesto'): 15,
#  ('agronoma', 'historias-visuales'): 16,
#  ('agronoma', 'fernando_perez_avila'): 16,
#  ('agronoma', 'deza-tabeiros-montes'): 16,
#  ...}

# %%
dict(filter(lambda k: k[1] < 3, sorted_scores.items()))
# Out:
# {('alicante', 'alacanti'): 2,
#  ('alsol', 'alcoy'): 2,
#  ('amarina', 'marina'): 1,
#  ('asturianu', 'asturianos'): 2,
#  ('asturias', 'asturianu'): 2,
#  ('asturias', 'asturianos'): 2,
#  ('cadiz', 'cadizcf'): 2,
#  ('cine', 'life'): 2,
#  ('concurso', 'concursos'): 1,
#  ('cultura', 'culturas'): 1,
#  ('eltiempo', 'tiempo'): 2,
#  ('es', 'yes'): 1,
#  ('local', 'social'): 2,
#  ('local', 'global'): 2,
#  ('lugo', 'vigo'): 2,
#  ('lugo', 'cdlugo'): 2,
#  ('malaga', 'alava'): 2,
#  ('marina', 'merida'): 2,
#  ('motor', 'motogp'): 2,
#  ('planeta', 'llanera'): 2,
#  ('rocio', 'ocio'): 1,
#  ('rocio', 'elrocio'): 2,
#  ('sevilla', 'sevillafc'): 2,
#  ('siero', 'sierra'): 2,
#  ('social', 'epsocial'): 2,
#  ('tendencias21', 'tendencias'): 2,
#  ('viajar', 'viajes'): 2,
#  ('viajes', 'virales'): 2,
#  ('vida', 'vital'): 2,
#  ('vida', 'elda'): 2,
#  ('vigo', 'vida'): 2}

# %% [markdown]
# ### Analysis of invalid urls

# %%
with open("../data/No valid urls_8.txt", "r") as file:
    data = pd.read_table(file, 
                         header=None,
                        ).to_series()
data.rename(columns={0: "url"}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25988\4118711790.py in <module>
#       1 with open("./data/No valid urls_8.txt", "r") as file:
# ----> 2     data = pd.read_table(file,
#       3                          header=None,
#       4                         ).to_series()
#       5 data.rename(columns={0: "url"}, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_series'

# %%
filter_farodevigo = data.url.str.contains("farodevigo")
data_farodevigo = data[filter_farodevigo].replace(";(.*)", "", regex=True)
data_farodevigo.values
# Out:
# array([['https://www.farodevigo.es/tags/baloncesto/'],
#        ['https://www.farodevigo.es/autores/javier-puga-llopis.html'],
#        ['https://www.farodevigo.es/autores/jorge-garnelo.html'],
#        ['https://www.farodevigo.es/promociones/'],
#        ['https://www.farodevigo.es/autores/jose-manuel-otero-lastres.html'],
#        ['https://www.farodevigo.es/autores/xoel-ben-ben-ramos.html'],
#        ['https://www.farodevigo.es/mas-noticias/'],
#        ['https://www.farodevigo.es/municipios.html'],
#        ['https://www.farodevigo.es/videos/'],
#        ['https://www.farodevigo.es/autores/armando-alvarez.html'],
#        ['https://www.farodevigo.es/faroeduca/faro-da-escola/'],
#        ['https://www.farodevigo.es/visado/'],
#        ['https://www.farodevigo.es/motogp/'],
#        ['https://www.farodevigo.es/suplementos/'],
#        ['https://www.farodevigo.es/ocio/tv/'],
#        ['https://www.farodevigo.es/autores/maria-do-carmo-henriquez-salido.html'],
#        ['https://www.farodevigo.es/autores/gabino-porto.html'],
#        ['https://www.farodevigo.es/ideas/mas-alla-de-los-colores/entrenadores-inspiradores.html'],
#        ['https://www.farodevigo.es/rss.html'],
#        ['https://www.farodevigo.es/autores/fernando-clavijo.html'],
#        ['https://www.farodevigo.es/deportes/morrazo/'],
#        ['https://www.farodevigo.es/salud/'],
#        ['https://www.farodevigo.es/club-faro/'],
#        ['https://www.farodevigo.es'],
#        ['https://www.farodevigo.es/farmacias-guardia/vigo/'],
#        ['https://www.farodevigo.es/autores/manuel-rodriguez.html'],
#        ['https://www.farodevigo.es/autores/montserrat-gonzalez.html'],
#        ['https://www.farodevigo.es/tags/val-minor/'],
#        ['https://www.farodevigo.es/finanzas-personales/'],
#        ['https://www.farodevigo.es/tour-francia/']], dtype=object)

# %%
current_date, current_time = str(datetime.today()).split(" ")
current_time = current_time.split(" ")[-1].split(".")[0].replace(":", "-")
current_time
# Out:
# '17-34-26'

# %%
if not os.path.exists("./scrapping statistics"):
    os.makedirs("./scrapping statistics")
if not os.path.exists(os.path.join("./scrapping statistics", f"processes_{current_date}")):
    os.makedirs(os.path.join("./scrapping_statistics", f"processes_{current_date}"))

# %%
pid = "0"
stats_path = os.path.join("scrapping statistics", 
                          f"processes_{current_date}", 
                          f"process_{current_date}_{current_time}_pid_{pid}.csv",
                          
                          )
stats_path
# Out:
# 'scrapping statistics\\processes_2023-08-22\\process_2023-08-22_17-34-26_0.csv'

# %%
if not os.path.exists(os.path.join("./scrapping stats", f"processes_{current_date}")):
    os.makedirs(os.path.join("scrapping stats", f"processes_{current_date}"))
else:
    print("exists 2")
# Out:
# exists 2

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Analysis of audited media ojdinteractiva.ipynb',
#  'data',
#  'db.sqlite3',
#  'development and utest_generalizable_scrapper.ipynb',
#  'Errors log.txt',
#  'Extraction of audited media scimago media.ipynb',
#  'Extraction of audited media.ipynb',
#  'Medias url preprocessing before scrapping and loading.ipynb',
#  'News scrapper and loader_general http extraction with Selenium.py',
#  'obsolete',
#  'registro de medios sin json disponible en codigo html.txt',
#  'Scrapper and loader test.py',
#  'Scrapper and loader.py',
#  'scrapping_stats',
#  'Skipped urls.txt',
#  'Unit tests.ipynb',
#  'URL cross-comparation.ipynb',
#  'utilities.py',
#  'Wrappers.ipynb',
#  '__pycache__']

# %%
os.path.exists(os.path.join("scrapping stats", f"processes_{current_date}"))
# Out:
# False
