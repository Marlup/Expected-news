# %% [markdown]
# Extracted from: https://www.scimagomedia.com/index.php

# %%
import pandas as pd
import numpy as np
import os
import re
from matplotlib import pyplot as plt
import xml
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.scimagomedia.com/rankings.php?country=Spain&language=Spanish"
response = requests.get(url)
parsed_html = BeautifulSoup(response.content, "html.parser")

def find_data_rows(tag):
    return tag.name == "tr" and "data-offer" in tag.attrs
tags_with_data = parsed_html.find_all("table", attrs={"class": "medios"})[-1].find_all(find_data_rows)
data = [re.sub("\n+", "\n", x.get_text("\n")).split("\n") for x in tags_with_data]
data = [x[2:-1] if len(x) <= 12 else x[4:-1] for x in data]
keys = (
    "name",
    "category",
    "sub_category",
    "daily_unique_ips_avg",
    "total_unique_ips",
    "variation",
    "sequences_of_visits",
    "visit_duration_avg",
    "pages"
)

# %%
traffic = pd.DataFrame(data, columns=keys).drop("variation", axis=1)
traffic.replace("--", np.nan, inplace=True)

# %%
numeric_cols = ["daily_unique_ips_avg", "total_unique_ips", "sequences_of_visits", "pages"]
traffic[numeric_cols] = traffic[numeric_cols].apply(lambda col: col.replace(["[.]", "[,]"], ["", "."], regex=True), axis=1)
traffic[numeric_cols] = traffic[numeric_cols].astype(float)
visit_duration_splits = traffic["visit_duration_avg"].str.extract("(?P<hours>[0-9]+):(?P<minutes>[0-9]+):(?P<seconds>[0-9]+)").astype(float)
traffic = pd.concat([traffic.drop("visit_duration_avg", axis=1), 
                     visit_duration_splits.drop("hours", axis=1)
                    ], axis=1)

# %%
traffic
# Out:
#                          name                category  \
# 0         7DIESACTUALITAT.COM  Noticias e Información
# 1           7TELEVALENCIA.COM  Noticias e Información
# 2             7TVANDALUCIA.ES         Entretenimiento
# 3     ACTUALIDADRIOJABAJA.COM  Noticias e Información
# 4    ACTUALITATVALENCIANA.COM  Noticias e Información
# ..                        ...                     ...
# 558            XCATALUNYA.CAT  Noticias e Información
# 559                XTRADIO.ES         Entretenimiento
# 560                   ZA49.ES  Noticias e Información
# 561         ZAMORA3PUNTO0.COM  Noticias e Información
# 562            ZAMORANEWS.COM  Noticias e Información
#
#                        sub_category  daily_unique_ips_avg  total_unique_ips  \
# 0    Noticias globales y actualidad                 434.0            9303.0
# 1    Noticias globales y actualidad                7682.0          182966.0
# 2                         Broadcast                1643.0           37572.0
# 3    Noticias globales y actualidad                2510.0           59854.0
# 4    Noticias globales y actualidad                3854.0           98610.0
# ..                              ...                   ...               ...
# 558  Noticias globales y actualidad               15658.0          239224.0
# 559                       Broadcast                  56.0            1331.0
# 560  Noticias globales y actualidad                4862.0           94374.0
# 561  Noticias globales y actualidad                1708.0           46142.0
# 562  Noticias globales y actualidad               12856.0          244900.0
#
#      sequences_of_visits     pages  minutes  seconds
# 0                17193.0   28929.0      1.0     39.0
# 1               251828.0  312441.0      1.0      4.0
# 2                63859.0  180869.0      1.0     25.0
# 3                84214.0  106288.0      0.0     38.0
# 4               127268.0  293923.0      1.0      8.0
# ..                   ...       ...      ...      ...
# 558             549739.0  646193.0      0.0     37.0
# 559               1965.0    3589.0      1.0     39.0
# 560             162722.0  217017.0      0.0     33.0
# 561              55974.0   94094.0      1.0      8.0
# 562             464392.0  658458.0      0.0     47.0
#
# [563 rows x 9 columns]

# %%
from datetime import datetime
datetime_str = str(datetime.today()).split(".")[0].replace(":", "_")
file_name = f"../data/spain_audience_total_traffic_{datetime_str}.csv"
traffic.to_csv(file_name)
print(f"Saved at {datetime_str}")
# Out:
# Saved at 2023-07-09 11_08_51

# %%
traffic.head()
# Out:
#                        name                category  \
# 0       7DIESACTUALITAT.COM  Noticias e Información
# 1         7TELEVALENCIA.COM  Noticias e Información
# 2           7TVANDALUCIA.ES         Entretenimiento
# 3   ACTUALIDADRIOJABAJA.COM  Noticias e Información
# 4  ACTUALITATVALENCIANA.COM  Noticias e Información
#
#                      sub_category  daily_unique_ips_avg  total_unique_ips  \
# 0  Noticias globales y actualidad                 434.0            9303.0
# 1  Noticias globales y actualidad                7682.0          182966.0
# 2                       Broadcast                1643.0           37572.0
# 3  Noticias globales y actualidad                2510.0           59854.0
# 4  Noticias globales y actualidad                3854.0           98610.0
#
#    sequences_of_visits     pages  minutes  seconds
# 0              17193.0   28929.0      1.0     39.0
# 1             251828.0  312441.0      1.0      4.0
# 2              63859.0  180869.0      1.0     25.0
# 3              84214.0  106288.0      0.0     38.0
# 4             127268.0  293923.0      1.0      8.0

# %% [markdown]
# ## Extraction through file

# %%
#!pip install xlrd
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      -------------------------------------- 250.0/250.0 kB 5.1 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
import xlrd
import openpyxl

# %%
os.listdir("../data")
# Out:
# ['.ipynb_checkpoints',
#  'BOE-A-1996-8930-consolidado_ley propiedad intelectual.pdf',
#  'BOE-A-1996-8930-consolidado_ley propiedad intelectual_plain text.txt',
#  'db.sqlite3',
#  'extraction checkpoint.json',
#  'region_to_media_urls.json',
#  'role prompt_keys extraction.txt',
#  'SCImago Media Ranking - Spain - Spanish.xlsx',
#  'spain_audience_total_traffic_2023-07-09 11_08_51.csv',
#  'sqldiff.exe',
#  'sqlite3.exe',
#  'sqlite3_analyzer.exe',
#  'test full news_okdiario.txt',
#  'test full news_xataka.txt',
#  'versiones de prompts para extraer keys de noticias.txt']

# %%
file_name = 'SCImago Media Ranking - Spain - Spanish.xlsx'

# %%
ranking = pd.read_excel(os.path.join("data", file_name)).drop(["Country", 
                                                               "Region", 
                                                               "Language"], axis=1)
ranking
# Out:
#                             Media                          Domain  \
# 0         Informaciones de cuenca           informacioncuenca.com
# 1    Diario Independiente Digital  diarioindependientedigital.com
# 2                   Navarra norte                 navarranorte.es
# 3                    Diari balear                  diaribalear.es
# 4                     Navarra sur                   navarrasur.es
# ..                            ...                             ...
# 184                 La Vanguardia                lavanguardia.com
# 185                      El Mundo                      elmundo.es
# 186                    El Español                   elespanol.com
# 187                          ABC                           abc.es
# 188                       El País                      elpais.com
#
#      Global_rank  Overall
# 0           4343     9.50
# 1           4281    10.75
# 2           4224    11.75
# 3           4224    11.75
# 4           4113    14.25
# ..           ...      ...
# 184           69    74.25
# 185           48    76.25
# 186           44    76.75
# 187           25    78.75
# 188            7    83.75
#
# [189 rows x 4 columns]

# %%
# Null values
ranking.isnull().sum()
# Out:
# Media          0
# Domain         0
# Country        0
# Region         0
# Language       0
# Global_rank    0
# Overall        0
# dtype: int64

# %%
ranking_global = ranking.sort_values("Global_rank")
ranking_overall = ranking.sort_values("Global_rank")
np.equal(ranking_global, ranking_overall).all()
# Out:
# Media          True
# Domain         True
# Global_rank    True
# Overall        True
# dtype: bool

# %%
ranking.sort_values("Global_rank", ascending=True, inplace=True)
ranking.head(50)
# Out:
#                             Media                          Domain  \
# 188                       El País                      elpais.com
# 187                          ABC                           abc.es
# 186                    El Español                   elespanol.com
# 185                      El Mundo                      elmundo.es
# 184                 La Vanguardia                lavanguardia.com
# ..                            ...                             ...
# 4                     Navarra sur                   navarrasur.es
# 3                    Diari balear                  diaribalear.es
# 2                   Navarra norte                 navarranorte.es
# 1    Diario Independiente Digital  diarioindependientedigital.com
# 0         Informaciones de cuenca           informacioncuenca.com
#
#      Global_rank  Overall
# 188            7    83.75
# 187           25    78.75
# 186           44    76.75
# 185           48    76.25
# 184           69    74.25
# ..           ...      ...
# 4           4113    14.25
# 3           4224    11.75
# 2           4224    11.75
# 1           4281    10.75
# 0           4343     9.50
#
# [189 rows x 4 columns]

# %%
ranking.set_index("Media").head(50)
# Out:
#                                                   Domain  Global_rank  Overall
# Media
# El País                                       elpais.com            7    83.75
# ABC                                               abc.es           25    78.75
# El Español                                 elespanol.com           44    76.75
# El Mundo                                      elmundo.es           48    76.25
# La Vanguardia                           lavanguardia.com           69    74.25
# El Periódico de Catalunya                elperiodico.com           71    74.00
# La Razón                                      larazon.es           98    71.75
# 20 Minutos                                  20minutos.es          103    71.50
# ABC de Sevilla                           sevilla.abc.es/          103    71.50
# Europa Press                              europapress.es          123    70.50
# elDiario.es                                  eldiario.es          142    69.50
# La Voz de Galicia                      lavozdegalicia.es          189    68.00
# El Correo Español                           elcorreo.com          229    66.75
# Libertad Digital                     libertaddigital.com          238    66.50
# SUR                                         diariosur.es          238    66.50
# Diario de Sevilla                     diariodesevilla.es          247    66.25
# Crónica global               cronicaglobal.elespanol.com          253    66.00
# El Diario Vasco                          diariovasco.com          272    65.50
# La Verdad                                    laverdad.es          289    65.00
# Levante                                  levante-emv.com          302    64.75
# El Confidencial                       elconfidencial.com          312    64.50
# Las Provincias                          lasprovincias.es          312    64.50
# Heraldo de Aragón                             heraldo.es          327    64.25
# OK Diario                                   okdiario.com          344    63.75
# Ideal                                           ideal.es          344    63.75
# Huffington Post España                 huffingtonpost.es          363    63.50
# Faro de Vigo                               farodevigo.es          382    63.00
# Canarias 7                                  canarias7.es          405    62.50
# El Periódico de España                            epe.es          419    62.25
# La Información                         lainformacion.com          434    62.00
# Periodista Digital                 periodistadigital.com          446    61.75
# Publico                                       publico.es          446    61.75
# DEIA                                            deia.eus          467    61.25
# El Comercio                                elcomercio.es          467    61.25
# Diario de Mallorca                   diariodemallorca.es          477    61.00
# Hoy de Badajoz                                    hoy.es          493    60.75
# El Diario Montañes                   eldiariomontanes.es          521    60.25
# Información                               informacion.es          521    60.25
# La Rioja                                     larioja.com          521    60.25
# República                                  republica.com          521    60.25
# Diario de Cádiz                         diariodecadiz.es          521    60.25
# El Plural                                   elplural.com          570    59.50
# Diario de Noticias                 noticiasdenavarra.com          570    59.50
# La Nueva España                                   lne.es          582    59.25
# Última Hora                                ultimahora.es          582    59.25
# El Confidencial Digital        elconfidencialdigital.com          597    59.00
# El Día                                          eldia.es          597    59.00
# La Opinión de Murcia                laopiniondemurcia.es          597    59.00
# El Periódico de Aragón           elperiodicodearagon.com          613    58.75
# El Periódico de Extremadura   elperiodicoextremadura.com          646    58.25

# %%
# Save list of media urls from spain
ranking.set_index("Media").Domain.to_json("../data/spain_media_name_to_url.json")
